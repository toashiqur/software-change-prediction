# %% [markdown]
# Input:
#
# Function:
#
# Output:
#
# Update:
# - Added tf.nn.relu explicitly in the model(updated: 5 april, 2018)
#
# Todo:

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import metrics

# %%
# %matplotlib inline

# %%
data_source_path = "F:\deep lerning project\data\FinalData\d2.wordpress_phpbb23.label_density.csv"

#test_output_file = open("F:\\deep lerning project\\data\\FinalData\\hidden_layer_test_output.txt", mode = 'w')# for testing layers...delete if not needed
# for slicing the necessary columns from the source file...directly related to source data columns
label_col_start = 0
feature_col_start = 8

# I have many labels but here is the col that contains 'changed_ever_class'
class_label_col = 2 # class is in col 2

# %%
# Some configurations
# set only one to true...
select_model_based_on_loss = False
select_model_based_on_error_rate = False
select_model_based_on_auc = True
#---------------------------------

# %%
def get_feature_and_label():
    # read the data file
    # return features and labels
    
    file_change_df = pd.read_csv(data_source_path)
    
    X = file_change_df.iloc[:,feature_col_start:]
    #print(X.shape)
    #print(X)
    
    y_all_labels = file_change_df.iloc[:,label_col_start:feature_col_start] # all available labels 
    #print(type(y_all_labels))
    #print(y_all_labels)
    y = y_all_labels.iloc[:,class_label_col] # take the changed_ever col only
    y = pd.Series.to_frame(y) # y is a series...convert it to dataframe again--- not necessary...series will do
    #print(y.head())
    #print(type(y))
    
    #print(y.shape)
    #print(y)
    
    return X, y

# %%
def get_train_test_split(X, y, nsplits = 1, testSize = 0.2):

    sss = StratifiedShuffleSplit(n_splits=nsplits, test_size=testSize)
    
    for train_index, test_index in sss.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index] # X.iloc[index] because its pandas dataframe.so..iloc
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    return X_train, y_train, X_test, y_test

# %%
def show_data_statistics(X_train, y_train, X_test, y_test):
    #print(X_train.shape)
    #print(y_train.shape)
    #print(X_test.shape)
    #print(y_test.shape)
    #print(type(y_test))
    print("y_train Statistics:\n", y_train.describe())
    print("y_test Statistics:\n",y_test.describe())
    
    plt.hist(y_train)
    plt.hist(y_test)

# %%
def get_feature_cols(X):
    feature_cols = []
    i=0

    for col in X.columns:
        #if is_numeric_dtype(X[col]): #is_numeric_dtype is pandas function
        feature_cols.extend([tf.feature_column.numeric_column(col)])
        i = i+1
        
    print("Total features column names converted to tf.feature_column.numeric_column('col_name') = ", i)
    return feature_cols

# %%
def train_model(model, X_train, y_train):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        batch_size=10,
        num_epochs=3000,
        shuffle=True)    
    
    model = model.train(input_fn=input_func,steps=3000)
    
    return model

# %%
def evaluate_model(model, X_test, y_test):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    results = model.evaluate(input_func)
    #print(results)
    
    return results

# %%
def prediction(model, X, y):
    
    prediction_list = []
    y_proba_positive_class_list = [] # positive class probability of each element for calculating AUC
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    y_predicted = model.predict(input_func)
    
    for elem in y_predicted: # y_predicted is a generator object holds a memory address...read all values from there
        #print("type elem:", type(elem))
        #print("elem:", elem)
        elem_probabilities = np.array(elem['probabilities'])
        #print("Elem probabilities of each class:", elem_probabilities)
        
        y_proba_positive_class_list.append(elem_probabilities[1]) # class 1 is the positive class, its index is 1
        #print("prob_list_now:", elem_positive_class_proba_list)
        
        elem_class = np.argmax(elem_probabilities) # one probable class based on the index that contain max value
        #print("probable class:",elem_class)
        
        prediction_list.append(elem_class)
        
    
    # assign prediction list to y_predicted for consistent name
    y_predicted = np.array(prediction_list)
    
    #print("y_predicted_shape:", y_predicted.shape, "val:", y_predicted)
    #print("y_type:", type(y),"y shape:", y.shape, "val:", y)
    
    #error_rate = sum(y_predicted != np.array(y)/len(y_predicted))
    
    #print(list(y_predicted))
    
    y = np.array(y) # convert y data to np array
    r,c = y.shape
    #print("y- r,c:",r,c)
    y = y.reshape(r) # change the shape of y to numpy [row,]
    #print("y-shape:", y.shape)
    
    
    '''
    print("before converting to list y_predicted:", y_predicted)
    
    y_predicted = list(y_predicted)
    print("y_predicted:", y_predicted)
    
    y_predicted = np.array(y_predicted)
    print("after converting to nparray y_predicted:", y_predicted, "shape:", y_predicted.shape)
    
    y= np.array(y)
    r,c = y.shape
    print("y- r,c:",r,c)
    y = y.reshape(r)
    print("y-shape:", y.shape)
    '''
    
    error_rate = sum(y_predicted != y)/len(y_predicted) # sum needs the operands in np array of shape [row,]
    
    return y_predicted, error_rate, y_proba_positive_class_list

# %%
def get_normalized_train_data(X_train):
    #Unused function---Normalization is done separately
    #print(type(X_train))
    #print(X_train.head())
    saved_cols = X_train.columns # save the columns names..scaling change the pandas frame to numpy..need to restore
    saved_index = list(X_train.index) # # scaling changes pandas X indices..need to restore to match with y data indices
    #print("saved_index", saved_index)
    
    min_max_scaler = preprocessing.MinMaxScaler()
    
    scaled_X_train = min_max_scaler.fit_transform(X_train)
    scaled_X_train = pd.DataFrame(scaled_X_train, index=saved_index, columns=saved_cols)# restore the column names

    #print(scaled_X_train.head())
    return scaled_X_train

# %%
def get_random_sample(X, y, n_sample = 1):
    n = np.arange(X.shape[0]) # generate numbers equal to the max no of rows in the X df
    if n_sample>len(n):
        print("You have asked", n_sample, " samples, but the training data has", len(n), " rows. Returning 1 sample...")
        n_sample = 1
        
    np.random.shuffle(n) # shuffle all the numbers representing row index
    index = n[0:n_sample] # take the numbers from 0 to given sample
    
    X_sample = X.iloc[index]
    y_sample = y.iloc[index]
    
    #print(X_sample.head())
    #print(y_sample.head())
    
    return X_sample, y_sample

# %%
def show_evaluation_error_report(eval_error_rates):
    
    eval_error_rate_avg = sum(eval_error_rates)/len(eval_error_rates)
    model_std = np.std(eval_error_rates)
    
    print("Evaluation Errors:", eval_error_rates)
    print('Evaluation error rate average:', eval_error_rate_avg, '\nModel\'s standard deviation:', model_std)

# %%
def calculate_performance_metrics(cnf_matrix):
    
    TP = cnf_matrix[1,1]
    TN = cnf_matrix[0,0]
    FP = cnf_matrix[0,1]
    FN = cnf_matrix[1,0]
    
    
    # Sensitivity, hit rate, recall, or true positive rate
    TPR_recall = TP/(TP+FN) # Recall
    # Specificity or true negative rate
    TNR = TN/(TN+FP) # **
    # Precision or positive predictive value
    PPV_precision = TP/(TP+FP) # precision
    # Negative predictive value
    NPV = TN/(TN+FN) #**
    # Fall out or false positive rate
    FPR_false_positive = FP/(FP+TN)
    # False negative rate
    FNR_false_negative = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP) # **

    # Overall accuracy
    accuracy = (TP+TN)/(TP+FP+FN+TN)
    f_measure = 2/((1.0/TPR_recall) + (1.0/PPV_precision)) #https://en.wikipedia.org/wiki/F1_score
    
    # ** some extra values are calculated but not returned
    return TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def get_roc_auc(y, y_proba_positive_class_list):
    
    y = y.as_matrix() # convert series data to numpy array
    
    auc = metrics.roc_auc_score(y, y_proba_positive_class_list)
    #print("Auc:", auc)
    
    '''
    #This one also works but not needed
    fpr, tpr, thresholds = metrics.roc_curve(y, elem_positive_class_proba_list)
    auc2 = metrics.auc(fpr, tpr)
    print("AUC2:", auc2, "fpr:", fpr, "tpr:", tpr)
    '''
    return auc

# %%
def get_cnf_matrix_prf_metrics(y, y_predicted):
    
    y = y.values.tolist() # convert pandas data to list
    #print(">>>>>type_y:", type(y), "val:", y)
    
    y = list(np.array(y).flat) # when converted to list panda gives [[values], [values]]...convert them to flat list[]
    #print("----------type_y_f:", type(y), "val:", y)
    
    
    y_predicted = list(y_predicted)
    #print(">>>>>>type_y_predicted:", type(y_predicted), "val:", y_predicted)
    
    cnf_matrix = confusion_matrix(y, y_predicted)
    
    #print("conf matrix:", cnf_matrix)
    # Calculate performane metrics
    TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = calculate_performance_metrics(cnf_matrix)
    
    return cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def show_confusion_matrix(cnf_matrix, class_names):
    # show cmap of confusion metrics
    np.set_printoptions(precision=2) # settings for printing floating point values
    
    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def main():
    
    X, y = get_feature_and_label()
    X_train_0, y_train_0, X_test_final, y_test_final = get_train_test_split(X,y) #get_train_test_split(X, y, nsplits = 1, testSize = 0.2)

    #show_data_statistics("---Train-Test Statistics---",X_train, y_train, X_test, y_test)
    #print(type(X))
    feature_cols = get_feature_cols(X_train_0)
    #print(feature_cols)

    # start k-fold cross validation and find the best model with the minimum loss during evaluation
    
    min_loss = float('inf')
    min_error_rate = float("inf")
    max_auc = float("-inf")

    folding_session = 0
    eval_error_rates = []
    
    sss = StratifiedShuffleSplit(n_splits=10) #stratifiedkfold generates error for y_train_0 and doesn't work if y multi-labe
    
    for train_index, eval_index in sss.split(X_train_0, y_train_0):

        X_train, X_eval = X_train_0.iloc[train_index], X_train_0.iloc[eval_index]  # iloc[index] because X is a pandas dataframe
        y_train, y_eval = y_train_0.iloc[train_index], y_train_0.iloc[eval_index]
        

        #X_train = get_normalized_train_data(X_train) # min-max standardization
        #print(X_train.head())
        
        # Add layers in this list if more layer settings are needed
        hidden_layers_units = [
            [1022, 511, 255, 128]
        ]
        
        for my_hidden_units in hidden_layers_units:
            print("Hidden Settings:", my_hidden_units)
            #create a new estimator model

            file_change_prediction_model = tf.estimator.DNNClassifier(
                                                                    hidden_units = my_hidden_units,
                                                                    feature_columns = feature_cols, 
                                                                    n_classes=2, 
                                                                    activation_fn = tf.nn.relu)

            #print("new:", file_change_prediction_model)    

            #train the model
            file_change_prediction_model = train_model(file_change_prediction_model, X_train, y_train)
            #print("ret:", file_change_prediction_model)

            #evaluate the trained model
            evaluation_res = evaluate_model(file_change_prediction_model, X_eval, y_eval)
            print("Evaluation using Tensorflow evaluate method...Result at folding session:", folding_session, evaluation_res,"\n\n")
            
            # Do my own evaluation using the trained model in this folding session using evaluation data
            y_predicted, error_rate, y_proba_positive_class_list = prediction(file_change_prediction_model, X_eval, y_eval)
            eval_error_rates.append(error_rate) # error_rate of current folding session
            
            # calculate auc
            auc_evaluation = get_roc_auc(y_eval, y_proba_positive_class_list)

            #----
            #print("\nHidden Settings:", my_hidden_units, file=test_output_file)
            #print('\nFolding Session', folding_session,"AUC:",auc_validation,"Accuracy:", 1-error_rate, 'Error_rate:', error_rate, file=test_output_file)
            print('\n-----Folding Session', folding_session, "Hidden Settings:", my_hidden_units, "-----\nAUC:",auc_evaluation, "Accuracy:", 1-error_rate, 'Error_rate:', error_rate)
    
            #----
            #select the best model using the tensorflow evaluation result
            if select_model_based_on_loss:
                if evaluation_res['loss'] < min_loss:
                    best_model = file_change_prediction_model
                    min_loss = evaluation_res['loss']
                    print("Selecting model based on min_loss.")
    
            # select the best model based on calculated error rate
            if select_model_based_on_error_rate:
                if error_rate < min_error_rate:
                    best_model = file_change_prediction_model # save the best model
                    min_error_rate = error_rate # update the min_error_rate
                    print("Selecting model based on min_error_rate.")
                
            if select_model_based_on_auc:
                if auc_evaluation > max_auc:
                    best_model = file_change_prediction_model # save the best model
                    max_auc = auc_evaluation # update the max_auc
                    print("Selecting model based on max_auc.")

            #Take the next fold in the loop
        folding_session = folding_session + 1
        #break # remove it later for k-fold...now just one fold    
    
    #============================================
    
    print("\n-----k-fold summary:-----")
    k_fold_eval_error_rates = eval_error_rates # for naming consistency with other models
    show_evaluation_error_report(k_fold_eval_error_rates) 
    
    # see the evaluation result using the best model and some random sample from the used training data
    #X_eval, y_eval = get_random_sample(X_train_0,y_train_0, n_sample = 1000)
    #test_res = evaluate_model(best_model, X_eval, y_eval)
    #print("A random evaluation of the model:\n", test_res)
    
    # Do final test using tensorflow function
    #test_res = evaluate_model(best_model, X_test_final, y_test_final)
    #print("Final performance with the best model and test data:", test_res)
    
    #Everything finished I have got the best model and now want to get the final evaluation in my format
    #----------------------------------------------------------------------------------------------------
    #predict using the best model
    y_predicted, error_rate, y_proba_positive_class_list = prediction(best_model, X_test_final, y_test_final)
    #print("shape of x test final:", X_test_final)
    
    # calculate auc
    auc_final = get_roc_auc(y_test_final, y_proba_positive_class_list)
    print("\nFinal Test>> AUC:", auc_final, "Accuracy:", 1-error_rate, "Final Error_rate:", error_rate)
    
    cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = get_cnf_matrix_prf_metrics(y_test_final, y_predicted)
    print("F-measure:", f_measure, "Accuracy:",accuracy, "Recall:", TPR_recall, "Precision:", PPV_precision, "False Positive Rate:", FPR_false_positive, "False Negative Rate:", FNR_false_negative)
    
    class_names = ['0','1'] # class names in order.. 1st index for class whose label is 0, 2nd index for class whose label is 1......
    show_confusion_matrix(cnf_matrix, class_names)

# %%
main()
# Out:
# Total features column names converted to tf.feature_column.numeric_column('col_name') =  1021
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpc3inuc6a'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a\model.ckpt.
# INFO:tensorflow:loss = 13.8607, step = 1
# INFO:tensorflow:global_step/sec: 8.92244
# INFO:tensorflow:loss = 11.2703, step = 101 (11.239 sec)
# INFO:tensorflow:global_step/sec: 3.62215
# INFO:tensorflow:loss = 3.95459, step = 201 (27.717 sec)
# INFO:tensorflow:global_step/sec: 3.50374
# INFO:tensorflow:loss = 4.39096, step = 301 (28.525 sec)
# INFO:tensorflow:global_step/sec: 3.4927
# INFO:tensorflow:loss = 4.65544, step = 401 (28.678 sec)
# INFO:tensorflow:global_step/sec: 3.40242
# INFO:tensorflow:loss = 5.5484, step = 501 (29.281 sec)
# INFO:tensorflow:global_step/sec: 3.42059
# INFO:tensorflow:loss = 3.31465, step = 601 (29.344 sec)
# INFO:tensorflow:global_step/sec: 3.59061
# INFO:tensorflow:loss = 4.46615, step = 701 (27.866 sec)
# INFO:tensorflow:global_step/sec: 3.26247
# INFO:tensorflow:loss = 5.58328, step = 801 (30.699 sec)
# INFO:tensorflow:global_step/sec: 3.48432
# INFO:tensorflow:loss = 3.38044, step = 901 (28.622 sec)
# INFO:tensorflow:global_step/sec: 3.52321
# INFO:tensorflow:loss = 4.78738, step = 1001 (28.352 sec)
# INFO:tensorflow:global_step/sec: 3.48775
# INFO:tensorflow:loss = 7.97513, step = 1101 (28.734 sec)
# INFO:tensorflow:global_step/sec: 3.42816
# INFO:tensorflow:loss = 10.5499, step = 1201 (29.108 sec)
# INFO:tensorflow:global_step/sec: 3.37474
# INFO:tensorflow:loss = 3.44275, step = 1301 (29.694 sec)
# INFO:tensorflow:global_step/sec: 3.50501
# INFO:tensorflow:loss = 3.91103, step = 1401 (28.531 sec)
# INFO:tensorflow:global_step/sec: 3.51214
# INFO:tensorflow:loss = 3.7365, step = 1501 (28.410 sec)
# INFO:tensorflow:global_step/sec: 3.40456
# INFO:tensorflow:loss = 3.76929, step = 1601 (29.372 sec)
# INFO:tensorflow:global_step/sec: 3.39895
# INFO:tensorflow:loss = 6.11183, step = 1701 (29.436 sec)
# INFO:tensorflow:global_step/sec: 3.21892
# INFO:tensorflow:loss = 4.14183, step = 1801 (31.144 sec)
# INFO:tensorflow:global_step/sec: 3.33289
# INFO:tensorflow:loss = 4.00966, step = 1901 (29.941 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.20636
# INFO:tensorflow:loss = 2.56858, step = 2001 (82.925 sec)
# INFO:tensorflow:global_step/sec: 10.4318
# INFO:tensorflow:loss = 3.8649, step = 2101 (9.727 sec)
# INFO:tensorflow:global_step/sec: 3.44624
# INFO:tensorflow:loss = 3.79689, step = 2201 (28.846 sec)
# INFO:tensorflow:global_step/sec: 3.31696
# INFO:tensorflow:loss = 3.73345, step = 2301 (30.163 sec)
# INFO:tensorflow:global_step/sec: 3.39957
# INFO:tensorflow:loss = 6.32466, step = 2401 (29.290 sec)
# INFO:tensorflow:global_step/sec: 3.47495
# INFO:tensorflow:loss = 5.00497, step = 2501 (28.918 sec)
# INFO:tensorflow:global_step/sec: 3.48581
# INFO:tensorflow:loss = 3.62963, step = 2601 (29.391 sec)
# INFO:tensorflow:global_step/sec: 3.15165
# INFO:tensorflow:loss = 3.59887, step = 2701 (30.979 sec)
# INFO:tensorflow:global_step/sec: 3.33074
# INFO:tensorflow:loss = 5.00681, step = 2801 (30.039 sec)
# INFO:tensorflow:global_step/sec: 3.39759
# INFO:tensorflow:loss = 2.10055, step = 2901 (29.339 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.8204.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-20:29:43
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-20:30:13
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.837585, accuracy_baseline = 0.839286, auc = 0.643667, auc_precision_recall = 0.870863, average_loss = 0.431569, global_step = 3000, label/mean = 0.839286, loss = 42.2937, prediction/mean = 0.812014
# Evaluation using Tensorflow evaluate method...Result at folding session: 0 {'auc_precision_recall': 0.87086272, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.81201369, 'average_loss': 0.4315685, 'auc': 0.64366663, 'accuracy': 0.83758503, 'loss': 42.293713, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpc3inuc6a\model.ckpt-3000
#
# -----Folding Session 0 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.688302428931 Accuracy: 0.837585034014 Error_rate: 0.162414965986
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpbkiepkg0'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0\model.ckpt.
# INFO:tensorflow:loss = 3.29154, step = 1
# INFO:tensorflow:global_step/sec: 8.87029
# INFO:tensorflow:loss = 2.72961, step = 101 (11.430 sec)
# INFO:tensorflow:global_step/sec: 3.43557
# INFO:tensorflow:loss = 3.30753, step = 201 (29.076 sec)
# INFO:tensorflow:global_step/sec: 3.38449
# INFO:tensorflow:loss = 3.13114, step = 301 (29.813 sec)
# INFO:tensorflow:global_step/sec: 3.44342
# INFO:tensorflow:loss = 3.71745, step = 401 (28.665 sec)
# INFO:tensorflow:global_step/sec: 3.45556
# INFO:tensorflow:loss = 3.06032, step = 501 (29.095 sec)
# INFO:tensorflow:global_step/sec: 3.47576
# INFO:tensorflow:loss = 3.45298, step = 601 (28.708 sec)
# INFO:tensorflow:global_step/sec: 3.37832
# INFO:tensorflow:loss = 2.47863, step = 701 (29.632 sec)
# INFO:tensorflow:global_step/sec: 3.38526
# INFO:tensorflow:loss = 3.23352, step = 801 (29.571 sec)
# INFO:tensorflow:global_step/sec: 3.47412
# INFO:tensorflow:loss = 2.74274, step = 901 (28.706 sec)
# INFO:tensorflow:global_step/sec: 3.50033
# INFO:tensorflow:loss = 3.06689, step = 1001 (28.619 sec)
# INFO:tensorflow:global_step/sec: 3.37891
# INFO:tensorflow:loss = 7.25452, step = 1101 (29.623 sec)
# INFO:tensorflow:global_step/sec: 3.37164
# INFO:tensorflow:loss = 6.43997, step = 1201 (29.643 sec)
# INFO:tensorflow:global_step/sec: 3.3715
# INFO:tensorflow:loss = 1.81646, step = 1301 (29.817 sec)
# INFO:tensorflow:global_step/sec: 3.44806
# INFO:tensorflow:loss = 1.97559, step = 1401 (28.814 sec)
# INFO:tensorflow:global_step/sec: 3.46514
# INFO:tensorflow:loss = 4.63294, step = 1501 (28.875 sec)
# INFO:tensorflow:global_step/sec: 3.31039
# INFO:tensorflow:loss = 2.28617, step = 1601 (30.301 sec)
# INFO:tensorflow:global_step/sec: 3.40628
# INFO:tensorflow:loss = 4.7476, step = 1701 (29.311 sec)
# INFO:tensorflow:global_step/sec: 3.58254
# INFO:tensorflow:loss = 2.9046, step = 1801 (27.851 sec)
# INFO:tensorflow:global_step/sec: 3.48523
# INFO:tensorflow:loss = 6.03369, step = 1901 (28.693 sec)
# INFO:tensorflow:Saving checkpoints for 1989 into C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.221
# INFO:tensorflow:loss = 4.20163, step = 2001 (81.853 sec)
# INFO:tensorflow:global_step/sec: 8.10502
# INFO:tensorflow:loss = 6.92004, step = 2101 (13.213 sec)
# INFO:tensorflow:global_step/sec: 3.34039
# INFO:tensorflow:loss = 0.872575, step = 2201 (29.062 sec)
# INFO:tensorflow:global_step/sec: 3.36247
# INFO:tensorflow:loss = 3.77407, step = 2301 (29.834 sec)
# INFO:tensorflow:global_step/sec: 3.45507
# INFO:tensorflow:loss = 4.69275, step = 2401 (28.943 sec)
# INFO:tensorflow:global_step/sec: 3.36749
# INFO:tensorflow:loss = 3.86354, step = 2501 (29.680 sec)
# INFO:tensorflow:global_step/sec: 3.46801
# INFO:tensorflow:loss = 1.78694, step = 2601 (28.788 sec)
# INFO:tensorflow:global_step/sec: 3.33046
# INFO:tensorflow:loss = 4.57797, step = 2701 (30.104 sec)
# INFO:tensorflow:global_step/sec: 3.3487
# INFO:tensorflow:loss = 3.58847, step = 2801 (29.847 sec)
# INFO:tensorflow:global_step/sec: 3.45577
# INFO:tensorflow:loss = 1.50856, step = 2901 (29.593 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.30947.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-20:53:58
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-20:54:28
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.861395, accuracy_baseline = 0.839286, auc = 0.800697, auc_precision_recall = 0.946187, average_loss = 0.378414, global_step = 3000, label/mean = 0.839286, loss = 37.0846, prediction/mean = 0.811419
# Evaluation using Tensorflow evaluate method...Result at folding session: 1 {'auc_precision_recall': 0.94618702, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.81141907, 'average_loss': 0.37841442, 'auc': 0.80069745, 'accuracy': 0.86139458, 'loss': 37.084614, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbkiepkg0\model.ckpt-3000
#
# -----Folding Session 1 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.800308775993 Accuracy: 0.861394557823 Error_rate: 0.138605442177
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp378m2q_s'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s\model.ckpt.
# INFO:tensorflow:loss = 5.1882, step = 1
# INFO:tensorflow:global_step/sec: 8.97817
# INFO:tensorflow:loss = 3.67123, step = 101 (11.326 sec)
# INFO:tensorflow:global_step/sec: 3.53921
# INFO:tensorflow:loss = 7.70872, step = 201 (28.239 sec)
# INFO:tensorflow:global_step/sec: 3.41553
# INFO:tensorflow:loss = 3.22875, step = 301 (29.231 sec)
# INFO:tensorflow:global_step/sec: 3.19466
# INFO:tensorflow:loss = 14.9233, step = 401 (31.365 sec)
# INFO:tensorflow:global_step/sec: 3.28297
# INFO:tensorflow:loss = 3.41056, step = 501 (30.398 sec)
# INFO:tensorflow:global_step/sec: 3.47694
# INFO:tensorflow:loss = 4.38978, step = 601 (28.667 sec)
# INFO:tensorflow:global_step/sec: 3.47421
# INFO:tensorflow:loss = 5.26503, step = 701 (28.909 sec)
# INFO:tensorflow:global_step/sec: 3.36712
# INFO:tensorflow:loss = 5.55584, step = 801 (29.762 sec)
# INFO:tensorflow:global_step/sec: 3.47716
# INFO:tensorflow:loss = 2.61438, step = 901 (29.418 sec)
# INFO:tensorflow:global_step/sec: 3.47274
# INFO:tensorflow:loss = 25.5294, step = 1001 (28.043 sec)
# INFO:tensorflow:global_step/sec: 3.27263
# INFO:tensorflow:loss = 2.95241, step = 1101 (30.541 sec)
# INFO:tensorflow:global_step/sec: 3.40084
# INFO:tensorflow:loss = 4.0483, step = 1201 (29.420 sec)
# INFO:tensorflow:global_step/sec: 3.45043
# INFO:tensorflow:loss = 3.01926, step = 1301 (29.029 sec)
# INFO:tensorflow:global_step/sec: 3.56628
# INFO:tensorflow:loss = 2.60566, step = 1401 (28.009 sec)
# INFO:tensorflow:global_step/sec: 3.39626
# INFO:tensorflow:loss = 7.31915, step = 1501 (29.444 sec)
# INFO:tensorflow:global_step/sec: 3.50566
# INFO:tensorflow:loss = 1.80125, step = 1601 (28.494 sec)
# INFO:tensorflow:global_step/sec: 3.52515
# INFO:tensorflow:loss = 11.9186, step = 1701 (28.321 sec)
# INFO:tensorflow:global_step/sec: 3.59964
# INFO:tensorflow:loss = 1.8551, step = 1801 (27.906 sec)
# INFO:tensorflow:global_step/sec: 3.39722
# INFO:tensorflow:loss = 2.482, step = 1901 (29.389 sec)
# INFO:tensorflow:global_step/sec: 3.40811
# INFO:tensorflow:loss = 1.52661, step = 2001 (29.326 sec)
# INFO:tensorflow:Saving checkpoints for 2003 into C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.56109
# INFO:tensorflow:loss = 2.6376, step = 2101 (64.183 sec)
# INFO:tensorflow:global_step/sec: 3.26265
# INFO:tensorflow:loss = 9.37957, step = 2201 (30.509 sec)
# INFO:tensorflow:global_step/sec: 3.47671
# INFO:tensorflow:loss = 3.00973, step = 2301 (28.810 sec)
# INFO:tensorflow:global_step/sec: 3.40733
# INFO:tensorflow:loss = 0.920266, step = 2401 (29.348 sec)
# INFO:tensorflow:global_step/sec: 3.33821
# INFO:tensorflow:loss = 6.21012, step = 2501 (29.987 sec)
# INFO:tensorflow:global_step/sec: 3.36005
# INFO:tensorflow:loss = 0.954509, step = 2601 (29.992 sec)
# INFO:tensorflow:global_step/sec: 3.41607
# INFO:tensorflow:loss = 4.07232, step = 2701 (28.933 sec)
# INFO:tensorflow:global_step/sec: 3.45951
# INFO:tensorflow:loss = 2.77988, step = 2801 (28.921 sec)
# INFO:tensorflow:global_step/sec: 3.44797
# INFO:tensorflow:loss = 4.81829, step = 2901 (29.062 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.23173.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-21:18:12
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-21:18:42
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.866497, accuracy_baseline = 0.839286, auc = 0.839487, auc_precision_recall = 0.956384, average_loss = 0.331461, global_step = 3000, label/mean = 0.839286, loss = 32.4832, prediction/mean = 0.820722
# Evaluation using Tensorflow evaluate method...Result at folding session: 2 {'auc_precision_recall': 0.95638436, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.82072198, 'average_loss': 0.33146086, 'auc': 0.83948743, 'accuracy': 0.86649662, 'loss': 32.483166, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp378m2q_s\model.ckpt-3000
#
# -----Folding Session 2 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.839819773457 Accuracy: 0.866496598639 Error_rate: 0.133503401361
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp40z6yntp'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp\model.ckpt.
# INFO:tensorflow:loss = 19.4383, step = 1
# INFO:tensorflow:global_step/sec: 8.37433
# INFO:tensorflow:loss = 2.70841, step = 101 (12.785 sec)
# INFO:tensorflow:global_step/sec: 3.30584
# INFO:tensorflow:loss = 0.803728, step = 201 (29.390 sec)
# INFO:tensorflow:global_step/sec: 3.33928
# INFO:tensorflow:loss = 2.28753, step = 301 (30.118 sec)
# INFO:tensorflow:global_step/sec: 3.58624
# INFO:tensorflow:loss = 3.54797, step = 401 (27.884 sec)
# INFO:tensorflow:global_step/sec: 3.37289
# INFO:tensorflow:loss = 3.12704, step = 501 (29.664 sec)
# INFO:tensorflow:global_step/sec: 3.38956
# INFO:tensorflow:loss = 6.8338, step = 601 (29.377 sec)
# INFO:tensorflow:global_step/sec: 3.40004
# INFO:tensorflow:loss = 1.55713, step = 701 (29.505 sec)
# INFO:tensorflow:global_step/sec: 3.49283
# INFO:tensorflow:loss = 5.08873, step = 801 (29.036 sec)
# INFO:tensorflow:global_step/sec: 3.45908
# INFO:tensorflow:loss = 6.37973, step = 901 (28.409 sec)
# INFO:tensorflow:global_step/sec: 3.52643
# INFO:tensorflow:loss = 6.44648, step = 1001 (28.467 sec)
# INFO:tensorflow:global_step/sec: 3.41529
# INFO:tensorflow:loss = 6.07846, step = 1101 (29.249 sec)
# INFO:tensorflow:global_step/sec: 3.42374
# INFO:tensorflow:loss = 0.779842, step = 1201 (29.255 sec)
# INFO:tensorflow:global_step/sec: 3.49843
# INFO:tensorflow:loss = 1.56916, step = 1301 (28.569 sec)
# INFO:tensorflow:global_step/sec: 3.48621
# INFO:tensorflow:loss = 2.79233, step = 1401 (28.591 sec)
# INFO:tensorflow:global_step/sec: 3.30895
# INFO:tensorflow:loss = 4.0082, step = 1501 (30.330 sec)
# INFO:tensorflow:global_step/sec: 3.0428
# INFO:tensorflow:loss = 4.19739, step = 1601 (32.881 sec)
# INFO:tensorflow:global_step/sec: 3.46494
# INFO:tensorflow:loss = 5.38401, step = 1701 (28.782 sec)
# INFO:tensorflow:global_step/sec: 3.40514
# INFO:tensorflow:loss = 2.38066, step = 1801 (29.367 sec)
# INFO:tensorflow:global_step/sec: 3.49424
# INFO:tensorflow:loss = 3.84976, step = 1901 (28.634 sec)
# INFO:tensorflow:Saving checkpoints for 1984 into C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.25322
# INFO:tensorflow:loss = 3.06846, step = 2001 (79.685 sec)
# INFO:tensorflow:global_step/sec: 7.76536
# INFO:tensorflow:loss = 3.14201, step = 2101 (13.003 sec)
# INFO:tensorflow:global_step/sec: 3.54724
# INFO:tensorflow:loss = 1.2584, step = 2201 (28.144 sec)
# INFO:tensorflow:global_step/sec: 3.37772
# INFO:tensorflow:loss = 5.27817, step = 2301 (29.688 sec)
# INFO:tensorflow:global_step/sec: 3.47151
# INFO:tensorflow:loss = 2.38293, step = 2401 (28.786 sec)
# INFO:tensorflow:global_step/sec: 3.36075
# INFO:tensorflow:loss = 1.20565, step = 2501 (29.818 sec)
# INFO:tensorflow:global_step/sec: 3.49232
# INFO:tensorflow:loss = 2.15188, step = 2601 (28.572 sec)
# INFO:tensorflow:global_step/sec: 3.40639
# INFO:tensorflow:loss = 3.07961, step = 2701 (29.372 sec)
# INFO:tensorflow:global_step/sec: 3.37833
# INFO:tensorflow:loss = 2.40061, step = 2801 (29.507 sec)
# INFO:tensorflow:global_step/sec: 3.4601
# INFO:tensorflow:loss = 2.74834, step = 2901 (28.917 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.58383.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-21:42:27
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-21:42:57
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.865646, accuracy_baseline = 0.839286, auc = 0.837072, auc_precision_recall = 0.954668, average_loss = 0.380737, global_step = 3000, label/mean = 0.839286, loss = 37.3122, prediction/mean = 0.787207
# Evaluation using Tensorflow evaluate method...Result at folding session: 3 {'auc_precision_recall': 0.95466799, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.78720707, 'average_loss': 0.38073701, 'auc': 0.83707243, 'accuracy': 0.86564624, 'loss': 37.312225, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp40z6yntp\model.ckpt-3000
#
# -----Folding Session 3 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.83856269064 Accuracy: 0.865646258503 Error_rate: 0.134353741497
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp8g4pzs0c'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c\model.ckpt.
# INFO:tensorflow:loss = 52.9173, step = 1
# INFO:tensorflow:global_step/sec: 8.87812
# INFO:tensorflow:loss = 2.98159, step = 101 (11.404 sec)
# INFO:tensorflow:global_step/sec: 3.55391
# INFO:tensorflow:loss = 2.69796, step = 201 (28.169 sec)
# INFO:tensorflow:global_step/sec: 3.51567
# INFO:tensorflow:loss = 3.67155, step = 301 (28.475 sec)
# INFO:tensorflow:global_step/sec: 3.39355
# INFO:tensorflow:loss = 3.03604, step = 401 (29.436 sec)
# INFO:tensorflow:global_step/sec: 3.3904
# INFO:tensorflow:loss = 6.18533, step = 501 (29.479 sec)
# INFO:tensorflow:global_step/sec: 3.38307
# INFO:tensorflow:loss = 4.57817, step = 601 (29.559 sec)
# INFO:tensorflow:global_step/sec: 3.48459
# INFO:tensorflow:loss = 6.04251, step = 701 (28.714 sec)
# INFO:tensorflow:global_step/sec: 3.55311
# INFO:tensorflow:loss = 3.59056, step = 801 (28.175 sec)
# INFO:tensorflow:global_step/sec: 3.35974
# INFO:tensorflow:loss = 4.54108, step = 901 (29.702 sec)
# INFO:tensorflow:global_step/sec: 3.39153
# INFO:tensorflow:loss = 4.82564, step = 1001 (29.485 sec)
# INFO:tensorflow:global_step/sec: 3.37522
# INFO:tensorflow:loss = 5.48455, step = 1101 (29.628 sec)
# INFO:tensorflow:global_step/sec: 3.46361
# INFO:tensorflow:loss = 2.90277, step = 1201 (28.919 sec)
# INFO:tensorflow:global_step/sec: 3.47727
# INFO:tensorflow:loss = 2.00542, step = 1301 (28.586 sec)
# INFO:tensorflow:global_step/sec: 3.48014
# INFO:tensorflow:loss = 1.6776, step = 1401 (28.859 sec)
# INFO:tensorflow:global_step/sec: 3.56236
# INFO:tensorflow:loss = 5.35279, step = 1501 (28.071 sec)
# INFO:tensorflow:global_step/sec: 3.29345
# INFO:tensorflow:loss = 3.60043, step = 1601 (30.316 sec)
# INFO:tensorflow:global_step/sec: 3.3714
# INFO:tensorflow:loss = 5.23252, step = 1701 (29.693 sec)
# INFO:tensorflow:global_step/sec: 3.50048
# INFO:tensorflow:loss = 3.68424, step = 1801 (28.661 sec)
# INFO:tensorflow:global_step/sec: 3.47516
# INFO:tensorflow:loss = 3.81338, step = 1901 (28.729 sec)
# INFO:tensorflow:Saving checkpoints for 1999 into C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.21137
# INFO:tensorflow:loss = 2.87973, step = 2001 (82.473 sec)
# INFO:tensorflow:global_step/sec: 10.3857
# INFO:tensorflow:loss = 7.2292, step = 2101 (9.691 sec)
# INFO:tensorflow:global_step/sec: 3.45474
# INFO:tensorflow:loss = 3.05993, step = 2201 (28.930 sec)
# INFO:tensorflow:global_step/sec: 3.34046
# INFO:tensorflow:loss = 2.73965, step = 2301 (29.936 sec)
# INFO:tensorflow:global_step/sec: 3.52622
# INFO:tensorflow:loss = 3.3451, step = 2401 (28.328 sec)
# INFO:tensorflow:global_step/sec: 3.54901
# INFO:tensorflow:loss = 2.95725, step = 2501 (28.208 sec)
# INFO:tensorflow:global_step/sec: 3.14131
# INFO:tensorflow:loss = 10.8188, step = 2601 (31.803 sec)
# INFO:tensorflow:global_step/sec: 3.05336
# INFO:tensorflow:loss = 7.44184, step = 2701 (32.798 sec)
# INFO:tensorflow:global_step/sec: 3.40437
# INFO:tensorflow:loss = 6.12508, step = 2801 (29.389 sec)
# INFO:tensorflow:global_step/sec: 3.43713
# INFO:tensorflow:loss = 2.69061, step = 2901 (29.094 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.86925.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-22:06:44
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-22:07:14
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.846939, accuracy_baseline = 0.839286, auc = 0.736431, auc_precision_recall = 0.922026, average_loss = 0.425669, global_step = 3000, label/mean = 0.839286, loss = 41.7156, prediction/mean = 0.831535
# Evaluation using Tensorflow evaluate method...Result at folding session: 4 {'auc_precision_recall': 0.92202568, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.83153522, 'average_loss': 0.42566893, 'auc': 0.73643076, 'accuracy': 0.84693879, 'loss': 41.715557, 'global_step': 3000}
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp8g4pzs0c\model.ckpt-3000
#
# -----Folding Session 4 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.735262111149 Accuracy: 0.84693877551 Error_rate: 0.15306122449
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmplo8tgkf8'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8\model.ckpt.
# INFO:tensorflow:loss = 2.64127, step = 1
# INFO:tensorflow:global_step/sec: 8.49818
# INFO:tensorflow:loss = 0.422178, step = 101 (11.986 sec)
# INFO:tensorflow:global_step/sec: 3.38767
# INFO:tensorflow:loss = 2.13465, step = 201 (29.441 sec)
# INFO:tensorflow:global_step/sec: 3.46876
# INFO:tensorflow:loss = 5.79973, step = 301 (28.907 sec)
# INFO:tensorflow:global_step/sec: 3.46397
# INFO:tensorflow:loss = 2.46757, step = 401 (28.822 sec)
# INFO:tensorflow:global_step/sec: 3.42224
# INFO:tensorflow:loss = 9.41782, step = 501 (29.205 sec)
# INFO:tensorflow:global_step/sec: 3.57719
# INFO:tensorflow:loss = 3.30754, step = 601 (27.986 sec)
# INFO:tensorflow:global_step/sec: 3.37828
# INFO:tensorflow:loss = 3.28251, step = 701 (29.601 sec)
# INFO:tensorflow:global_step/sec: 3.38929
# INFO:tensorflow:loss = 3.39387, step = 801 (29.598 sec)
# INFO:tensorflow:global_step/sec: 3.37822
# INFO:tensorflow:loss = 3.54919, step = 901 (29.414 sec)
# INFO:tensorflow:global_step/sec: 3.48942
# INFO:tensorflow:loss = 4.18073, step = 1001 (28.705 sec)
# INFO:tensorflow:global_step/sec: 3.56093
# INFO:tensorflow:loss = 2.02696, step = 1101 (28.114 sec)
# INFO:tensorflow:global_step/sec: 3.38101
# INFO:tensorflow:loss = 3.17994, step = 1201 (29.577 sec)
# INFO:tensorflow:global_step/sec: 3.48729
# INFO:tensorflow:loss = 3.00801, step = 1301 (28.707 sec)
# INFO:tensorflow:global_step/sec: 3.49479
# INFO:tensorflow:loss = 1.84469, step = 1401 (28.583 sec)
# INFO:tensorflow:global_step/sec: 3.48901
# INFO:tensorflow:loss = 4.60799, step = 1501 (28.568 sec)
# INFO:tensorflow:global_step/sec: 3.49354
# INFO:tensorflow:loss = 1.18761, step = 1601 (28.703 sec)
# INFO:tensorflow:global_step/sec: 3.38913
# INFO:tensorflow:loss = 6.84052, step = 1701 (29.506 sec)
# INFO:tensorflow:global_step/sec: 3.39322
# INFO:tensorflow:loss = 1.185, step = 1801 (29.502 sec)
# INFO:tensorflow:global_step/sec: 3.44847
# INFO:tensorflow:loss = 2.91134, step = 1901 (28.936 sec)
# INFO:tensorflow:global_step/sec: 3.45439
# INFO:tensorflow:loss = 3.49452, step = 2001 (28.839 sec)
# INFO:tensorflow:Saving checkpoints for 2017 into C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.50949
# INFO:tensorflow:loss = 4.7024, step = 2101 (66.372 sec)
# INFO:tensorflow:global_step/sec: 3.60923
# INFO:tensorflow:loss = 0.959542, step = 2201 (27.769 sec)
# INFO:tensorflow:global_step/sec: 3.30586
# INFO:tensorflow:loss = 1.35732, step = 2301 (30.187 sec)
# INFO:tensorflow:global_step/sec: 3.25256
# INFO:tensorflow:loss = 4.4918, step = 2401 (30.823 sec)
# INFO:tensorflow:global_step/sec: 3.19367
# INFO:tensorflow:loss = 2.84064, step = 2501 (120.814 sec)
# INFO:tensorflow:global_step/sec: 0.832565
# INFO:tensorflow:loss = 3.53245, step = 2601 (30.593 sec)
# INFO:tensorflow:global_step/sec: 3.24985
# INFO:tensorflow:loss = 3.14637, step = 2701 (30.724 sec)
# INFO:tensorflow:global_step/sec: 3.22981
# INFO:tensorflow:loss = 1.57452, step = 2801 (30.946 sec)
# INFO:tensorflow:global_step/sec: 3.19209
# INFO:tensorflow:loss = 1.07915, step = 2901 (31.374 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.97167.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-22:32:39
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-22:33:10
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.834674, auc_precision_recall = 0.954455, average_loss = 0.342619, global_step = 3000, label/mean = 0.839286, loss = 33.5767, prediction/mean = 0.811015
# Evaluation using Tensorflow evaluate method...Result at folding session: 5 {'auc_precision_recall': 0.95445508, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.81101543, 'average_loss': 0.34261924, 'auc': 0.83467358, 'accuracy': 0.86989796, 'loss': 33.576687, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmplo8tgkf8\model.ckpt-3000
#
# -----Folding Session 5 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.835539259045 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp_1fj5t56'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56\model.ckpt.
# INFO:tensorflow:loss = 1.88188, step = 1
# INFO:tensorflow:global_step/sec: 8.91202
# INFO:tensorflow:loss = 85.4054, step = 101 (11.299 sec)
# INFO:tensorflow:global_step/sec: 3.24973
# INFO:tensorflow:loss = 7.67797, step = 201 (30.772 sec)
# INFO:tensorflow:global_step/sec: 3.20458
# INFO:tensorflow:loss = 5.37056, step = 301 (31.362 sec)
# INFO:tensorflow:global_step/sec: 2.76125
# INFO:tensorflow:loss = 2.64647, step = 401 (36.090 sec)
# INFO:tensorflow:global_step/sec: 2.16816
# INFO:tensorflow:loss = 5.23901, step = 501 (46.185 sec)
# INFO:tensorflow:global_step/sec: 2.27042
# INFO:tensorflow:loss = 48.1823, step = 601 (43.998 sec)
# INFO:tensorflow:global_step/sec: 2.47164
# INFO:tensorflow:loss = 1.59193, step = 701 (40.428 sec)
# INFO:tensorflow:global_step/sec: 2.12512
# INFO:tensorflow:loss = 4.86159, step = 801 (47.025 sec)
# INFO:tensorflow:global_step/sec: 2.93987
# INFO:tensorflow:loss = 5.59623, step = 901 (34.140 sec)
# INFO:tensorflow:global_step/sec: 2.5435
# INFO:tensorflow:loss = 1.07707, step = 1001 (39.285 sec)
# INFO:tensorflow:global_step/sec: 1.97572
# INFO:tensorflow:loss = 5.34237, step = 1101 (50.521 sec)
# INFO:tensorflow:global_step/sec: 2.83658
# INFO:tensorflow:loss = 4.22055, step = 1201 (35.363 sec)
# INFO:tensorflow:global_step/sec: 3.21546
# INFO:tensorflow:loss = 1.58891, step = 1301 (30.990 sec)
# INFO:tensorflow:global_step/sec: 3.07127
# INFO:tensorflow:loss = 5.81485, step = 1401 (32.622 sec)
# INFO:tensorflow:global_step/sec: 3.34134
# INFO:tensorflow:loss = 2.71165, step = 1501 (29.881 sec)
# INFO:tensorflow:Saving checkpoints for 1568 into C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.20841
# INFO:tensorflow:loss = 8.10214, step = 1601 (82.784 sec)
# INFO:tensorflow:global_step/sec: 5.08829
# INFO:tensorflow:loss = 4.51454, step = 1701 (19.684 sec)
# INFO:tensorflow:global_step/sec: 3.23541
# INFO:tensorflow:loss = 3.52684, step = 1801 (30.955 sec)
# INFO:tensorflow:global_step/sec: 3.00273
# INFO:tensorflow:loss = 4.24495, step = 1901 (33.256 sec)
# INFO:tensorflow:global_step/sec: 3.06816
# INFO:tensorflow:loss = 3.01967, step = 2001 (32.593 sec)
# INFO:tensorflow:global_step/sec: 2.87858
# INFO:tensorflow:loss = 4.67855, step = 2101 (34.646 sec)
# INFO:tensorflow:global_step/sec: 3.13204
# INFO:tensorflow:loss = 1.28112, step = 2201 (32.069 sec)
# INFO:tensorflow:global_step/sec: 2.91571
# INFO:tensorflow:loss = 1.11499, step = 2301 (34.172 sec)
# INFO:tensorflow:global_step/sec: 3.05368
# INFO:tensorflow:loss = 4.05161, step = 2401 (32.763 sec)
# INFO:tensorflow:global_step/sec: 2.92004
# INFO:tensorflow:loss = 3.5761, step = 2501 (34.184 sec)
# INFO:tensorflow:global_step/sec: 3.09964
# INFO:tensorflow:loss = 4.58638, step = 2601 (32.371 sec)
# INFO:tensorflow:global_step/sec: 3.18647
# INFO:tensorflow:loss = 3.3232, step = 2701 (31.367 sec)
# INFO:tensorflow:global_step/sec: 2.98592
# INFO:tensorflow:loss = 6.27304, step = 2801 (33.522 sec)
# INFO:tensorflow:global_step/sec: 2.96121
# INFO:tensorflow:loss = 4.27726, step = 2901 (33.739 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.98841.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-23:00:23
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-23:00:54
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.872449, accuracy_baseline = 0.839286, auc = 0.834931, auc_precision_recall = 0.957289, average_loss = 0.384538, global_step = 3000, label/mean = 0.839286, loss = 37.6847, prediction/mean = 0.856025
# Evaluation using Tensorflow evaluate method...Result at folding session: 6 {'auc_precision_recall': 0.95728874, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.85602462, 'average_loss': 0.38453752, 'auc': 0.83493078, 'accuracy': 0.87244898, 'loss': 37.684677, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_1fj5t56\model.ckpt-3000
#
# -----Folding Session 6 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.834627941011 Accuracy: 0.872448979592 Error_rate: 0.127551020408
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp6ik310ra'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt.
# INFO:tensorflow:loss = 7.18584, step = 1
# INFO:tensorflow:global_step/sec: 7.74556
# INFO:tensorflow:loss = 4.1705, step = 101 (13.114 sec)
# INFO:tensorflow:global_step/sec: 2.78678
# INFO:tensorflow:loss = 4.74109, step = 201 (35.852 sec)
# INFO:tensorflow:global_step/sec: 3.11446
# INFO:tensorflow:loss = 5.39163, step = 301 (32.124 sec)
# INFO:tensorflow:global_step/sec: 2.77487
# INFO:tensorflow:loss = 2.33802, step = 401 (36.006 sec)
# INFO:tensorflow:global_step/sec: 3.35164
# INFO:tensorflow:loss = 12.2536, step = 501 (29.820 sec)
# INFO:tensorflow:global_step/sec: 2.91891
# INFO:tensorflow:loss = 2.71157, step = 601 (34.259 sec)
# INFO:tensorflow:global_step/sec: 3.14283
# INFO:tensorflow:loss = 2.26137, step = 701 (31.990 sec)
# INFO:tensorflow:global_step/sec: 3.17807
# INFO:tensorflow:loss = 3.3411, step = 801 (31.278 sec)
# INFO:tensorflow:global_step/sec: 3.26535
# INFO:tensorflow:loss = 2.78647, step = 901 (30.640 sec)
# INFO:tensorflow:global_step/sec: 3.37676
# INFO:tensorflow:loss = 5.75377, step = 1001 (29.646 sec)
# INFO:tensorflow:global_step/sec: 3.05279
# INFO:tensorflow:loss = 7.35983, step = 1101 (32.741 sec)
# INFO:tensorflow:global_step/sec: 2.94131
# INFO:tensorflow:loss = 5.63717, step = 1201 (33.998 sec)
# INFO:tensorflow:global_step/sec: 3.20133
# INFO:tensorflow:loss = 3.36373, step = 1301 (31.190 sec)
# INFO:tensorflow:global_step/sec: 3.09525
# INFO:tensorflow:loss = 4.172, step = 1401 (32.390 sec)
# INFO:tensorflow:global_step/sec: 2.57397
# INFO:tensorflow:loss = 2.89089, step = 1501 (38.877 sec)
# INFO:tensorflow:global_step/sec: 3.07418
# INFO:tensorflow:loss = 2.702, step = 1601 (33.311 sec)
# INFO:tensorflow:global_step/sec: 3.26685
# INFO:tensorflow:loss = 12.3168, step = 1701 (29.797 sec)
# INFO:tensorflow:Saving checkpoints for 1771 into C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.22201
# INFO:tensorflow:loss = 5.78129, step = 1801 (81.645 sec)
# INFO:tensorflow:global_step/sec: 5.77938
# INFO:tensorflow:loss = 2.10892, step = 1901 (17.475 sec)
# INFO:tensorflow:global_step/sec: 3.30563
# INFO:tensorflow:loss = 1.81563, step = 2001 (30.251 sec)
# INFO:tensorflow:global_step/sec: 3.3863
# INFO:tensorflow:loss = 6.67001, step = 2101 (29.546 sec)
# INFO:tensorflow:global_step/sec: 3.26587
# INFO:tensorflow:loss = 4.38689, step = 2201 (30.604 sec)
# INFO:tensorflow:global_step/sec: 3.2651
# INFO:tensorflow:loss = 4.76305, step = 2301 (30.502 sec)
# INFO:tensorflow:global_step/sec: 3.25846
# INFO:tensorflow:loss = 1.89764, step = 2401 (30.767 sec)
# INFO:tensorflow:global_step/sec: 3.06773
# INFO:tensorflow:loss = 3.58881, step = 2501 (32.597 sec)
# INFO:tensorflow:global_step/sec: 3.22731
# INFO:tensorflow:loss = 5.10802, step = 2601 (31.001 sec)
# INFO:tensorflow:global_step/sec: 3.21911
# INFO:tensorflow:loss = 10.6557, step = 2701 (31.127 sec)
# INFO:tensorflow:global_step/sec: 3.35877
# INFO:tensorflow:loss = 2.12808, step = 2801 (29.742 sec)
# INFO:tensorflow:global_step/sec: 3.14197
# INFO:tensorflow:loss = 1.5984, step = 2901 (31.874 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.08136.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-23:27:26
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-23:27:59
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.868197, accuracy_baseline = 0.839286, auc = 0.839796, auc_precision_recall = 0.95862, average_loss = 0.345328, global_step = 3000, label/mean = 0.839286, loss = 33.8422, prediction/mean = 0.819132
# Evaluation using Tensorflow evaluate method...Result at folding session: 7 {'auc_precision_recall': 0.95862019, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.81913161, 'average_loss': 0.34532833, 'auc': 0.83979565, 'accuracy': 0.86819726, 'loss': 33.842175, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt-3000
#
# -----Folding Session 7 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.841060774191 Accuracy: 0.868197278912 Error_rate: 0.131802721088
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp114c01f9
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp114c01f9'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp114c01f9\model.ckpt.
# INFO:tensorflow:loss = 1.88465, step = 1
# INFO:tensorflow:global_step/sec: 7.27832
# INFO:tensorflow:loss = 100.449, step = 101 (13.786 sec)
# INFO:tensorflow:global_step/sec: 2.93273
# INFO:tensorflow:loss = 2.97286, step = 201 (34.160 sec)
# INFO:tensorflow:global_step/sec: 2.90376
# INFO:tensorflow:loss = 1.19442, step = 301 (34.515 sec)
# INFO:tensorflow:global_step/sec: 2.70285
# INFO:tensorflow:loss = 2.83765, step = 401 (36.827 sec)
# INFO:tensorflow:global_step/sec: 3.10079
# INFO:tensorflow:loss = 4.54325, step = 501 (32.390 sec)
# INFO:tensorflow:global_step/sec: 3.13169
# INFO:tensorflow:loss = 2.91638, step = 601 (31.900 sec)
# INFO:tensorflow:global_step/sec: 3.27581
# INFO:tensorflow:loss = 4.05826, step = 701 (30.621 sec)
# INFO:tensorflow:global_step/sec: 3.40639
# INFO:tensorflow:loss = 4.62475, step = 801 (29.278 sec)
# INFO:tensorflow:global_step/sec: 3.28386
# INFO:tensorflow:loss = 3.9314, step = 901 (30.483 sec)
# INFO:tensorflow:global_step/sec: 3.37007
# INFO:tensorflow:loss = 5.2274, step = 1001 (29.657 sec)
# INFO:tensorflow:global_step/sec: 3.30054
# INFO:tensorflow:loss = 2.68289, step = 1101 (30.220 sec)
# INFO:tensorflow:global_step/sec: 2.85855
# INFO:tensorflow:loss = 2.94782, step = 1201 (35.129 sec)
# INFO:tensorflow:global_step/sec: 2.86769
# INFO:tensorflow:loss = 1.18268, step = 1301 (34.788 sec)
# INFO:tensorflow:global_step/sec: 3.40549
# INFO:tensorflow:loss = 3.96613, step = 1401 (29.286 sec)
# INFO:tensorflow:global_step/sec: 3.12406
# INFO:tensorflow:loss = 2.72246, step = 1501 (32.072 sec)
# INFO:tensorflow:global_step/sec: 3.45003
# INFO:tensorflow:loss = 4.5228, step = 1601 (29.063 sec)
# INFO:tensorflow:global_step/sec: 3.56244
# INFO:tensorflow:loss = 3.64559, step = 1701 (28.008 sec)
# INFO:tensorflow:global_step/sec: 3.32157
# INFO:tensorflow:loss = 1.34753, step = 1801 (30.106 sec)
# INFO:tensorflow:Saving checkpoints for 1826 into C:\Users\ASR\AppData\Local\Temp\tmp114c01f9\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.4819
# INFO:tensorflow:loss = 3.21689, step = 1901 (67.387 sec)
# INFO:tensorflow:global_step/sec: 3.37471
# INFO:tensorflow:loss = 4.88503, step = 2001 (29.726 sec)
# INFO:tensorflow:global_step/sec: 3.40915
# INFO:tensorflow:loss = 1.35288, step = 2101 (29.192 sec)
# INFO:tensorflow:global_step/sec: 3.17409
# INFO:tensorflow:loss = 2.58423, step = 2201 (31.661 sec)
# INFO:tensorflow:global_step/sec: 3.45861
# INFO:tensorflow:loss = 3.87313, step = 2301 (28.851 sec)
# INFO:tensorflow:global_step/sec: 3.14532
# INFO:tensorflow:loss = 4.97058, step = 2401 (31.934 sec)
# INFO:tensorflow:global_step/sec: 3.30195
# INFO:tensorflow:loss = 2.1314, step = 2501 (30.191 sec)
# INFO:tensorflow:global_step/sec: 3.44339
# INFO:tensorflow:loss = 1.52819, step = 2601 (29.088 sec)
# INFO:tensorflow:global_step/sec: 3.45182
# INFO:tensorflow:loss = 6.1743, step = 2701 (28.908 sec)
# INFO:tensorflow:global_step/sec: 3.44909
# INFO:tensorflow:loss = 3.088, step = 2801 (29.024 sec)
# INFO:tensorflow:global_step/sec: 3.37042
# INFO:tensorflow:loss = 0.870179, step = 2901 (29.576 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp114c01f9\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.64886.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-23:53:33
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp114c01f9\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-23:54:03
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.863946, accuracy_baseline = 0.839286, auc = 0.832982, auc_precision_recall = 0.954879, average_loss = 0.357519, global_step = 3000, label/mean = 0.839286, loss = 35.0368, prediction/mean = 0.809706
# Evaluation using Tensorflow evaluate method...Result at folding session: 8 {'auc_precision_recall': 0.95487946, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.80970615, 'average_loss': 0.3575187, 'auc': 0.83298218, 'accuracy': 0.8639456, 'loss': 35.036831, 'global_step': 3000}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp114c01f9\model.ckpt-3000
#
# -----Folding Session 8 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.833502195204 Accuracy: 0.863945578231 Error_rate: 0.136054421769
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_tf_random_seed': 1, '_save_summary_steps': 100, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpt_7vtynf'}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf\model.ckpt.
# INFO:tensorflow:loss = 3.79535, step = 1
# INFO:tensorflow:global_step/sec: 8.5339
# INFO:tensorflow:loss = 2.74534, step = 101 (11.890 sec)
# INFO:tensorflow:global_step/sec: 3.37701
# INFO:tensorflow:loss = 4.2058, step = 201 (29.549 sec)
# INFO:tensorflow:global_step/sec: 3.41849
# INFO:tensorflow:loss = 3.56316, step = 301 (29.284 sec)
# INFO:tensorflow:global_step/sec: 3.45375
# INFO:tensorflow:loss = 4.13575, step = 401 (28.954 sec)
# INFO:tensorflow:global_step/sec: 3.4259
# INFO:tensorflow:loss = 1.51598, step = 501 (29.174 sec)
# INFO:tensorflow:global_step/sec: 3.2941
# INFO:tensorflow:loss = 3.7512, step = 601 (30.420 sec)
# INFO:tensorflow:global_step/sec: 3.24174
# INFO:tensorflow:loss = 4.05713, step = 701 (30.801 sec)
# INFO:tensorflow:global_step/sec: 3.14179
# INFO:tensorflow:loss = 2.62234, step = 801 (31.876 sec)
# INFO:tensorflow:global_step/sec: 3.3106
# INFO:tensorflow:loss = 2.47533, step = 901 (30.175 sec)
# INFO:tensorflow:global_step/sec: 3.42287
# INFO:tensorflow:loss = 1.98987, step = 1001 (29.232 sec)
# INFO:tensorflow:global_step/sec: 3.3525
# INFO:tensorflow:loss = 2.79154, step = 1101 (29.687 sec)
# INFO:tensorflow:global_step/sec: 3.46832
# INFO:tensorflow:loss = 4.67383, step = 1201 (28.973 sec)
# INFO:tensorflow:global_step/sec: 3.48041
# INFO:tensorflow:loss = 3.97604, step = 1301 (28.748 sec)
# INFO:tensorflow:global_step/sec: 3.24678
# INFO:tensorflow:loss = 4.84503, step = 1401 (30.778 sec)
# INFO:tensorflow:global_step/sec: 3.32144
# INFO:tensorflow:loss = 4.38539, step = 1501 (30.005 sec)
# INFO:tensorflow:global_step/sec: 3.46267
# INFO:tensorflow:loss = 2.5915, step = 1601 (28.972 sec)
# INFO:tensorflow:global_step/sec: 3.54482
# INFO:tensorflow:loss = 1.57057, step = 1701 (28.210 sec)
# INFO:tensorflow:global_step/sec: 3.33021
# INFO:tensorflow:loss = 5.35993, step = 1801 (30.078 sec)
# INFO:tensorflow:global_step/sec: 3.28457
# INFO:tensorflow:loss = 1.54122, step = 1901 (30.364 sec)
# INFO:tensorflow:Saving checkpoints for 1960 into C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.3185
# INFO:tensorflow:loss = 1.95358, step = 2001 (75.781 sec)
# INFO:tensorflow:global_step/sec: 5.35844
# INFO:tensorflow:loss = 2.08987, step = 2101 (18.772 sec)
# INFO:tensorflow:global_step/sec: 3.27194
# INFO:tensorflow:loss = 4.59777, step = 2201 (30.469 sec)
# INFO:tensorflow:global_step/sec: 3.31005
# INFO:tensorflow:loss = 8.30087, step = 2301 (30.258 sec)
# INFO:tensorflow:global_step/sec: 3.40027
# INFO:tensorflow:loss = 2.18079, step = 2401 (29.456 sec)
# INFO:tensorflow:global_step/sec: 3.24468
# INFO:tensorflow:loss = 9.14922, step = 2501 (30.648 sec)
# INFO:tensorflow:global_step/sec: 3.31461
# INFO:tensorflow:loss = 4.9823, step = 2601 (30.169 sec)
# INFO:tensorflow:global_step/sec: 3.33243
# INFO:tensorflow:loss = 4.58058, step = 2701 (30.133 sec)
# INFO:tensorflow:global_step/sec: 3.33338
# INFO:tensorflow:loss = 7.99346, step = 2801 (30.000 sec)
# INFO:tensorflow:global_step/sec: 3.43433
# INFO:tensorflow:loss = 4.00287, step = 2901 (29.165 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.56348.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-20-00:18:05
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-20-00:18:35
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.863095, accuracy_baseline = 0.839286, auc = 0.804836, auc_precision_recall = 0.936208, average_loss = 0.392423, global_step = 3000, label/mean = 0.839286, loss = 38.4575, prediction/mean = 0.772278
# Evaluation using Tensorflow evaluate method...Result at folding session: 9 {'auc_precision_recall': 0.93620813, 'accuracy_baseline': 0.83928573, 'label/mean': 0.83928573, 'prediction/mean': 0.77227795, 'average_loss': 0.392423, 'auc': 0.80483586, 'accuracy': 0.86309522, 'loss': 38.457455, 'global_step': 3000}
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpt_7vtynf\model.ckpt-3000
#
# -----Folding Session 9 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.804742070193 Accuracy: 0.863095238095 Error_rate: 0.136904761905
#
# -----k-fold summary:-----
# Evaluation Errors: [0.16241496598639457, 0.13860544217687074, 0.13350340136054423, 0.13435374149659865, 0.15306122448979592, 0.13010204081632654, 0.12755102040816327, 0.13180272108843538, 0.1360544217687075, 0.13690476190476192]
# Evaluation error rate average: 0.13843537415
# Model's standard deviation: 0.0103434361902
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp6ik310ra\model.ckpt-3000
#
# Final Test>> AUC: 0.790339652639 Accuracy: 0.859863945578 Final Error_rate: 0.140136054422
# F-measure: 0.922117202268 Accuracy: 0.859863945578 Recall: 0.988249594814 Precision: 0.86428065202 False Positive Rate: 0.811440677966 False Negative Rate: 0.0117504051864
# Confusion matrix, without normalization
# [[  89  383]
#  [  29 2439]]
# Normalized confusion matrix
# [[ 0.19  0.81]
#  [ 0.01  0.99]]
