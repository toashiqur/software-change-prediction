# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import metrics

# %%
# %matplotlib inline

# %%
data_source_path = "F:\deep lerning project\data\FinalData\d4.wordpress_phpbb23.label_appearance_density.csv"

#test_output_file = open("F:\\deep lerning project\\data\\FinalData\\hidden_layer_test_output.txt", mode = 'w')# for testing layers...delete if not needed
# for slicing the necessary columns from the source file...directly related to source data columns
label_col_start = 0
feature_col_start = 8

# I have many labels but here is the col that contains 'changed_ever_class'
class_label_col = 2 # class is in col 2

# %%
# Some configurations
# set only one to true...
select_model_based_on_loss = False
select_model_based_on_error_rate = False
select_model_based_on_auc = True
#---------------------------------

# %%
def get_feature_and_label():
    # read the data file
    # return features and labels
    
    file_change_df = pd.read_csv(data_source_path)
    
    X = file_change_df.iloc[:,feature_col_start:]
    #print(X.shape)
    #print(X)
    
    y_all_labels = file_change_df.iloc[:,label_col_start:feature_col_start] # all available labels 
    #print(type(y_all_labels))
    #print(y_all_labels)
    y = y_all_labels.iloc[:,class_label_col] # take the changed_ever col only
    y = pd.Series.to_frame(y) # y is a series...convert it to dataframe again--- not necessary...series will do
    #print(y.head())
    #print(type(y))
    
    #print(y.shape)
    #print(y)
    
    return X, y

# %%
def get_train_test_split(X, y, nsplits = 1, testSize = 0.2):

    sss = StratifiedShuffleSplit(n_splits=nsplits, test_size=testSize)
    
    for train_index, test_index in sss.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index] # X.iloc[index] because its pandas dataframe.so..iloc
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    return X_train, y_train, X_test, y_test

# %%
def show_data_statistics(X_train, y_train, X_test, y_test):
    #print(X_train.shape)
    #print(y_train.shape)
    #print(X_test.shape)
    #print(y_test.shape)
    #print(type(y_test))
    print("y_train Statistics:\n", y_train.describe())
    print("y_test Statistics:\n",y_test.describe())
    
    plt.hist(y_train)
    plt.hist(y_test)

# %%
def get_feature_cols(X):
    feature_cols = []
    i=0

    for col in X.columns:
        #if is_numeric_dtype(X[col]): #is_numeric_dtype is pandas function
        feature_cols.extend([tf.feature_column.numeric_column(col)])
        i = i+1
        
    print("Total features column names converted to tf.feature_column.numeric_column('col_name') = ", i)
    return feature_cols

# %%
def train_model(model, X_train, y_train):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        batch_size=10,
        num_epochs=3000,
        shuffle=True)    
    
    model = model.train(input_fn=input_func,steps=3000)
    
    return model

# %%
def evaluate_model(model, X_test, y_test):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    results = model.evaluate(input_func)
    #print(results)
    
    return results

# %%
def prediction(model, X, y):
    
    prediction_list = []
    y_proba_positive_class_list = [] # positive class probability of each element for calculating AUC
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    y_predicted = model.predict(input_func)
    
    for elem in y_predicted: # y_predicted is a generator object holds a memory address...read all values from there
        #print("type elem:", type(elem))
        #print("elem:", elem)
        elem_probabilities = np.array(elem['probabilities'])
        #print("Elem probabilities of each class:", elem_probabilities)
        
        y_proba_positive_class_list.append(elem_probabilities[1]) # class 1 is the positive class, its index is 1
        #print("prob_list_now:", elem_positive_class_proba_list)
        
        elem_class = np.argmax(elem_probabilities) # one probable class based on the index that contain max value
        #print("probable class:",elem_class)
        
        prediction_list.append(elem_class)
        
    
    # assign prediction list to y_predicted for consistent name
    y_predicted = np.array(prediction_list)
    
    #print("y_predicted_shape:", y_predicted.shape, "val:", y_predicted)
    #print("y_type:", type(y),"y shape:", y.shape, "val:", y)
    
    #error_rate = sum(y_predicted != np.array(y)/len(y_predicted))
    
    #print(list(y_predicted))
    
    y = np.array(y) # convert y data to np array
    r,c = y.shape
    #print("y- r,c:",r,c)
    y = y.reshape(r) # change the shape of y to numpy [row,]
    #print("y-shape:", y.shape)
    
    
    '''
    print("before converting to list y_predicted:", y_predicted)
    
    y_predicted = list(y_predicted)
    print("y_predicted:", y_predicted)
    
    y_predicted = np.array(y_predicted)
    print("after converting to nparray y_predicted:", y_predicted, "shape:", y_predicted.shape)
    
    y= np.array(y)
    r,c = y.shape
    print("y- r,c:",r,c)
    y = y.reshape(r)
    print("y-shape:", y.shape)
    '''
    
    error_rate = sum(y_predicted != y)/len(y_predicted) # sum needs the operands in np array of shape [row,]
    
    return y_predicted, error_rate, y_proba_positive_class_list

# %%
def get_normalized_train_data(X_train):
    #Unused function---Normalization is done separately
    #print(type(X_train))
    #print(X_train.head())
    saved_cols = X_train.columns # save the columns names..scaling change the pandas frame to numpy..need to restore
    saved_index = list(X_train.index) # # scaling changes pandas X indices..need to restore to match with y data indices
    #print("saved_index", saved_index)
    
    min_max_scaler = preprocessing.MinMaxScaler()
    
    scaled_X_train = min_max_scaler.fit_transform(X_train)
    scaled_X_train = pd.DataFrame(scaled_X_train, index=saved_index, columns=saved_cols)# restore the column names

    #print(scaled_X_train.head())
    return scaled_X_train

# %%
def get_random_sample(X, y, n_sample = 1):
    n = np.arange(X.shape[0]) # generate numbers equal to the max no of rows in the X df
    if n_sample>len(n):
        print("You have asked", n_sample, " samples, but the training data has", len(n), " rows. Returning 1 sample...")
        n_sample = 1
        
    np.random.shuffle(n) # shuffle all the numbers representing row index
    index = n[0:n_sample] # take the numbers from 0 to given sample
    
    X_sample = X.iloc[index]
    y_sample = y.iloc[index]
    
    #print(X_sample.head())
    #print(y_sample.head())
    
    return X_sample, y_sample

# %%
def show_evaluation_error_report(eval_error_rates):
    
    eval_error_rate_avg = sum(eval_error_rates)/len(eval_error_rates)
    model_std = np.std(eval_error_rates)
    
    print("Evaluation Errors:", eval_error_rates)
    print('Evaluation error rate average:', eval_error_rate_avg, '\nModel\'s standard deviation:', model_std)

# %%
def calculate_performance_metrics(cnf_matrix):
    
    TP = cnf_matrix[1,1]
    TN = cnf_matrix[0,0]
    FP = cnf_matrix[0,1]
    FN = cnf_matrix[1,0]
    
    
    # Sensitivity, hit rate, recall, or true positive rate
    TPR_recall = TP/(TP+FN) # Recall
    # Specificity or true negative rate
    TNR = TN/(TN+FP) # **
    # Precision or positive predictive value
    PPV_precision = TP/(TP+FP) # precision
    # Negative predictive value
    NPV = TN/(TN+FN) #**
    # Fall out or false positive rate
    FPR_false_positive = FP/(FP+TN)
    # False negative rate
    FNR_false_negative = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP) # **

    # Overall accuracy
    accuracy = (TP+TN)/(TP+FP+FN+TN)
    f_measure = 2/((1.0/TPR_recall) + (1.0/PPV_precision)) #https://en.wikipedia.org/wiki/F1_score
    
    # ** some extra values are calculated but not returned
    return TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def get_roc_auc(y, y_proba_positive_class_list):
    
    y = y.as_matrix() # convert series data to numpy array
    
    auc = metrics.roc_auc_score(y, y_proba_positive_class_list)
    #print("Auc:", auc)
    
    '''
    #This one also works but not needed
    fpr, tpr, thresholds = metrics.roc_curve(y, elem_positive_class_proba_list)
    auc2 = metrics.auc(fpr, tpr)
    print("AUC2:", auc2, "fpr:", fpr, "tpr:", tpr)
    '''
    return auc

# %%
def get_cnf_matrix_prf_metrics(y, y_predicted):
    
    y = y.values.tolist() # convert pandas data to list
    #print(">>>>>type_y:", type(y), "val:", y)
    
    y = list(np.array(y).flat) # when converted to list panda gives [[values], [values]]...convert them to flat list[]
    #print("----------type_y_f:", type(y), "val:", y)
    
    
    y_predicted = list(y_predicted)
    #print(">>>>>>type_y_predicted:", type(y_predicted), "val:", y_predicted)
    
    cnf_matrix = confusion_matrix(y, y_predicted)
    
    #print("conf matrix:", cnf_matrix)
    # Calculate performane metrics
    TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = calculate_performance_metrics(cnf_matrix)
    
    return cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def show_confusion_matrix(cnf_matrix, class_names):
    # show cmap of confusion metrics
    np.set_printoptions(precision=2) # settings for printing floating point values
    
    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def main():
    
    X, y = get_feature_and_label()
    X_train_0, y_train_0, X_test_final, y_test_final = get_train_test_split(X,y) #get_train_test_split(X, y, nsplits = 1, testSize = 0.2)

    #show_data_statistics("---Train-Test Statistics---",X_train, y_train, X_test, y_test)
    #print(type(X))
    feature_cols = get_feature_cols(X_train_0)
    #print(feature_cols)

    # start k-fold cross validation and find the best model with the minimum loss during evaluation
    
    min_loss = float('inf')
    min_error_rate = float("inf")
    max_auc = float("-inf")

    folding_session = 0
    eval_error_rates = []
    
    sss = StratifiedShuffleSplit(n_splits=10) #stratifiedkfold generates error for y_train_0 and doesn't work if y multi-labe
    
    for train_index, eval_index in sss.split(X_train_0, y_train_0):

        X_train, X_eval = X_train_0.iloc[train_index], X_train_0.iloc[eval_index]  # iloc[index] because X is a pandas dataframe
        y_train, y_eval = y_train_0.iloc[train_index], y_train_0.iloc[eval_index]
        

        #X_train = get_normalized_train_data(X_train) # min-max standardization
        #print(X_train.head())
        
        # Add layers in this list if more layer settings are needed
        hidden_layers_units = [
            [1022, 511, 255, 128]
        ]
        
        for my_hidden_units in hidden_layers_units:
            print("Hidden Settings:", my_hidden_units)
            #create a new estimator model

            file_change_prediction_model = tf.estimator.DNNClassifier(
                                                                    hidden_units = my_hidden_units,
                                                                    feature_columns = feature_cols, 
                                                                    n_classes=2, 
                                                                    activation_fn = tf.nn.relu)

            #print("new:", file_change_prediction_model)    

            #train the model
            file_change_prediction_model = train_model(file_change_prediction_model, X_train, y_train)
            #print("ret:", file_change_prediction_model)

            #evaluate the trained model
            evaluation_res = evaluate_model(file_change_prediction_model, X_eval, y_eval)
            print("Evaluation using Tensorflow evaluate method...Result at folding session:", folding_session, evaluation_res,"\n\n")
            
            # Do my own evaluation using the trained model in this folding session using evaluation data
            y_predicted, error_rate, y_proba_positive_class_list = prediction(file_change_prediction_model, X_eval, y_eval)
            eval_error_rates.append(error_rate) # error_rate of current folding session
            
            # calculate auc
            auc_evaluation = get_roc_auc(y_eval, y_proba_positive_class_list)

            #----
            #print("\nHidden Settings:", my_hidden_units, file=test_output_file)
            #print('\nFolding Session', folding_session,"AUC:",auc_validation,"Accuracy:", 1-error_rate, 'Error_rate:', error_rate, file=test_output_file)
            print('\n-----Folding Session', folding_session, "Hidden Settings:", my_hidden_units, "-----\nAUC:",auc_evaluation, "Accuracy:", 1-error_rate, 'Error_rate:', error_rate)
    
            #----
            #select the best model using the tensorflow evaluation result
            if select_model_based_on_loss:
                if evaluation_res['loss'] < min_loss:
                    best_model = file_change_prediction_model
                    min_loss = evaluation_res['loss']
                    print("Selecting model based on min_loss.")
    
            # select the best model based on calculated error rate
            if select_model_based_on_error_rate:
                if error_rate < min_error_rate:
                    best_model = file_change_prediction_model # save the best model
                    min_error_rate = error_rate # update the min_error_rate
                    print("Selecting model based on min_error_rate.")
                
            if select_model_based_on_auc:
                if auc_evaluation > max_auc:
                    best_model = file_change_prediction_model # save the best model
                    max_auc = auc_evaluation # update the max_auc
                    print("Selecting model based on max_auc.")

            #Take the next fold in the loop
        folding_session = folding_session + 1
        #break # remove it later for k-fold...now just one fold    
    
    #============================================
    
    print("\n-----k-fold summary:-----")
    k_fold_eval_error_rates = eval_error_rates # for naming consistency with other models
    show_evaluation_error_report(k_fold_eval_error_rates) 
    
    # see the evaluation result using the best model and some random sample from the used training data
    #X_eval, y_eval = get_random_sample(X_train_0,y_train_0, n_sample = 1000)
    #test_res = evaluate_model(best_model, X_eval, y_eval)
    #print("A random evaluation of the model:\n", test_res)
    
    # Do final test using tensorflow function
    #test_res = evaluate_model(best_model, X_test_final, y_test_final)
    #print("Final performance with the best model and test data:", test_res)
    
    #Everything finished I have got the best model and now want to get the final evaluation in my format
    #----------------------------------------------------------------------------------------------------
    #predict using the best model
    y_predicted, error_rate, y_proba_positive_class_list = prediction(best_model, X_test_final, y_test_final)
    #print("shape of x test final:", X_test_final)
    
    # calculate auc
    auc_final = get_roc_auc(y_test_final, y_proba_positive_class_list)
    print("\nFinal Test>> AUC:", auc_final, "Accuracy:", 1-error_rate, "Final Error_rate:", error_rate)
    
    cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = get_cnf_matrix_prf_metrics(y_test_final, y_predicted)
    print("F-measure:", f_measure, "Accuracy:",accuracy, "Recall:", TPR_recall, "Precision:", PPV_precision, "False Positive Rate:", FPR_false_positive, "False Negative Rate:", FNR_false_negative)
    
    class_names = ['0','1'] # class names in order.. 1st index for class whose label is 0, 2nd index for class whose label is 1......
    show_confusion_matrix(cnf_matrix, class_names)

# %%
main()
# Out:
# Total features column names converted to tf.feature_column.numeric_column('col_name') =  2042
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpe1sbiq0o', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt.
# INFO:tensorflow:loss = 3.13767, step = 1
# INFO:tensorflow:global_step/sec: 4.54014
# INFO:tensorflow:loss = 0.586898, step = 101 (22.245 sec)
# INFO:tensorflow:global_step/sec: 1.63942
# INFO:tensorflow:loss = 2.92898, step = 201 (60.872 sec)
# INFO:tensorflow:global_step/sec: 1.68948
# INFO:tensorflow:loss = 3.57399, step = 301 (59.237 sec)
# INFO:tensorflow:global_step/sec: 1.65174
# INFO:tensorflow:loss = 78.1102, step = 401 (60.574 sec)
# INFO:tensorflow:global_step/sec: 1.69513
# INFO:tensorflow:loss = 2.37276, step = 501 (59.008 sec)
# INFO:tensorflow:global_step/sec: 1.68506
# INFO:tensorflow:loss = 2.98076, step = 601 (59.361 sec)
# INFO:tensorflow:global_step/sec: 1.64003
# INFO:tensorflow:loss = 2.86563, step = 701 (60.927 sec)
# INFO:tensorflow:global_step/sec: 1.67344
# INFO:tensorflow:loss = 2.25574, step = 801 (59.804 sec)
# INFO:tensorflow:global_step/sec: 1.61261
# INFO:tensorflow:loss = 4.03386, step = 901 (61.949 sec)
# INFO:tensorflow:Saving checkpoints for 951 into C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.693754
# INFO:tensorflow:loss = 3.1741, step = 1001 (144.174 sec)
# INFO:tensorflow:global_step/sec: 2.46452
# INFO:tensorflow:loss = 1.89252, step = 1101 (40.513 sec)
# INFO:tensorflow:global_step/sec: 1.66341
# INFO:tensorflow:loss = 12.4766, step = 1201 (60.180 sec)
# INFO:tensorflow:global_step/sec: 1.67993
# INFO:tensorflow:loss = 4.44732, step = 1301 (59.526 sec)
# INFO:tensorflow:global_step/sec: 1.68485
# INFO:tensorflow:loss = 5.1728, step = 1401 (59.337 sec)
# INFO:tensorflow:global_step/sec: 1.66447
# INFO:tensorflow:loss = 2.7638, step = 1501 (60.063 sec)
# INFO:tensorflow:global_step/sec: 1.71971
# INFO:tensorflow:loss = 1.93612, step = 1601 (58.212 sec)
# INFO:tensorflow:global_step/sec: 1.6831
# INFO:tensorflow:loss = 4.78182, step = 1701 (59.336 sec)
# INFO:tensorflow:global_step/sec: 1.71575
# INFO:tensorflow:loss = 1.14626, step = 1801 (58.299 sec)
# INFO:tensorflow:Saving checkpoints for 1853 into C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.703603
# INFO:tensorflow:loss = 1.21383, step = 1901 (142.079 sec)
# INFO:tensorflow:global_step/sec: 2.47785
# INFO:tensorflow:loss = 3.25661, step = 2001 (40.373 sec)
# INFO:tensorflow:global_step/sec: 1.67856
# INFO:tensorflow:loss = 2.07567, step = 2101 (59.590 sec)
# INFO:tensorflow:global_step/sec: 1.7097
# INFO:tensorflow:loss = 3.28517, step = 2201 (58.552 sec)
# INFO:tensorflow:global_step/sec: 1.68624
# INFO:tensorflow:loss = 0.988696, step = 2301 (59.288 sec)
# INFO:tensorflow:global_step/sec: 1.72119
# INFO:tensorflow:loss = 3.01674, step = 2401 (58.084 sec)
# INFO:tensorflow:global_step/sec: 1.71429
# INFO:tensorflow:loss = 6.14285, step = 2501 (58.771 sec)
# INFO:tensorflow:global_step/sec: 1.65032
# INFO:tensorflow:loss = 3.01328, step = 2601 (60.204 sec)
# INFO:tensorflow:global_step/sec: 1.6971
# INFO:tensorflow:loss = 1.84788, step = 2701 (58.878 sec)
# INFO:tensorflow:Saving checkpoints for 2761 into C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.686445
# INFO:tensorflow:loss = 4.04108, step = 2801 (145.693 sec)
# INFO:tensorflow:global_step/sec: 2.74683
# INFO:tensorflow:loss = 6.46898, step = 2901 (36.394 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.11053.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-07:34:16
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-07:35:12
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.87585, accuracy_baseline = 0.839286, auc = 0.792362, auc_precision_recall = 0.926312, average_loss = 0.437836, global_step = 3000, label/mean = 0.839286, loss = 42.9079, prediction/mean = 0.81948
# Evaluation using Tensorflow evaluate method...Result at folding session: 0 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 42.907928, 'auc': 0.79236156, 'average_loss': 0.43783599, 'prediction/mean': 0.81947953, 'auc_precision_recall': 0.92631197, 'accuracy': 0.87585032, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpe1sbiq0o\model.ckpt-3000
#
# -----Folding Session 0 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.790790863233 Accuracy: 0.875850340136 Error_rate: 0.124149659864
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpkpqmfaoj', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt.
# INFO:tensorflow:loss = 2.0441, step = 1
# INFO:tensorflow:global_step/sec: 4.60564
# INFO:tensorflow:loss = 1.74207, step = 101 (21.947 sec)
# INFO:tensorflow:global_step/sec: 1.74366
# INFO:tensorflow:loss = 8.91523, step = 201 (57.273 sec)
# INFO:tensorflow:global_step/sec: 1.68293
# INFO:tensorflow:loss = 4.76456, step = 301 (59.420 sec)
# INFO:tensorflow:global_step/sec: 1.70596
# INFO:tensorflow:loss = 5.38404, step = 401 (59.071 sec)
# INFO:tensorflow:global_step/sec: 1.69563
# INFO:tensorflow:loss = 1.71698, step = 501 (58.553 sec)
# INFO:tensorflow:global_step/sec: 1.66784
# INFO:tensorflow:loss = 3.83302, step = 601 (59.911 sec)
# INFO:tensorflow:global_step/sec: 1.71369
# INFO:tensorflow:loss = 3.79869, step = 701 (58.385 sec)
# INFO:tensorflow:global_step/sec: 1.67217
# INFO:tensorflow:loss = 20.9783, step = 801 (59.771 sec)
# INFO:tensorflow:global_step/sec: 1.70204
# INFO:tensorflow:loss = 4.13921, step = 901 (58.800 sec)
# INFO:tensorflow:Saving checkpoints for 970 into C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.662822
# INFO:tensorflow:loss = 2.04486, step = 1001 (150.792 sec)
# INFO:tensorflow:global_step/sec: 3.11292
# INFO:tensorflow:loss = 3.25653, step = 1101 (32.155 sec)
# INFO:tensorflow:global_step/sec: 1.68643
# INFO:tensorflow:loss = 0.753058, step = 1201 (59.281 sec)
# INFO:tensorflow:global_step/sec: 1.68778
# INFO:tensorflow:loss = 3.76154, step = 1301 (59.343 sec)
# INFO:tensorflow:global_step/sec: 1.67028
# INFO:tensorflow:loss = 0.977096, step = 1401 (59.792 sec)
# INFO:tensorflow:global_step/sec: 1.70132
# INFO:tensorflow:loss = 5.41132, step = 1501 (58.762 sec)
# INFO:tensorflow:global_step/sec: 1.65704
# INFO:tensorflow:loss = 0.71968, step = 1601 (60.692 sec)
# INFO:tensorflow:global_step/sec: 1.67498
# INFO:tensorflow:loss = 3.10677, step = 1701 (59.359 sec)
# INFO:tensorflow:global_step/sec: 1.67795
# INFO:tensorflow:loss = 6.4427, step = 1801 (59.659 sec)
# INFO:tensorflow:Saving checkpoints for 1870 into C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.660117
# INFO:tensorflow:loss = 2.19469, step = 1901 (151.410 sec)
# INFO:tensorflow:global_step/sec: 3.17982
# INFO:tensorflow:loss = 5.54053, step = 2001 (31.480 sec)
# INFO:tensorflow:global_step/sec: 1.66512
# INFO:tensorflow:loss = 2.3941, step = 2101 (60.087 sec)
# INFO:tensorflow:global_step/sec: 1.69636
# INFO:tensorflow:loss = 2.16808, step = 2201 (58.996 sec)
# INFO:tensorflow:global_step/sec: 1.65712
# INFO:tensorflow:loss = 5.74089, step = 2301 (60.283 sec)
# INFO:tensorflow:global_step/sec: 1.68237
# INFO:tensorflow:loss = 8.39532, step = 2401 (59.444 sec)
# INFO:tensorflow:global_step/sec: 1.69151
# INFO:tensorflow:loss = 3.99235, step = 2501 (59.474 sec)
# INFO:tensorflow:global_step/sec: 1.64735
# INFO:tensorflow:loss = 3.51757, step = 2601 (60.344 sec)
# INFO:tensorflow:global_step/sec: 1.6851
# INFO:tensorflow:loss = 4.51775, step = 2701 (59.391 sec)
# INFO:tensorflow:Saving checkpoints for 2769 into C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.658371
# INFO:tensorflow:loss = 3.04568, step = 2801 (151.796 sec)
# INFO:tensorflow:global_step/sec: 3.06153
# INFO:tensorflow:loss = 3.2759, step = 2901 (32.726 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.23387.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-08:24:26
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-08:25:22
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.823491, auc_precision_recall = 0.948214, average_loss = 0.577181, global_step = 3000, label/mean = 0.839286, loss = 56.5637, prediction/mean = 0.755266
# Evaluation using Tensorflow evaluate method...Result at folding session: 1 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 56.563705, 'auc': 0.8234911, 'average_loss': 0.57718068, 'prediction/mean': 0.75526577, 'auc_precision_recall': 0.94821441, 'accuracy': 0.86989796, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpkpqmfaoj\model.ckpt-3000
#
# -----Folding Session 1 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.823137292742 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp_itg49sc', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt.
# INFO:tensorflow:loss = 1.24026, step = 1
# INFO:tensorflow:global_step/sec: 4.59221
# INFO:tensorflow:loss = 3.96989, step = 101 (21.995 sec)
# INFO:tensorflow:global_step/sec: 1.73398
# INFO:tensorflow:loss = 2.67626, step = 201 (57.593 sec)
# INFO:tensorflow:global_step/sec: 1.66217
# INFO:tensorflow:loss = 3.11698, step = 301 (60.209 sec)
# INFO:tensorflow:global_step/sec: 1.69969
# INFO:tensorflow:loss = 8.26786, step = 401 (58.850 sec)
# INFO:tensorflow:global_step/sec: 1.67265
# INFO:tensorflow:loss = 2.11694, step = 501 (59.739 sec)
# INFO:tensorflow:global_step/sec: 1.70721
# INFO:tensorflow:loss = 4.9067, step = 601 (58.591 sec)
# INFO:tensorflow:global_step/sec: 1.71743
# INFO:tensorflow:loss = 3.41767, step = 701 (58.289 sec)
# INFO:tensorflow:global_step/sec: 1.67049
# INFO:tensorflow:loss = 3.4841, step = 801 (59.816 sec)
# INFO:tensorflow:global_step/sec: 1.68897
# INFO:tensorflow:loss = 6.44596, step = 901 (59.223 sec)
# INFO:tensorflow:Saving checkpoints for 967 into C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.667886
# INFO:tensorflow:loss = 4.05311, step = 1001 (149.570 sec)
# INFO:tensorflow:global_step/sec: 3.03153
# INFO:tensorflow:loss = 2.30183, step = 1101 (33.034 sec)
# INFO:tensorflow:global_step/sec: 1.69785
# INFO:tensorflow:loss = 5.22173, step = 1201 (58.992 sec)
# INFO:tensorflow:global_step/sec: 1.65363
# INFO:tensorflow:loss = 3.23082, step = 1301 (60.520 sec)
# INFO:tensorflow:global_step/sec: 1.69802
# INFO:tensorflow:loss = 2.72083, step = 1401 (58.783 sec)
# INFO:tensorflow:global_step/sec: 1.65302
# INFO:tensorflow:loss = 2.14771, step = 1501 (60.464 sec)
# INFO:tensorflow:global_step/sec: 1.687
# INFO:tensorflow:loss = 4.78441, step = 1601 (59.386 sec)
# INFO:tensorflow:global_step/sec: 1.68632
# INFO:tensorflow:loss = 2.47565, step = 1701 (59.223 sec)
# INFO:tensorflow:global_step/sec: 1.65774
# INFO:tensorflow:loss = 2.40199, step = 1801 (60.370 sec)
# INFO:tensorflow:Saving checkpoints for 1868 into C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.672522
# INFO:tensorflow:loss = 1.95138, step = 1901 (148.553 sec)
# INFO:tensorflow:global_step/sec: 2.96344
# INFO:tensorflow:loss = 1.87546, step = 2001 (33.838 sec)
# INFO:tensorflow:global_step/sec: 1.65142
# INFO:tensorflow:loss = 5.19566, step = 2101 (60.554 sec)
# INFO:tensorflow:global_step/sec: 1.67863
# INFO:tensorflow:loss = 1.39039, step = 2201 (59.634 sec)
# INFO:tensorflow:global_step/sec: 1.68838
# INFO:tensorflow:loss = 7.48963, step = 2301 (59.181 sec)
# INFO:tensorflow:global_step/sec: 1.65695
# INFO:tensorflow:loss = 0.997805, step = 2401 (60.352 sec)
# INFO:tensorflow:global_step/sec: 1.6916
# INFO:tensorflow:loss = 0.659857, step = 2501 (59.506 sec)
# INFO:tensorflow:global_step/sec: 1.64443
# INFO:tensorflow:loss = 1.13609, step = 2601 (60.421 sec)
# INFO:tensorflow:global_step/sec: 1.68216
# INFO:tensorflow:loss = 9.8247, step = 2701 (59.479 sec)
# INFO:tensorflow:Saving checkpoints for 2765 into C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.675611
# INFO:tensorflow:loss = 2.99353, step = 2801 (147.967 sec)
# INFO:tensorflow:global_step/sec: 2.73477
# INFO:tensorflow:loss = 1.67573, step = 2901 (36.597 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.68349.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-09:14:35
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-09:15:31
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.852891, accuracy_baseline = 0.839286, auc = 0.813341, auc_precision_recall = 0.949707, average_loss = 0.347741, global_step = 3000, label/mean = 0.839286, loss = 34.0786, prediction/mean = 0.80634
# Evaluation using Tensorflow evaluate method...Result at folding session: 2 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 34.078571, 'auc': 0.81334066, 'average_loss': 0.34774053, 'prediction/mean': 0.80633956, 'auc_precision_recall': 0.94970691, 'accuracy': 0.85289115, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_itg49sc\model.ckpt-3000
#
# -----Folding Session 2 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.814431525171 Accuracy: 0.852891156463 Error_rate: 0.147108843537
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmptbi51vwm', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt.
# INFO:tensorflow:loss = 2.25443, step = 1
# INFO:tensorflow:global_step/sec: 4.52428
# INFO:tensorflow:loss = 17.5763, step = 101 (22.322 sec)
# INFO:tensorflow:global_step/sec: 1.70434
# INFO:tensorflow:loss = 6.42089, step = 201 (58.658 sec)
# INFO:tensorflow:global_step/sec: 1.67132
# INFO:tensorflow:loss = 2.89379, step = 301 (59.817 sec)
# INFO:tensorflow:global_step/sec: 1.70522
# INFO:tensorflow:loss = 2.53477, step = 401 (58.597 sec)
# INFO:tensorflow:global_step/sec: 1.7
# INFO:tensorflow:loss = 6.27793, step = 501 (58.808 sec)
# INFO:tensorflow:global_step/sec: 1.6661
# INFO:tensorflow:loss = 5.14102, step = 601 (60.005 sec)
# INFO:tensorflow:global_step/sec: 1.70773
# INFO:tensorflow:loss = 1.33639, step = 701 (58.699 sec)
# INFO:tensorflow:global_step/sec: 1.69673
# INFO:tensorflow:loss = 2.28718, step = 801 (58.827 sec)
# INFO:tensorflow:global_step/sec: 1.66031
# INFO:tensorflow:loss = 4.36056, step = 901 (60.214 sec)
# INFO:tensorflow:Saving checkpoints for 967 into C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.678716
# INFO:tensorflow:loss = 3.17058, step = 1001 (147.353 sec)
# INFO:tensorflow:global_step/sec: 2.84463
# INFO:tensorflow:loss = 1.16781, step = 1101 (35.185 sec)
# INFO:tensorflow:global_step/sec: 1.6751
# INFO:tensorflow:loss = 4.09099, step = 1201 (59.682 sec)
# INFO:tensorflow:global_step/sec: 1.68405
# INFO:tensorflow:loss = 1.60966, step = 1301 (59.365 sec)
# INFO:tensorflow:global_step/sec: 1.6468
# INFO:tensorflow:loss = 6.11436, step = 1401 (60.739 sec)
# INFO:tensorflow:global_step/sec: 1.69546
# INFO:tensorflow:loss = 8.05005, step = 1501 (58.919 sec)
# INFO:tensorflow:global_step/sec: 1.6885
# INFO:tensorflow:loss = 1.98852, step = 1601 (59.365 sec)
# INFO:tensorflow:global_step/sec: 1.6605
# INFO:tensorflow:loss = 2.16311, step = 1701 (60.098 sec)
# INFO:tensorflow:global_step/sec: 1.68345
# INFO:tensorflow:loss = 3.96973, step = 1801 (59.449 sec)
# INFO:tensorflow:Saving checkpoints for 1864 into C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.669424
# INFO:tensorflow:loss = 4.27402, step = 1901 (149.351 sec)
# INFO:tensorflow:global_step/sec: 2.91988
# INFO:tensorflow:loss = 1.95846, step = 2001 (34.232 sec)
# INFO:tensorflow:global_step/sec: 1.68146
# INFO:tensorflow:loss = 1.78746, step = 2101 (59.503 sec)
# INFO:tensorflow:global_step/sec: 1.65804
# INFO:tensorflow:loss = 6.80385, step = 2201 (60.656 sec)
# INFO:tensorflow:global_step/sec: 1.68133
# INFO:tensorflow:loss = 2.50907, step = 2301 (59.149 sec)
# INFO:tensorflow:global_step/sec: 1.69528
# INFO:tensorflow:loss = 1.9284, step = 2401 (58.956 sec)
# INFO:tensorflow:global_step/sec: 1.65139
# INFO:tensorflow:loss = 1.90214, step = 2501 (60.493 sec)
# INFO:tensorflow:global_step/sec: 1.68315
# INFO:tensorflow:loss = 3.65862, step = 2601 (59.537 sec)
# INFO:tensorflow:global_step/sec: 1.6436
# INFO:tensorflow:loss = 5.03779, step = 2701 (60.873 sec)
# INFO:tensorflow:Saving checkpoints for 2762 into C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.684397
# INFO:tensorflow:loss = 2.32914, step = 2801 (145.911 sec)
# INFO:tensorflow:global_step/sec: 2.7562
# INFO:tensorflow:loss = 4.38606, step = 2901 (36.407 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.12691.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-10:04:45
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-10:05:42
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.866497, accuracy_baseline = 0.839286, auc = 0.831747, auc_precision_recall = 0.95292, average_loss = 0.339376, global_step = 3000, label/mean = 0.839286, loss = 33.2588, prediction/mean = 0.811368
# Evaluation using Tensorflow evaluate method...Result at folding session: 3 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 33.25882, 'auc': 0.83174652, 'average_loss': 0.3393757, 'prediction/mean': 0.81136751, 'auc_precision_recall': 0.95291972, 'accuracy': 0.86649662, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmptbi51vwm\model.ckpt-3000
#
# -----Folding Session 3 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.832247792734 Accuracy: 0.866496598639 Error_rate: 0.133503401361
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp572v68hn
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp572v68hn', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt.
# INFO:tensorflow:loss = 3.96646, step = 1
# INFO:tensorflow:global_step/sec: 4.58032
# INFO:tensorflow:loss = 1.92608, step = 101 (22.036 sec)
# INFO:tensorflow:global_step/sec: 1.74313
# INFO:tensorflow:loss = 2.24095, step = 201 (57.337 sec)
# INFO:tensorflow:global_step/sec: 1.67167
# INFO:tensorflow:loss = 2.80412, step = 301 (59.758 sec)
# INFO:tensorflow:global_step/sec: 1.70646
# INFO:tensorflow:loss = 6.5056, step = 401 (58.976 sec)
# INFO:tensorflow:global_step/sec: 1.68077
# INFO:tensorflow:loss = 7.84957, step = 501 (59.200 sec)
# INFO:tensorflow:global_step/sec: 1.66534
# INFO:tensorflow:loss = 1.85955, step = 601 (60.048 sec)
# INFO:tensorflow:global_step/sec: 1.70273
# INFO:tensorflow:loss = 2.16325, step = 701 (58.839 sec)
# INFO:tensorflow:global_step/sec: 1.65922
# INFO:tensorflow:loss = 2.54881, step = 801 (60.097 sec)
# INFO:tensorflow:global_step/sec: 1.69529
# INFO:tensorflow:loss = 5.65349, step = 901 (59.003 sec)
# INFO:tensorflow:Saving checkpoints for 967 into C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.652863
# INFO:tensorflow:loss = 3.12824, step = 1001 (153.187 sec)
# INFO:tensorflow:global_step/sec: 2.98515
# INFO:tensorflow:loss = 1.75529, step = 1101 (33.530 sec)
# INFO:tensorflow:global_step/sec: 1.67869
# INFO:tensorflow:loss = 5.25278, step = 1201 (59.555 sec)
# INFO:tensorflow:global_step/sec: 1.68445
# INFO:tensorflow:loss = 3.63299, step = 1301 (59.398 sec)
# INFO:tensorflow:global_step/sec: 1.6492
# INFO:tensorflow:loss = 1.13169, step = 1401 (60.604 sec)
# INFO:tensorflow:global_step/sec: 1.69387
# INFO:tensorflow:loss = 7.97124, step = 1501 (58.990 sec)
# INFO:tensorflow:global_step/sec: 1.65142
# INFO:tensorflow:loss = 3.36179, step = 1601 (60.632 sec)
# INFO:tensorflow:global_step/sec: 1.69132
# INFO:tensorflow:loss = 2.49529, step = 1701 (59.063 sec)
# INFO:tensorflow:global_step/sec: 1.6763
# INFO:tensorflow:loss = 4.32687, step = 1801 (59.624 sec)
# INFO:tensorflow:Saving checkpoints for 1858 into C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.666668
# INFO:tensorflow:loss = 4.63047, step = 1901 (149.922 sec)
# INFO:tensorflow:global_step/sec: 2.68282
# INFO:tensorflow:loss = 1.0552, step = 2001 (37.352 sec)
# INFO:tensorflow:global_step/sec: 1.67944
# INFO:tensorflow:loss = 4.81583, step = 2101 (59.559 sec)
# INFO:tensorflow:global_step/sec: 1.65304
# INFO:tensorflow:loss = 3.09046, step = 2201 (60.573 sec)
# INFO:tensorflow:global_step/sec: 1.67516
# INFO:tensorflow:loss = 3.4455, step = 2301 (59.665 sec)
# INFO:tensorflow:global_step/sec: 1.64453
# INFO:tensorflow:loss = 3.90807, step = 2401 (60.808 sec)
# INFO:tensorflow:global_step/sec: 1.66862
# INFO:tensorflow:loss = 10.6288, step = 2501 (59.899 sec)
# INFO:tensorflow:global_step/sec: 1.68538
# INFO:tensorflow:loss = 3.42927, step = 2601 (59.318 sec)
# INFO:tensorflow:global_step/sec: 1.64162
# INFO:tensorflow:loss = 6.89298, step = 2701 (60.962 sec)
# INFO:tensorflow:Saving checkpoints for 2747 into C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.700556
# INFO:tensorflow:loss = 2.40857, step = 2801 (142.634 sec)
# INFO:tensorflow:global_step/sec: 2.30494
# INFO:tensorflow:loss = 3.33851, step = 2901 (43.479 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.81029.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-10:55:15
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-10:56:12
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.871599, accuracy_baseline = 0.839286, auc = 0.828166, auc_precision_recall = 0.95344, average_loss = 0.35158, global_step = 3000, label/mean = 0.839286, loss = 34.4549, prediction/mean = 0.857761
# Evaluation using Tensorflow evaluate method...Result at folding session: 4 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 34.45488, 'auc': 0.82816565, 'average_loss': 0.35158041, 'prediction/mean': 0.85776132, 'auc_precision_recall': 0.95344043, 'accuracy': 0.87159866, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp572v68hn\model.ckpt-3000
#
# -----Folding Session 4 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.828401494562 Accuracy: 0.871598639456 Error_rate: 0.128401360544
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp3_1c331g', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt.
# INFO:tensorflow:loss = 12.2162, step = 1
# INFO:tensorflow:global_step/sec: 4.2657
# INFO:tensorflow:loss = 12.5895, step = 101 (23.568 sec)
# INFO:tensorflow:global_step/sec: 1.68375
# INFO:tensorflow:loss = 3.37914, step = 201 (59.439 sec)
# INFO:tensorflow:global_step/sec: 1.65673
# INFO:tensorflow:loss = 4.20667, step = 301 (60.328 sec)
# INFO:tensorflow:global_step/sec: 1.69169
# INFO:tensorflow:loss = 5.58667, step = 401 (59.191 sec)
# INFO:tensorflow:global_step/sec: 1.70017
# INFO:tensorflow:loss = 3.0356, step = 501 (58.740 sec)
# INFO:tensorflow:global_step/sec: 1.66623
# INFO:tensorflow:loss = 2.54815, step = 601 (59.985 sec)
# INFO:tensorflow:global_step/sec: 1.70215
# INFO:tensorflow:loss = 4.21384, step = 701 (59.171 sec)
# INFO:tensorflow:global_step/sec: 1.64896
# INFO:tensorflow:loss = 1.79182, step = 801 (60.238 sec)
# INFO:tensorflow:global_step/sec: 1.69826
# INFO:tensorflow:loss = 3.7436, step = 901 (58.899 sec)
# INFO:tensorflow:Saving checkpoints for 962 into C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.674757
# INFO:tensorflow:loss = 2.72962, step = 1001 (148.108 sec)
# INFO:tensorflow:global_step/sec: 2.6319
# INFO:tensorflow:loss = 4.29956, step = 1101 (38.105 sec)
# INFO:tensorflow:global_step/sec: 1.68293
# INFO:tensorflow:loss = 0.79935, step = 1201 (59.389 sec)
# INFO:tensorflow:global_step/sec: 1.67663
# INFO:tensorflow:loss = 8.82527, step = 1301 (59.737 sec)
# INFO:tensorflow:global_step/sec: 1.64934
# INFO:tensorflow:loss = 12.4948, step = 1401 (60.552 sec)
# INFO:tensorflow:global_step/sec: 1.68085
# INFO:tensorflow:loss = 4.90576, step = 1501 (59.540 sec)
# INFO:tensorflow:global_step/sec: 1.65081
# INFO:tensorflow:loss = 4.21806, step = 1601 (60.514 sec)
# INFO:tensorflow:global_step/sec: 1.67865
# INFO:tensorflow:loss = 1.97598, step = 1701 (59.619 sec)
# INFO:tensorflow:global_step/sec: 1.66896
# INFO:tensorflow:loss = 1.9442, step = 1801 (59.855 sec)
# INFO:tensorflow:Saving checkpoints for 1851 into C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.681834
# INFO:tensorflow:loss = 7.28765, step = 1901 (146.679 sec)
# INFO:tensorflow:global_step/sec: 2.48408
# INFO:tensorflow:loss = 4.20506, step = 2001 (40.272 sec)
# INFO:tensorflow:global_step/sec: 1.64635
# INFO:tensorflow:loss = 2.30494, step = 2101 (60.709 sec)
# INFO:tensorflow:global_step/sec: 1.68371
# INFO:tensorflow:loss = 2.89199, step = 2201 (59.440 sec)
# INFO:tensorflow:global_step/sec: 1.68167
# INFO:tensorflow:loss = 2.72877, step = 2301 (59.434 sec)
# INFO:tensorflow:global_step/sec: 1.6449
# INFO:tensorflow:loss = 7.01586, step = 2401 (60.856 sec)
# INFO:tensorflow:global_step/sec: 1.67594
# INFO:tensorflow:loss = 4.39388, step = 2501 (59.668 sec)
# INFO:tensorflow:global_step/sec: 1.64475
# INFO:tensorflow:loss = 3.76663, step = 2601 (60.799 sec)
# INFO:tensorflow:global_step/sec: 1.67931
# INFO:tensorflow:loss = 3.66859, step = 2701 (59.486 sec)
# INFO:tensorflow:Saving checkpoints for 2741 into C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.71014
# INFO:tensorflow:loss = 4.8162, step = 2801 (140.833 sec)
# INFO:tensorflow:global_step/sec: 2.18243
# INFO:tensorflow:loss = 1.23311, step = 2901 (45.821 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.75087.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-11:46:05
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-11:47:02
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.860711, auc_precision_recall = 0.957263, average_loss = 0.34525, global_step = 3000, label/mean = 0.839286, loss = 33.8345, prediction/mean = 0.808444
# Evaluation using Tensorflow evaluate method...Result at folding session: 5 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 33.834476, 'auc': 0.8607105, 'average_loss': 0.34524974, 'prediction/mean': 0.80844355, 'auc_precision_recall': 0.95726293, 'accuracy': 0.86989796, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt-3000
#
# -----Folding Session 5 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.860820293444 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp72yixvuq', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt.
# INFO:tensorflow:loss = 3.29466, step = 1
# INFO:tensorflow:global_step/sec: 4.50019
# INFO:tensorflow:loss = 5.51883, step = 101 (22.503 sec)
# INFO:tensorflow:global_step/sec: 1.6464
# INFO:tensorflow:loss = 3.54375, step = 201 (60.614 sec)
# INFO:tensorflow:global_step/sec: 1.70385
# INFO:tensorflow:loss = 3.38463, step = 301 (58.691 sec)
# INFO:tensorflow:global_step/sec: 1.69371
# INFO:tensorflow:loss = 10.5862, step = 401 (59.370 sec)
# INFO:tensorflow:global_step/sec: 1.65538
# INFO:tensorflow:loss = 2.3972, step = 501 (60.065 sec)
# INFO:tensorflow:global_step/sec: 1.68394
# INFO:tensorflow:loss = 2.12984, step = 601 (59.463 sec)
# INFO:tensorflow:global_step/sec: 1.65427
# INFO:tensorflow:loss = 6.37508, step = 701 (60.371 sec)
# INFO:tensorflow:global_step/sec: 1.69417
# INFO:tensorflow:loss = 1.12629, step = 801 (59.057 sec)
# INFO:tensorflow:global_step/sec: 1.69277
# INFO:tensorflow:loss = 2.99355, step = 901 (59.450 sec)
# INFO:tensorflow:Saving checkpoints for 961 into C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.668084
# INFO:tensorflow:loss = 1.98962, step = 1001 (149.276 sec)
# INFO:tensorflow:global_step/sec: 2.80319
# INFO:tensorflow:loss = 2.86998, step = 1101 (35.658 sec)
# INFO:tensorflow:global_step/sec: 1.6424
# INFO:tensorflow:loss = 1.467, step = 1201 (60.918 sec)
# INFO:tensorflow:global_step/sec: 1.67573
# INFO:tensorflow:loss = 5.12638, step = 1301 (59.879 sec)
# INFO:tensorflow:global_step/sec: 1.64264
# INFO:tensorflow:loss = 3.22945, step = 1401 (60.628 sec)
# INFO:tensorflow:global_step/sec: 1.66976
# INFO:tensorflow:loss = 1.80483, step = 1501 (60.373 sec)
# INFO:tensorflow:global_step/sec: 1.66511
# INFO:tensorflow:loss = 2.87541, step = 1601 (59.650 sec)
# INFO:tensorflow:global_step/sec: 1.6308
# INFO:tensorflow:loss = 2.18876, step = 1701 (61.460 sec)
# INFO:tensorflow:global_step/sec: 1.66189
# INFO:tensorflow:loss = 4.4755, step = 1801 (59.875 sec)
# INFO:tensorflow:Saving checkpoints for 1849 into C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.68219
# INFO:tensorflow:loss = 2.25409, step = 1901 (146.555 sec)
# INFO:tensorflow:global_step/sec: 2.3544
# INFO:tensorflow:loss = 9.4279, step = 2001 (42.599 sec)
# INFO:tensorflow:global_step/sec: 1.63948
# INFO:tensorflow:loss = 3.18832, step = 2101 (61.026 sec)
# INFO:tensorflow:global_step/sec: 1.677
# INFO:tensorflow:loss = 5.16131, step = 2201 (60.161 sec)
# INFO:tensorflow:global_step/sec: 1.62742
# INFO:tensorflow:loss = 4.81301, step = 2301 (60.931 sec)
# INFO:tensorflow:global_step/sec: 1.6707
# INFO:tensorflow:loss = 3.4225, step = 2401 (59.855 sec)
# INFO:tensorflow:global_step/sec: 1.67015
# INFO:tensorflow:loss = 1.48118, step = 2501 (59.859 sec)
# INFO:tensorflow:global_step/sec: 1.63444
# INFO:tensorflow:loss = 4.10401, step = 2601 (61.167 sec)
# INFO:tensorflow:global_step/sec: 1.66652
# INFO:tensorflow:loss = 2.53941, step = 2701 (60.021 sec)
# INFO:tensorflow:Saving checkpoints for 2728 into C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.751231
# INFO:tensorflow:loss = 7.66157, step = 2801 (133.146 sec)
# INFO:tensorflow:global_step/sec: 1.93386
# INFO:tensorflow:loss = 3.62208, step = 2901 (51.679 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.29706.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-12:36:41
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-12:37:38
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.866497, accuracy_baseline = 0.839286, auc = 0.812716, auc_precision_recall = 0.946077, average_loss = 0.349703, global_step = 3000, label/mean = 0.839286, loss = 34.2709, prediction/mean = 0.808746
# Evaluation using Tensorflow evaluate method...Result at folding session: 6 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 34.270885, 'auc': 0.81271613, 'average_loss': 0.34970289, 'prediction/mean': 0.8087455, 'auc_precision_recall': 0.94607699, 'accuracy': 0.86649662, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp72yixvuq\model.ckpt-3000
#
# -----Folding Session 6 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.812700020907 Accuracy: 0.866496598639 Error_rate: 0.133503401361
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpahxhk2wx', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt.
# INFO:tensorflow:loss = 2.83287, step = 1
# INFO:tensorflow:global_step/sec: 4.48678
# INFO:tensorflow:loss = 7.17442, step = 101 (22.428 sec)
# INFO:tensorflow:global_step/sec: 1.70108
# INFO:tensorflow:loss = 3.73478, step = 201 (58.755 sec)
# INFO:tensorflow:global_step/sec: 1.6956
# INFO:tensorflow:loss = 3.83812, step = 301 (58.961 sec)
# INFO:tensorflow:global_step/sec: 1.65867
# INFO:tensorflow:loss = 3.73289, step = 401 (60.414 sec)
# INFO:tensorflow:global_step/sec: 1.68802
# INFO:tensorflow:loss = 23.8095, step = 501 (59.212 sec)
# INFO:tensorflow:global_step/sec: 1.66029
# INFO:tensorflow:loss = 2.71194, step = 601 (60.150 sec)
# INFO:tensorflow:global_step/sec: 1.70478
# INFO:tensorflow:loss = 2.70659, step = 701 (58.752 sec)
# INFO:tensorflow:global_step/sec: 1.6947
# INFO:tensorflow:loss = 10.9839, step = 801 (58.914 sec)
# INFO:tensorflow:global_step/sec: 1.66218
# INFO:tensorflow:loss = 4.70417, step = 901 (60.178 sec)
# INFO:tensorflow:Saving checkpoints for 964 into C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.681328
# INFO:tensorflow:loss = 3.64789, step = 1001 (146.788 sec)
# INFO:tensorflow:global_step/sec: 2.81279
# INFO:tensorflow:loss = 3.23178, step = 1101 (35.521 sec)
# INFO:tensorflow:global_step/sec: 1.677
# INFO:tensorflow:loss = 2.60079, step = 1201 (59.630 sec)
# INFO:tensorflow:global_step/sec: 1.65074
# INFO:tensorflow:loss = 4.84256, step = 1301 (60.641 sec)
# INFO:tensorflow:global_step/sec: 1.68029
# INFO:tensorflow:loss = 1.89822, step = 1401 (59.451 sec)
# INFO:tensorflow:global_step/sec: 1.65323
# INFO:tensorflow:loss = 0.736131, step = 1501 (60.472 sec)
# INFO:tensorflow:global_step/sec: 1.68343
# INFO:tensorflow:loss = 3.12951, step = 1601 (59.418 sec)
# INFO:tensorflow:global_step/sec: 1.67672
# INFO:tensorflow:loss = 2.80132, step = 1701 (59.640 sec)
# INFO:tensorflow:global_step/sec: 1.64097
# INFO:tensorflow:loss = 2.45377, step = 1801 (61.018 sec)
# INFO:tensorflow:Saving checkpoints for 1859 into C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.690219
# INFO:tensorflow:loss = 3.48549, step = 1901 (144.694 sec)
# INFO:tensorflow:global_step/sec: 2.64694
# INFO:tensorflow:loss = 4.1898, step = 2001 (37.889 sec)
# INFO:tensorflow:global_step/sec: 1.68725
# INFO:tensorflow:loss = 6.25456, step = 2101 (59.315 sec)
# INFO:tensorflow:global_step/sec: 1.65336
# INFO:tensorflow:loss = 1.55387, step = 2201 (60.561 sec)
# INFO:tensorflow:global_step/sec: 1.68197
# INFO:tensorflow:loss = 3.40541, step = 2301 (59.251 sec)
# INFO:tensorflow:global_step/sec: 1.61207
# INFO:tensorflow:loss = 2.2068, step = 2401 (62.235 sec)
# INFO:tensorflow:global_step/sec: 1.6382
# INFO:tensorflow:loss = 1.84264, step = 2501 (60.918 sec)
# INFO:tensorflow:global_step/sec: 1.68432
# INFO:tensorflow:loss = 2.24319, step = 2601 (59.746 sec)
# INFO:tensorflow:global_step/sec: 1.63597
# INFO:tensorflow:loss = 1.64249, step = 2701 (60.766 sec)
# INFO:tensorflow:Saving checkpoints for 2751 into C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.70467
# INFO:tensorflow:loss = 3.0179, step = 2801 (141.895 sec)
# INFO:tensorflow:global_step/sec: 2.47509
# INFO:tensorflow:loss = 2.54527, step = 2901 (40.481 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.36764.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-13:26:57
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-13:27:53
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.873299, accuracy_baseline = 0.839286, auc = 0.803941, auc_precision_recall = 0.941758, average_loss = 0.394145, global_step = 3000, label/mean = 0.839286, loss = 38.6262, prediction/mean = 0.8513
# Evaluation using Tensorflow evaluate method...Result at folding session: 7 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 38.626194, 'auc': 0.80394065, 'average_loss': 0.39414483, 'prediction/mean': 0.85129976, 'auc_precision_recall': 0.94175816, 'accuracy': 0.8732993, 'label/mean': 0.83928573}
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpahxhk2wx\model.ckpt-3000
#
# -----Folding Session 7 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.804130951041 Accuracy: 0.873299319728 Error_rate: 0.126700680272
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp49_n5lb5', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt.
# INFO:tensorflow:loss = 3.97798, step = 1
# INFO:tensorflow:global_step/sec: 4.3293
# INFO:tensorflow:loss = 4.39635, step = 101 (23.364 sec)
# INFO:tensorflow:global_step/sec: 1.69489
# INFO:tensorflow:loss = 21.6376, step = 201 (58.923 sec)
# INFO:tensorflow:global_step/sec: 1.65393
# INFO:tensorflow:loss = 5.34043, step = 301 (60.400 sec)
# INFO:tensorflow:global_step/sec: 1.68884
# INFO:tensorflow:loss = 3.91497, step = 401 (59.291 sec)
# INFO:tensorflow:global_step/sec: 1.688
# INFO:tensorflow:loss = 6.06045, step = 501 (59.163 sec)
# INFO:tensorflow:global_step/sec: 1.65546
# INFO:tensorflow:loss = 1.6616, step = 601 (60.406 sec)
# INFO:tensorflow:global_step/sec: 1.69325
# INFO:tensorflow:loss = 2.74673, step = 701 (59.371 sec)
# INFO:tensorflow:global_step/sec: 1.65869
# INFO:tensorflow:loss = 2.2171, step = 801 (60.007 sec)
# INFO:tensorflow:global_step/sec: 1.69141
# INFO:tensorflow:loss = 7.32203, step = 901 (59.075 sec)
# INFO:tensorflow:Saving checkpoints for 963 into C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.671682
# INFO:tensorflow:loss = 2.03978, step = 1001 (148.943 sec)
# INFO:tensorflow:global_step/sec: 2.57909
# INFO:tensorflow:loss = 1.5387, step = 1101 (38.773 sec)
# INFO:tensorflow:global_step/sec: 1.31574
# INFO:tensorflow:loss = 4.1226, step = 1201 (76.159 sec)
# INFO:tensorflow:global_step/sec: 1.38237
# INFO:tensorflow:loss = 7.00641, step = 1301 (72.152 sec)
# INFO:tensorflow:global_step/sec: 1.51236
# INFO:tensorflow:loss = 1.21506, step = 1401 (66.184 sec)
# INFO:tensorflow:global_step/sec: 1.62645
# INFO:tensorflow:loss = 4.61528, step = 1501 (61.437 sec)
# INFO:tensorflow:global_step/sec: 1.60604
# INFO:tensorflow:loss = 3.95489, step = 1601 (62.296 sec)
# INFO:tensorflow:global_step/sec: 1.63072
# INFO:tensorflow:loss = 1.78674, step = 1701 (61.291 sec)
# INFO:tensorflow:Saving checkpoints for 1775 into C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.575837
# INFO:tensorflow:loss = 3.11055, step = 1801 (173.660 sec)
# INFO:tensorflow:global_step/sec: 2.90859
# INFO:tensorflow:loss = 2.58153, step = 1901 (34.396 sec)
# INFO:tensorflow:global_step/sec: 1.59911
# INFO:tensorflow:loss = 2.41189, step = 2001 (62.504 sec)
# INFO:tensorflow:global_step/sec: 1.61205
# INFO:tensorflow:loss = 3.86604, step = 2101 (62.142 sec)
# INFO:tensorflow:global_step/sec: 1.64618
# INFO:tensorflow:loss = 4.89407, step = 2201 (60.637 sec)
# INFO:tensorflow:global_step/sec: 1.65101
# INFO:tensorflow:loss = 9.24904, step = 2301 (60.741 sec)
# INFO:tensorflow:global_step/sec: 1.6104
# INFO:tensorflow:loss = 3.33223, step = 2401 (61.925 sec)
# INFO:tensorflow:global_step/sec: 1.44698
# INFO:tensorflow:loss = 1.59432, step = 2501 (69.025 sec)
# INFO:tensorflow:Saving checkpoints for 2597 into C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.56164
# INFO:tensorflow:loss = 1.5591, step = 2601 (178.150 sec)
# INFO:tensorflow:global_step/sec: 3.97452
# INFO:tensorflow:loss = 2.83308, step = 2701 (25.129 sec)
# INFO:tensorflow:global_step/sec: 1.54298
# INFO:tensorflow:loss = 3.11763, step = 2801 (64.794 sec)
# INFO:tensorflow:global_step/sec: 1.62381
# INFO:tensorflow:loss = 3.74493, step = 2901 (61.708 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.96812.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-14:19:14
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-14:20:10
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.821851, auc_precision_recall = 0.952785, average_loss = 0.344681, global_step = 3000, label/mean = 0.839286, loss = 33.7788, prediction/mean = 0.815225
# Evaluation using Tensorflow evaluate method...Result at folding session: 8 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 33.778759, 'auc': 0.82185078, 'average_loss': 0.3446812, 'prediction/mean': 0.81522489, 'auc_precision_recall': 0.95278543, 'accuracy': 0.86989796, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp49_n5lb5\model.ckpt-3000
#
# -----Folding Session 8 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.822097318045 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpfev725wf
# INFO:tensorflow:Using config: {'_session_config': None, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpfev725wf', '_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt.
# INFO:tensorflow:loss = 21.1301, step = 1
# INFO:tensorflow:global_step/sec: 4.40668
# INFO:tensorflow:loss = 0.443913, step = 101 (22.912 sec)
# INFO:tensorflow:global_step/sec: 1.66816
# INFO:tensorflow:loss = 0.293052, step = 201 (59.868 sec)
# INFO:tensorflow:global_step/sec: 1.66552
# INFO:tensorflow:loss = 3.36815, step = 301 (60.120 sec)
# INFO:tensorflow:global_step/sec: 1.6426
# INFO:tensorflow:loss = 7.80051, step = 401 (60.816 sec)
# INFO:tensorflow:global_step/sec: 1.68119
# INFO:tensorflow:loss = 4.07948, step = 501 (59.529 sec)
# INFO:tensorflow:global_step/sec: 1.54201
# INFO:tensorflow:loss = 5.6502, step = 601 (64.772 sec)
# INFO:tensorflow:global_step/sec: 1.64462
# INFO:tensorflow:loss = 32.7685, step = 701 (60.883 sec)
# INFO:tensorflow:global_step/sec: 1.66628
# INFO:tensorflow:loss = 2.80252, step = 801 (59.951 sec)
# INFO:tensorflow:global_step/sec: 1.67318
# INFO:tensorflow:loss = 2.1915, step = 901 (59.813 sec)
# INFO:tensorflow:Saving checkpoints for 943 into C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.709604
# INFO:tensorflow:loss = 1.68646, step = 1001 (140.799 sec)
# INFO:tensorflow:global_step/sec: 2.13583
# INFO:tensorflow:loss = 4.06941, step = 1101 (46.859 sec)
# INFO:tensorflow:global_step/sec: 1.62196
# INFO:tensorflow:loss = 3.3612, step = 1201 (61.678 sec)
# INFO:tensorflow:global_step/sec: 1.65555
# INFO:tensorflow:loss = 4.16681, step = 1301 (60.497 sec)
# INFO:tensorflow:global_step/sec: 1.62471
# INFO:tensorflow:loss = 2.67305, step = 1401 (61.440 sec)
# INFO:tensorflow:global_step/sec: 1.61978
# INFO:tensorflow:loss = 6.04141, step = 1501 (61.815 sec)
# INFO:tensorflow:global_step/sec: 1.6439
# INFO:tensorflow:loss = 5.04408, step = 1601 (60.815 sec)
# INFO:tensorflow:global_step/sec: 1.43855
# INFO:tensorflow:loss = 3.55172, step = 1701 (69.514 sec)
# INFO:tensorflow:Saving checkpoints for 1797 into C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.547402
# INFO:tensorflow:loss = 3.72749, step = 1801 (182.603 sec)
# INFO:tensorflow:global_step/sec: 4.39961
# INFO:tensorflow:loss = 3.22713, step = 1901 (22.761 sec)
# INFO:tensorflow:global_step/sec: 1.4563
# INFO:tensorflow:loss = 2.65474, step = 2001 (68.698 sec)
# INFO:tensorflow:global_step/sec: 1.46412
# INFO:tensorflow:loss = 1.79297, step = 2101 (68.316 sec)
# INFO:tensorflow:global_step/sec: 1.42061
# INFO:tensorflow:loss = 5.63305, step = 2201 (70.345 sec)
# INFO:tensorflow:global_step/sec: 1.47694
# INFO:tensorflow:loss = 3.30724, step = 2301 (67.755 sec)
# INFO:tensorflow:global_step/sec: 1.48364
# INFO:tensorflow:loss = 3.35733, step = 2401 (67.402 sec)
# INFO:tensorflow:global_step/sec: 1.56021
# INFO:tensorflow:loss = 3.93181, step = 2501 (64.203 sec)
# INFO:tensorflow:Saving checkpoints for 2578 into C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.570071
# INFO:tensorflow:loss = 2.44388, step = 2601 (175.308 sec)
# INFO:tensorflow:global_step/sec: 2.95853
# INFO:tensorflow:loss = 3.4463, step = 2701 (33.753 sec)
# INFO:tensorflow:global_step/sec: 1.47835
# INFO:tensorflow:loss = 5.43496, step = 2801 (67.643 sec)
# INFO:tensorflow:global_step/sec: 1.49987
# INFO:tensorflow:loss = 2.57748, step = 2901 (66.688 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.93408.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-15:12:46
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-15:13:47
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.856293, accuracy_baseline = 0.839286, auc = 0.738192, auc_precision_recall = 0.914614, average_loss = 0.38611, global_step = 3000, label/mean = 0.839286, loss = 37.8388, prediction/mean = 0.821855
# Evaluation using Tensorflow evaluate method...Result at folding session: 9 {'accuracy_baseline': 0.83928573, 'global_step': 3000, 'loss': 37.838764, 'auc': 0.73819166, 'average_loss': 0.38610986, 'prediction/mean': 0.82185483, 'auc_precision_recall': 0.91461426, 'accuracy': 0.85629255, 'label/mean': 0.83928573}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpfev725wf\model.ckpt-3000
#
# -----Folding Session 9 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.73703382062 Accuracy: 0.856292517007 Error_rate: 0.143707482993
#
# -----k-fold summary:-----
# Evaluation Errors: [0.12414965986394558, 0.13010204081632654, 0.14710884353741496, 0.13350340136054423, 0.12840136054421769, 0.13010204081632654, 0.13350340136054423, 0.12670068027210885, 0.13010204081632654, 0.14370748299319727]
# Evaluation error rate average: 0.132738095238
# Model's standard deviation: 0.00691290445126
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp3_1c331g\model.ckpt-3000
#
# Final Test>> AUC: 0.837595373321 Accuracy: 0.872108843537 Final Error_rate: 0.127891156463
# F-measure: 0.92794174013 Accuracy: 0.872108843537 Recall: 0.98095623987 Precision: 0.880363636364 False Positive Rate: 0.697033898305 False Negative Rate: 0.0190437601297
# Confusion matrix, without normalization
# [[ 143  329]
#  [  47 2421]]
# Normalized confusion matrix
# [[ 0.3   0.7 ]
#  [ 0.02  0.98]]
