# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import metrics

# %%
# %matplotlib inline

# %%
data_source_path = "F:\deep lerning project\data\FinalData\d5.wordpress_phpbb23.label_appearance_normalized_density.csv"

#test_output_file = open("F:\\deep lerning project\\data\\FinalData\\hidden_layer_test_output.txt", mode = 'w')# for testing layers...delete if not needed
# for slicing the necessary columns from the source file...directly related to source data columns
label_col_start = 0
feature_col_start = 8

# I have many labels but here is the col that contains 'changed_ever_class'
class_label_col = 2 # class is in col 2

# %%
# Some configurations
# set only one to true...
select_model_based_on_loss = False
select_model_based_on_error_rate = False
select_model_based_on_auc = True
#---------------------------------

# %%
def get_feature_and_label():
    # read the data file
    # return features and labels
    
    file_change_df = pd.read_csv(data_source_path)
    
    X = file_change_df.iloc[:,feature_col_start:]
    #print(X.shape)
    #print(X)
    
    y_all_labels = file_change_df.iloc[:,label_col_start:feature_col_start] # all available labels 
    #print(type(y_all_labels))
    #print(y_all_labels)
    y = y_all_labels.iloc[:,class_label_col] # take the changed_ever col only
    y = pd.Series.to_frame(y) # y is a series...convert it to dataframe again--- not necessary...series will do
    #print(y.head())
    #print(type(y))
    
    #print(y.shape)
    #print(y)
    
    return X, y

# %%
def get_train_test_split(X, y, nsplits = 1, testSize = 0.2):

    sss = StratifiedShuffleSplit(n_splits=nsplits, test_size=testSize)
    
    for train_index, test_index in sss.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index] # X.iloc[index] because its pandas dataframe.so..iloc
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    return X_train, y_train, X_test, y_test

# %%
def show_data_statistics(X_train, y_train, X_test, y_test):
    #print(X_train.shape)
    #print(y_train.shape)
    #print(X_test.shape)
    #print(y_test.shape)
    #print(type(y_test))
    print("y_train Statistics:\n", y_train.describe())
    print("y_test Statistics:\n",y_test.describe())
    
    plt.hist(y_train)
    plt.hist(y_test)

# %%
def get_feature_cols(X):
    feature_cols = []
    i=0

    for col in X.columns:
        #if is_numeric_dtype(X[col]): #is_numeric_dtype is pandas function
        feature_cols.extend([tf.feature_column.numeric_column(col)])
        i = i+1
        
    print("Total features column names converted to tf.feature_column.numeric_column('col_name') = ", i)
    return feature_cols

# %%
def train_model(model, X_train, y_train):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        batch_size=10,
        num_epochs=3000,
        shuffle=True)    
    
    model = model.train(input_fn=input_func,steps=3000)
    
    return model

# %%
def evaluate_model(model, X_test, y_test):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    results = model.evaluate(input_func)
    #print(results)
    
    return results

# %%
def prediction(model, X, y):
    
    prediction_list = []
    y_proba_positive_class_list = [] # positive class probability of each element for calculating AUC
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    y_predicted = model.predict(input_func)
    
    for elem in y_predicted: # y_predicted is a generator object holds a memory address...read all values from there
        #print("type elem:", type(elem))
        #print("elem:", elem)
        elem_probabilities = np.array(elem['probabilities'])
        #print("Elem probabilities of each class:", elem_probabilities)
        
        y_proba_positive_class_list.append(elem_probabilities[1]) # class 1 is the positive class, its index is 1
        #print("prob_list_now:", elem_positive_class_proba_list)
        
        elem_class = np.argmax(elem_probabilities) # one probable class based on the index that contain max value
        #print("probable class:",elem_class)
        
        prediction_list.append(elem_class)
        
    
    # assign prediction list to y_predicted for consistent name
    y_predicted = np.array(prediction_list)
    
    #print("y_predicted_shape:", y_predicted.shape, "val:", y_predicted)
    #print("y_type:", type(y),"y shape:", y.shape, "val:", y)
    
    #error_rate = sum(y_predicted != np.array(y)/len(y_predicted))
    
    #print(list(y_predicted))
    
    y = np.array(y) # convert y data to np array
    r,c = y.shape
    #print("y- r,c:",r,c)
    y = y.reshape(r) # change the shape of y to numpy [row,]
    #print("y-shape:", y.shape)
    
    
    '''
    print("before converting to list y_predicted:", y_predicted)
    
    y_predicted = list(y_predicted)
    print("y_predicted:", y_predicted)
    
    y_predicted = np.array(y_predicted)
    print("after converting to nparray y_predicted:", y_predicted, "shape:", y_predicted.shape)
    
    y= np.array(y)
    r,c = y.shape
    print("y- r,c:",r,c)
    y = y.reshape(r)
    print("y-shape:", y.shape)
    '''
    
    error_rate = sum(y_predicted != y)/len(y_predicted) # sum needs the operands in np array of shape [row,]
    
    return y_predicted, error_rate, y_proba_positive_class_list

# %%
def get_normalized_train_data(X_train):
    #Unused function---Normalization is done separately
    #print(type(X_train))
    #print(X_train.head())
    saved_cols = X_train.columns # save the columns names..scaling change the pandas frame to numpy..need to restore
    saved_index = list(X_train.index) # # scaling changes pandas X indices..need to restore to match with y data indices
    #print("saved_index", saved_index)
    
    min_max_scaler = preprocessing.MinMaxScaler()
    
    scaled_X_train = min_max_scaler.fit_transform(X_train)
    scaled_X_train = pd.DataFrame(scaled_X_train, index=saved_index, columns=saved_cols)# restore the column names

    #print(scaled_X_train.head())
    return scaled_X_train

# %%
def get_random_sample(X, y, n_sample = 1):
    n = np.arange(X.shape[0]) # generate numbers equal to the max no of rows in the X df
    if n_sample>len(n):
        print("You have asked", n_sample, " samples, but the training data has", len(n), " rows. Returning 1 sample...")
        n_sample = 1
        
    np.random.shuffle(n) # shuffle all the numbers representing row index
    index = n[0:n_sample] # take the numbers from 0 to given sample
    
    X_sample = X.iloc[index]
    y_sample = y.iloc[index]
    
    #print(X_sample.head())
    #print(y_sample.head())
    
    return X_sample, y_sample

# %%
def show_evaluation_error_report(eval_error_rates):
    
    eval_error_rate_avg = sum(eval_error_rates)/len(eval_error_rates)
    model_std = np.std(eval_error_rates)
    
    print("Evaluation Errors:", eval_error_rates)
    print('Evaluation error rate average:', eval_error_rate_avg, '\nModel\'s standard deviation:', model_std)

# %%
def calculate_performance_metrics(cnf_matrix):
    
    TP = cnf_matrix[1,1]
    TN = cnf_matrix[0,0]
    FP = cnf_matrix[0,1]
    FN = cnf_matrix[1,0]
    
    
    # Sensitivity, hit rate, recall, or true positive rate
    TPR_recall = TP/(TP+FN) # Recall
    # Specificity or true negative rate
    TNR = TN/(TN+FP) # **
    # Precision or positive predictive value
    PPV_precision = TP/(TP+FP) # precision
    # Negative predictive value
    NPV = TN/(TN+FN) #**
    # Fall out or false positive rate
    FPR_false_positive = FP/(FP+TN)
    # False negative rate
    FNR_false_negative = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP) # **

    # Overall accuracy
    accuracy = (TP+TN)/(TP+FP+FN+TN)
    f_measure = 2/((1.0/TPR_recall) + (1.0/PPV_precision)) #https://en.wikipedia.org/wiki/F1_score
    
    # ** some extra values are calculated but not returned
    return TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def get_roc_auc(y, y_proba_positive_class_list):
    
    y = y.as_matrix() # convert series data to numpy array
    
    auc = metrics.roc_auc_score(y, y_proba_positive_class_list)
    #print("Auc:", auc)
    
    '''
    #This one also works but not needed
    fpr, tpr, thresholds = metrics.roc_curve(y, elem_positive_class_proba_list)
    auc2 = metrics.auc(fpr, tpr)
    print("AUC2:", auc2, "fpr:", fpr, "tpr:", tpr)
    '''
    return auc

# %%
def get_cnf_matrix_prf_metrics(y, y_predicted):
    
    y = y.values.tolist() # convert pandas data to list
    #print(">>>>>type_y:", type(y), "val:", y)
    
    y = list(np.array(y).flat) # when converted to list panda gives [[values], [values]]...convert them to flat list[]
    #print("----------type_y_f:", type(y), "val:", y)
    
    
    y_predicted = list(y_predicted)
    #print(">>>>>>type_y_predicted:", type(y_predicted), "val:", y_predicted)
    
    cnf_matrix = confusion_matrix(y, y_predicted)
    
    #print("conf matrix:", cnf_matrix)
    # Calculate performane metrics
    TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = calculate_performance_metrics(cnf_matrix)
    
    return cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def show_confusion_matrix(cnf_matrix, class_names):
    # show cmap of confusion metrics
    np.set_printoptions(precision=2) # settings for printing floating point values
    
    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def main():
    
    X, y = get_feature_and_label()
    X_train_0, y_train_0, X_test_final, y_test_final = get_train_test_split(X,y) #get_train_test_split(X, y, nsplits = 1, testSize = 0.2)

    #show_data_statistics("---Train-Test Statistics---",X_train, y_train, X_test, y_test)
    #print(type(X))
    feature_cols = get_feature_cols(X_train_0)
    #print(feature_cols)

    # start k-fold cross validation and find the best model with the minimum loss during evaluation
    
    min_loss = float('inf')
    min_error_rate = float("inf")
    max_auc = float("-inf")

    folding_session = 0
    eval_error_rates = []
    
    sss = StratifiedShuffleSplit(n_splits=10) #stratifiedkfold generates error for y_train_0 and doesn't work if y multi-labe
    
    for train_index, eval_index in sss.split(X_train_0, y_train_0):

        X_train, X_eval = X_train_0.iloc[train_index], X_train_0.iloc[eval_index]  # iloc[index] because X is a pandas dataframe
        y_train, y_eval = y_train_0.iloc[train_index], y_train_0.iloc[eval_index]
        

        #X_train = get_normalized_train_data(X_train) # min-max standardization
        #print(X_train.head())
        
        # Add layers in this list if more layer settings are needed
        hidden_layers_units = [
            [1022, 511, 255, 128]
        ]
        
        for my_hidden_units in hidden_layers_units:
            print("Hidden Settings:", my_hidden_units)
            #create a new estimator model

            file_change_prediction_model = tf.estimator.DNNClassifier(
                                                                    hidden_units = my_hidden_units,
                                                                    feature_columns = feature_cols, 
                                                                    n_classes=2, 
                                                                    activation_fn = tf.nn.relu)

            #print("new:", file_change_prediction_model)    

            #train the model
            file_change_prediction_model = train_model(file_change_prediction_model, X_train, y_train)
            #print("ret:", file_change_prediction_model)

            #evaluate the trained model
            evaluation_res = evaluate_model(file_change_prediction_model, X_eval, y_eval)
            print("Evaluation using Tensorflow evaluate method...Result at folding session:", folding_session, evaluation_res,"\n\n")
            
            # Do my own evaluation using the trained model in this folding session using evaluation data
            y_predicted, error_rate, y_proba_positive_class_list = prediction(file_change_prediction_model, X_eval, y_eval)
            eval_error_rates.append(error_rate) # error_rate of current folding session
            
            # calculate auc
            auc_evaluation = get_roc_auc(y_eval, y_proba_positive_class_list)

            #----
            #print("\nHidden Settings:", my_hidden_units, file=test_output_file)
            #print('\nFolding Session', folding_session,"AUC:",auc_validation,"Accuracy:", 1-error_rate, 'Error_rate:', error_rate, file=test_output_file)
            print('\n-----Folding Session', folding_session, "Hidden Settings:", my_hidden_units, "-----\nAUC:",auc_evaluation, "Accuracy:", 1-error_rate, 'Error_rate:', error_rate)
    
            #----
            #select the best model using the tensorflow evaluation result
            if select_model_based_on_loss:
                if evaluation_res['loss'] < min_loss:
                    best_model = file_change_prediction_model
                    min_loss = evaluation_res['loss']
                    print("Selecting model based on min_loss.")
    
            # select the best model based on calculated error rate
            if select_model_based_on_error_rate:
                if error_rate < min_error_rate:
                    best_model = file_change_prediction_model # save the best model
                    min_error_rate = error_rate # update the min_error_rate
                    print("Selecting model based on min_error_rate.")
                
            if select_model_based_on_auc:
                if auc_evaluation > max_auc:
                    best_model = file_change_prediction_model # save the best model
                    max_auc = auc_evaluation # update the max_auc
                    print("Selecting model based on max_auc.")

            #Take the next fold in the loop
        folding_session = folding_session + 1
        #break # remove it later for k-fold...now just one fold    
    
    #============================================
    
    print("\n-----k-fold summary:-----")
    k_fold_eval_error_rates = eval_error_rates # for naming consistency with other models
    show_evaluation_error_report(k_fold_eval_error_rates) 
    
    # see the evaluation result using the best model and some random sample from the used training data
    #X_eval, y_eval = get_random_sample(X_train_0,y_train_0, n_sample = 1000)
    #test_res = evaluate_model(best_model, X_eval, y_eval)
    #print("A random evaluation of the model:\n", test_res)
    
    # Do final test using tensorflow function
    #test_res = evaluate_model(best_model, X_test_final, y_test_final)
    #print("Final performance with the best model and test data:", test_res)
    
    #Everything finished I have got the best model and now want to get the final evaluation in my format
    #----------------------------------------------------------------------------------------------------
    #predict using the best model
    y_predicted, error_rate, y_proba_positive_class_list = prediction(best_model, X_test_final, y_test_final)
    #print("shape of x test final:", X_test_final)
    
    # calculate auc
    auc_final = get_roc_auc(y_test_final, y_proba_positive_class_list)
    print("\nFinal Test>> AUC:", auc_final, "Accuracy:", 1-error_rate, "Final Error_rate:", error_rate)
    
    cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = get_cnf_matrix_prf_metrics(y_test_final, y_predicted)
    print("F-measure:", f_measure, "Accuracy:",accuracy, "Recall:", TPR_recall, "Precision:", PPV_precision, "False Positive Rate:", FPR_false_positive, "False Negative Rate:", FNR_false_negative)
    
    class_names = ['0','1'] # class names in order.. 1st index for class whose label is 0, 2nd index for class whose label is 1......
    show_confusion_matrix(cnf_matrix, class_names)

# %%
main()
# Out:
# Total features column names converted to tf.feature_column.numeric_column('col_name') =  2042
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpo2aku0kq', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt.
# INFO:tensorflow:loss = 7.43213, step = 1
# INFO:tensorflow:global_step/sec: 3.12623
# INFO:tensorflow:loss = 7.32607, step = 101 (31.769 sec)
# INFO:tensorflow:global_step/sec: 1.60997
# INFO:tensorflow:loss = 1.93579, step = 201 (62.160 sec)
# INFO:tensorflow:global_step/sec: 1.65303
# INFO:tensorflow:loss = 2.82669, step = 301 (60.506 sec)
# INFO:tensorflow:global_step/sec: 1.49284
# INFO:tensorflow:loss = 4.16413, step = 401 (67.007 sec)
# INFO:tensorflow:global_step/sec: 1.51964
# INFO:tensorflow:loss = 4.23194, step = 501 (65.711 sec)
# INFO:tensorflow:global_step/sec: 1.4701
# INFO:tensorflow:loss = 4.11558, step = 601 (68.085 sec)
# INFO:tensorflow:global_step/sec: 1.54526
# INFO:tensorflow:loss = 4.85845, step = 701 (66.069 sec)
# INFO:tensorflow:global_step/sec: 1.54205
# INFO:tensorflow:loss = 4.55875, step = 801 (63.462 sec)
# INFO:tensorflow:Saving checkpoints for 854 into C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.649821
# INFO:tensorflow:loss = 2.41149, step = 901 (153.888 sec)
# INFO:tensorflow:global_step/sec: 2.34917
# INFO:tensorflow:loss = 7.12428, step = 1001 (42.584 sec)
# INFO:tensorflow:global_step/sec: 1.62913
# INFO:tensorflow:loss = 2.75025, step = 1101 (61.398 sec)
# INFO:tensorflow:global_step/sec: 1.6642
# INFO:tensorflow:loss = 1.40487, step = 1201 (60.167 sec)
# INFO:tensorflow:global_step/sec: 1.66348
# INFO:tensorflow:loss = 2.17241, step = 1301 (60.068 sec)
# INFO:tensorflow:global_step/sec: 1.53147
# INFO:tensorflow:loss = 5.56473, step = 1401 (65.281 sec)
# INFO:tensorflow:global_step/sec: 1.63394
# INFO:tensorflow:loss = 3.15589, step = 1501 (61.124 sec)
# INFO:tensorflow:global_step/sec: 1.48638
# INFO:tensorflow:loss = 1.75011, step = 1601 (67.293 sec)
# INFO:tensorflow:Saving checkpoints for 1695 into C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.586434
# INFO:tensorflow:loss = 3.18063, step = 1701 (170.475 sec)
# INFO:tensorflow:global_step/sec: 4.28767
# INFO:tensorflow:loss = 12.3011, step = 1801 (23.370 sec)
# INFO:tensorflow:global_step/sec: 1.66087
# INFO:tensorflow:loss = 3.13491, step = 1901 (60.256 sec)
# INFO:tensorflow:global_step/sec: 1.66727
# INFO:tensorflow:loss = 6.15122, step = 2001 (60.009 sec)
# INFO:tensorflow:global_step/sec: 1.57991
# INFO:tensorflow:loss = 2.5592, step = 2101 (63.201 sec)
# INFO:tensorflow:global_step/sec: 1.60121
# INFO:tensorflow:loss = 4.10141, step = 2201 (62.953 sec)
# INFO:tensorflow:global_step/sec: 1.61174
# INFO:tensorflow:loss = 3.06488, step = 2301 (61.623 sec)
# INFO:tensorflow:global_step/sec: 1.63693
# INFO:tensorflow:loss = 1.16823, step = 2401 (61.137 sec)
# INFO:tensorflow:global_step/sec: 1.65927
# INFO:tensorflow:loss = 0.488031, step = 2501 (60.205 sec)
# INFO:tensorflow:Saving checkpoints for 2562 into C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.648635
# INFO:tensorflow:loss = 2.70337, step = 2601 (154.139 sec)
# INFO:tensorflow:global_step/sec: 2.76314
# INFO:tensorflow:loss = 0.394792, step = 2701 (36.206 sec)
# INFO:tensorflow:global_step/sec: 1.6345
# INFO:tensorflow:loss = 0.990185, step = 2801 (61.149 sec)
# INFO:tensorflow:global_step/sec: 1.6659
# INFO:tensorflow:loss = 1.93665, step = 2901 (59.996 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt.
# INFO:tensorflow:Loss for final step: 0.696376.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-16:40:40
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-16:41:39
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.886054, accuracy_baseline = 0.839286, auc = 0.897155, auc_precision_recall = 0.977767, average_loss = 0.276329, global_step = 3000, label/mean = 0.839286, loss = 27.0802, prediction/mean = 0.847735
# Evaluation using Tensorflow evaluate method...Result at folding session: 0 {'auc': 0.89715517, 'prediction/mean': 0.84773475, 'accuracy': 0.8860544, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97776711, 'loss': 27.0802, 'accuracy_baseline': 0.83928573, 'average_loss': 0.27632856}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpo2aku0kq\model.ckpt-3000
#
# -----Folding Session 0 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.897640222362 Accuracy: 0.886054421769 Error_rate: 0.113945578231
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp1sf3ksv1', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt.
# INFO:tensorflow:loss = 7.40483, step = 1
# INFO:tensorflow:global_step/sec: 4.52199
# INFO:tensorflow:loss = 3.02418, step = 101 (22.286 sec)
# INFO:tensorflow:global_step/sec: 1.6621
# INFO:tensorflow:loss = 7.18071, step = 201 (60.102 sec)
# INFO:tensorflow:global_step/sec: 1.62794
# INFO:tensorflow:loss = 3.62077, step = 301 (61.505 sec)
# INFO:tensorflow:global_step/sec: 1.64217
# INFO:tensorflow:loss = 5.48536, step = 401 (60.864 sec)
# INFO:tensorflow:global_step/sec: 1.63084
# INFO:tensorflow:loss = 1.89646, step = 501 (61.397 sec)
# INFO:tensorflow:global_step/sec: 1.6607
# INFO:tensorflow:loss = 0.641327, step = 601 (60.040 sec)
# INFO:tensorflow:global_step/sec: 1.61258
# INFO:tensorflow:loss = 2.60311, step = 701 (62.140 sec)
# INFO:tensorflow:global_step/sec: 1.63533
# INFO:tensorflow:loss = 7.12684, step = 801 (61.072 sec)
# INFO:tensorflow:global_step/sec: 1.67062
# INFO:tensorflow:loss = 3.65286, step = 901 (60.311 sec)
# INFO:tensorflow:Saving checkpoints for 940 into C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.716376
# INFO:tensorflow:loss = 2.15978, step = 1001 (139.029 sec)
# INFO:tensorflow:global_step/sec: 2.13294
# INFO:tensorflow:loss = 3.54336, step = 1101 (47.024 sec)
# INFO:tensorflow:global_step/sec: 1.62188
# INFO:tensorflow:loss = 0.634004, step = 1201 (61.626 sec)
# INFO:tensorflow:global_step/sec: 1.64256
# INFO:tensorflow:loss = 4.29231, step = 1301 (60.913 sec)
# INFO:tensorflow:global_step/sec: 1.66344
# INFO:tensorflow:loss = 5.24181, step = 1401 (60.163 sec)
# INFO:tensorflow:global_step/sec: 1.55419
# INFO:tensorflow:loss = 4.01451, step = 1501 (64.295 sec)
# INFO:tensorflow:global_step/sec: 1.65337
# INFO:tensorflow:loss = 1.45313, step = 1601 (60.514 sec)
# INFO:tensorflow:global_step/sec: 1.62413
# INFO:tensorflow:loss = 0.80032, step = 1701 (61.603 sec)
# INFO:tensorflow:global_step/sec: 1.652
# INFO:tensorflow:loss = 2.99759, step = 1801 (60.517 sec)
# INFO:tensorflow:Saving checkpoints for 1815 into C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.777913
# INFO:tensorflow:loss = 1.41982, step = 1901 (128.502 sec)
# INFO:tensorflow:global_step/sec: 1.69374
# INFO:tensorflow:loss = 1.06762, step = 2001 (60.291 sec)
# INFO:tensorflow:global_step/sec: 1.61561
# INFO:tensorflow:loss = 2.40011, step = 2101 (60.771 sec)
# INFO:tensorflow:global_step/sec: 1.63694
# INFO:tensorflow:loss = 4.98657, step = 2201 (60.980 sec)
# INFO:tensorflow:global_step/sec: 1.62184
# INFO:tensorflow:loss = 1.24506, step = 2301 (61.658 sec)
# INFO:tensorflow:global_step/sec: 1.65126
# INFO:tensorflow:loss = 2.38853, step = 2401 (60.496 sec)
# INFO:tensorflow:global_step/sec: 1.63964
# INFO:tensorflow:loss = 1.10153, step = 2501 (61.115 sec)
# INFO:tensorflow:global_step/sec: 1.5743
# INFO:tensorflow:loss = 0.947058, step = 2601 (63.458 sec)
# INFO:tensorflow:Saving checkpoints for 2683 into C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.602006
# INFO:tensorflow:loss = 0.484097, step = 2701 (166.080 sec)
# INFO:tensorflow:global_step/sec: 3.60784
# INFO:tensorflow:loss = 2.15508, step = 2801 (27.764 sec)
# INFO:tensorflow:global_step/sec: 1.65243
# INFO:tensorflow:loss = 0.661764, step = 2901 (60.517 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.27544.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-17:32:45
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-17:33:45
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.887755, accuracy_baseline = 0.839286, auc = 0.893001, auc_precision_recall = 0.974612, average_loss = 0.283418, global_step = 3000, label/mean = 0.839286, loss = 27.7749, prediction/mean = 0.831085
# Evaluation using Tensorflow evaluate method...Result at folding session: 1 {'auc': 0.89300054, 'prediction/mean': 0.83108515, 'accuracy': 0.8877551, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97461224, 'loss': 27.774942, 'accuracy_baseline': 0.83928573, 'average_loss': 0.28341779}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp1sf3ksv1\model.ckpt-3000
#
# -----Folding Session 1 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.893241772674 Accuracy: 0.887755102041 Error_rate: 0.112244897959
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpbqwbiwos', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt.
# INFO:tensorflow:loss = 7.38599, step = 1
# INFO:tensorflow:global_step/sec: 4.30393
# INFO:tensorflow:loss = 0.156589, step = 101 (23.469 sec)
# INFO:tensorflow:global_step/sec: 1.66274
# INFO:tensorflow:loss = 2.4349, step = 201 (60.064 sec)
# INFO:tensorflow:global_step/sec: 1.62567
# INFO:tensorflow:loss = 0.753542, step = 301 (61.545 sec)
# INFO:tensorflow:global_step/sec: 1.6065
# INFO:tensorflow:loss = 2.36976, step = 401 (62.247 sec)
# INFO:tensorflow:global_step/sec: 1.55317
# INFO:tensorflow:loss = 2.23481, step = 501 (64.588 sec)
# INFO:tensorflow:global_step/sec: 1.47447
# INFO:tensorflow:loss = 2.58908, step = 601 (67.555 sec)
# INFO:tensorflow:global_step/sec: 1.55145
# INFO:tensorflow:loss = 1.47082, step = 701 (64.534 sec)
# INFO:tensorflow:global_step/sec: 1.58999
# INFO:tensorflow:loss = 3.98864, step = 801 (62.831 sec)
# INFO:tensorflow:global_step/sec: 1.57156
# INFO:tensorflow:loss = 1.13169, step = 901 (63.772 sec)
# INFO:tensorflow:Saving checkpoints for 907 into C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.76992
# INFO:tensorflow:loss = 4.63251, step = 1001 (129.790 sec)
# INFO:tensorflow:global_step/sec: 1.58598
# INFO:tensorflow:loss = 2.67174, step = 1101 (63.006 sec)
# INFO:tensorflow:global_step/sec: 1.58937
# INFO:tensorflow:loss = 3.7895, step = 1201 (62.981 sec)
# INFO:tensorflow:global_step/sec: 1.57557
# INFO:tensorflow:loss = 4.84429, step = 1301 (63.454 sec)
# INFO:tensorflow:global_step/sec: 1.5627
# INFO:tensorflow:loss = 2.07421, step = 1401 (63.945 sec)
# INFO:tensorflow:global_step/sec: 1.60151
# INFO:tensorflow:loss = 2.99331, step = 1501 (62.410 sec)
# INFO:tensorflow:global_step/sec: 1.57177
# INFO:tensorflow:loss = 6.06883, step = 1601 (63.732 sec)
# INFO:tensorflow:global_step/sec: 1.58645
# INFO:tensorflow:loss = 0.729269, step = 1701 (63.034 sec)
# INFO:tensorflow:Saving checkpoints for 1752 into C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.66245
# INFO:tensorflow:loss = 2.12976, step = 1801 (150.861 sec)
# INFO:tensorflow:global_step/sec: 2.27203
# INFO:tensorflow:loss = 0.161545, step = 1901 (44.075 sec)
# INFO:tensorflow:global_step/sec: 1.5389
# INFO:tensorflow:loss = 1.97943, step = 2001 (64.935 sec)
# INFO:tensorflow:global_step/sec: 1.60675
# INFO:tensorflow:loss = 1.12965, step = 2101 (62.237 sec)
# INFO:tensorflow:global_step/sec: 1.55585
# INFO:tensorflow:loss = 5.62727, step = 2201 (64.320 sec)
# INFO:tensorflow:global_step/sec: 1.54439
# INFO:tensorflow:loss = 1.83497, step = 2301 (64.813 sec)
# INFO:tensorflow:global_step/sec: 1.61949
# INFO:tensorflow:loss = 1.29139, step = 2401 (61.670 sec)
# INFO:tensorflow:global_step/sec: 1.58208
# INFO:tensorflow:loss = 1.18277, step = 2501 (63.224 sec)
# INFO:tensorflow:Saving checkpoints for 2592 into C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.590718
# INFO:tensorflow:loss = 1.40053, step = 2601 (169.254 sec)
# INFO:tensorflow:global_step/sec: 4.42597
# INFO:tensorflow:loss = 5.57617, step = 2701 (22.578 sec)
# INFO:tensorflow:global_step/sec: 1.62381
# INFO:tensorflow:loss = 1.40437, step = 2801 (61.552 sec)
# INFO:tensorflow:global_step/sec: 1.64857
# INFO:tensorflow:loss = 1.28987, step = 2901 (60.737 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.92854.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-18:25:47
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-18:26:46
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.864525, auc_precision_recall = 0.968561, average_loss = 0.305684, global_step = 3000, label/mean = 0.839286, loss = 29.9571, prediction/mean = 0.841889
# Evaluation using Tensorflow evaluate method...Result at folding session: 2 {'auc': 0.86452466, 'prediction/mean': 0.84188896, 'accuracy': 0.86989796, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.9685607, 'loss': 29.957071, 'accuracy_baseline': 0.83928573, 'average_loss': 0.30568442}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbqwbiwos\model.ckpt-3000
#
# -----Folding Session 2 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.865041840219 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpg_q48srh', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt.
# INFO:tensorflow:loss = 7.26322, step = 1
# INFO:tensorflow:global_step/sec: 4.55585
# INFO:tensorflow:loss = 3.81042, step = 101 (22.231 sec)
# INFO:tensorflow:global_step/sec: 1.63711
# INFO:tensorflow:loss = 8.12716, step = 201 (60.974 sec)
# INFO:tensorflow:global_step/sec: 1.6614
# INFO:tensorflow:loss = 4.18317, step = 301 (60.237 sec)
# INFO:tensorflow:global_step/sec: 1.65978
# INFO:tensorflow:loss = 2.49137, step = 401 (60.202 sec)
# INFO:tensorflow:global_step/sec: 1.6258
# INFO:tensorflow:loss = 3.90095, step = 501 (61.555 sec)
# INFO:tensorflow:global_step/sec: 1.66427
# INFO:tensorflow:loss = 1.36624, step = 601 (60.055 sec)
# INFO:tensorflow:global_step/sec: 1.61964
# INFO:tensorflow:loss = 1.91013, step = 701 (61.759 sec)
# INFO:tensorflow:global_step/sec: 1.65682
# INFO:tensorflow:loss = 0.583907, step = 801 (60.340 sec)
# INFO:tensorflow:global_step/sec: 1.66464
# INFO:tensorflow:loss = 4.19627, step = 901 (60.448 sec)
# INFO:tensorflow:Saving checkpoints for 943 into C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.698667
# INFO:tensorflow:loss = 2.20071, step = 1001 (142.708 sec)
# INFO:tensorflow:global_step/sec: 2.09963
# INFO:tensorflow:loss = 1.55935, step = 1101 (47.674 sec)
# INFO:tensorflow:global_step/sec: 1.58165
# INFO:tensorflow:loss = 1.40859, step = 1201 (63.209 sec)
# INFO:tensorflow:global_step/sec: 1.60892
# INFO:tensorflow:loss = 4.77226, step = 1301 (62.294 sec)
# INFO:tensorflow:global_step/sec: 1.64282
# INFO:tensorflow:loss = 2.46217, step = 1401 (60.809 sec)
# INFO:tensorflow:global_step/sec: 1.64573
# INFO:tensorflow:loss = 2.13067, step = 1501 (60.685 sec)
# INFO:tensorflow:global_step/sec: 1.61529
# INFO:tensorflow:loss = 0.88918, step = 1601 (61.893 sec)
# INFO:tensorflow:global_step/sec: 1.63648
# INFO:tensorflow:loss = 1.66514, step = 1701 (61.138 sec)
# INFO:tensorflow:global_step/sec: 1.6059
# INFO:tensorflow:loss = 3.02898, step = 1801 (62.192 sec)
# INFO:tensorflow:Saving checkpoints for 1806 into C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.761634
# INFO:tensorflow:loss = 3.34552, step = 1901 (131.328 sec)
# INFO:tensorflow:global_step/sec: 1.62699
# INFO:tensorflow:loss = 2.76792, step = 2001 (61.479 sec)
# INFO:tensorflow:global_step/sec: 1.65959
# INFO:tensorflow:loss = 4.15806, step = 2101 (60.287 sec)
# INFO:tensorflow:global_step/sec: 1.6502
# INFO:tensorflow:loss = 1.41744, step = 2201 (60.599 sec)
# INFO:tensorflow:global_step/sec: 1.60737
# INFO:tensorflow:loss = 1.43509, step = 2301 (62.510 sec)
# INFO:tensorflow:global_step/sec: 1.64491
# INFO:tensorflow:loss = 4.31384, step = 2401 (60.465 sec)
# INFO:tensorflow:global_step/sec: 1.60793
# INFO:tensorflow:loss = 0.916235, step = 2501 (62.317 sec)
# INFO:tensorflow:global_step/sec: 1.64969
# INFO:tensorflow:loss = 1.85924, step = 2601 (60.461 sec)
# INFO:tensorflow:Saving checkpoints for 2672 into C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.626421
# INFO:tensorflow:loss = 3.87199, step = 2701 (159.700 sec)
# INFO:tensorflow:global_step/sec: 3.13479
# INFO:tensorflow:loss = 2.19483, step = 2801 (31.884 sec)
# INFO:tensorflow:global_step/sec: 1.63928
# INFO:tensorflow:loss = 1.57639, step = 2901 (60.987 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.50014.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-19:17:59
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-19:18:58
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.887755, accuracy_baseline = 0.839286, auc = 0.904397, auc_precision_recall = 0.977861, average_loss = 0.271639, global_step = 3000, label/mean = 0.839286, loss = 26.6206, prediction/mean = 0.878987
# Evaluation using Tensorflow evaluate method...Result at folding session: 3 {'auc': 0.90439743, 'prediction/mean': 0.87898743, 'accuracy': 0.8877551, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.9778614, 'loss': 26.620615, 'accuracy_baseline': 0.83928573, 'average_loss': 0.27163893}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt-3000
#
# -----Folding Session 3 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.905354261484 Accuracy: 0.887755102041 Error_rate: 0.112244897959
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpldc1geew
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpldc1geew', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt.
# INFO:tensorflow:loss = 7.2436, step = 1
# INFO:tensorflow:global_step/sec: 4.19733
# INFO:tensorflow:loss = 4.43976, step = 101 (24.028 sec)
# INFO:tensorflow:global_step/sec: 1.65472
# INFO:tensorflow:loss = 2.87804, step = 201 (60.355 sec)
# INFO:tensorflow:global_step/sec: 1.61783
# INFO:tensorflow:loss = 4.31191, step = 301 (61.967 sec)
# INFO:tensorflow:global_step/sec: 1.64966
# INFO:tensorflow:loss = 3.42767, step = 401 (60.447 sec)
# INFO:tensorflow:global_step/sec: 1.6634
# INFO:tensorflow:loss = 3.81772, step = 501 (60.243 sec)
# INFO:tensorflow:global_step/sec: 1.6246
# INFO:tensorflow:loss = 6.25098, step = 601 (61.491 sec)
# INFO:tensorflow:global_step/sec: 1.6674
# INFO:tensorflow:loss = 5.96651, step = 701 (60.020 sec)
# INFO:tensorflow:global_step/sec: 1.6371
# INFO:tensorflow:loss = 5.67607, step = 801 (61.005 sec)
# INFO:tensorflow:global_step/sec: 1.61534
# INFO:tensorflow:loss = 2.18861, step = 901 (61.938 sec)
# INFO:tensorflow:Saving checkpoints for 939 into C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.7049
# INFO:tensorflow:loss = 4.79265, step = 1001 (141.833 sec)
# INFO:tensorflow:global_step/sec: 2.10301
# INFO:tensorflow:loss = 3.71661, step = 1101 (47.613 sec)
# INFO:tensorflow:global_step/sec: 1.64586
# INFO:tensorflow:loss = 4.17254, step = 1201 (60.681 sec)
# INFO:tensorflow:global_step/sec: 1.63721
# INFO:tensorflow:loss = 0.529462, step = 1301 (61.142 sec)
# INFO:tensorflow:global_step/sec: 1.60384
# INFO:tensorflow:loss = 2.48376, step = 1401 (62.288 sec)
# INFO:tensorflow:global_step/sec: 1.64003
# INFO:tensorflow:loss = 2.22337, step = 1501 (61.054 sec)
# INFO:tensorflow:global_step/sec: 1.61084
# INFO:tensorflow:loss = 3.35778, step = 1601 (62.049 sec)
# INFO:tensorflow:global_step/sec: 1.61561
# INFO:tensorflow:loss = 0.596011, step = 1701 (61.879 sec)
# INFO:tensorflow:global_step/sec: 1.63846
# INFO:tensorflow:loss = 0.887147, step = 1801 (61.080 sec)
# INFO:tensorflow:Saving checkpoints for 1808 into C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.778171
# INFO:tensorflow:loss = 0.956035, step = 1901 (128.460 sec)
# INFO:tensorflow:global_step/sec: 1.63338
# INFO:tensorflow:loss = 5.60976, step = 2001 (61.176 sec)
# INFO:tensorflow:global_step/sec: 1.59905
# INFO:tensorflow:loss = 1.29183, step = 2101 (62.647 sec)
# INFO:tensorflow:global_step/sec: 1.62457
# INFO:tensorflow:loss = 2.2816, step = 2201 (61.430 sec)
# INFO:tensorflow:global_step/sec: 1.63498
# INFO:tensorflow:loss = 2.05923, step = 2301 (61.194 sec)
# INFO:tensorflow:global_step/sec: 1.61762
# INFO:tensorflow:loss = 2.31565, step = 2401 (61.882 sec)
# INFO:tensorflow:global_step/sec: 1.65175
# INFO:tensorflow:loss = 3.56604, step = 2501 (60.620 sec)
# INFO:tensorflow:global_step/sec: 1.63292
# INFO:tensorflow:loss = 6.97399, step = 2601 (61.084 sec)
# INFO:tensorflow:Saving checkpoints for 2675 into C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.612385
# INFO:tensorflow:loss = 4.39925, step = 2701 (163.202 sec)
# INFO:tensorflow:global_step/sec: 3.11903
# INFO:tensorflow:loss = 4.47665, step = 2801 (32.217 sec)
# INFO:tensorflow:global_step/sec: 1.63567
# INFO:tensorflow:loss = 2.18149, step = 2901 (61.090 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.96576.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-20:10:29
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-20:11:29
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.873299, accuracy_baseline = 0.839286, auc = 0.879004, auc_precision_recall = 0.972165, average_loss = 0.29432, global_step = 3000, label/mean = 0.839286, loss = 28.8434, prediction/mean = 0.834164
# Evaluation using Tensorflow evaluate method...Result at folding session: 4 {'auc': 0.87900376, 'prediction/mean': 0.83416355, 'accuracy': 0.8732993, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97216541, 'loss': 28.843401, 'accuracy_baseline': 0.83928573, 'average_loss': 0.29432043}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpldc1geew\model.ckpt-3000
#
# -----Folding Session 4 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.878363165597 Accuracy: 0.873299319728 Error_rate: 0.126700680272
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmptbobo04o
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmptbobo04o', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt.
# INFO:tensorflow:loss = 7.27537, step = 1
# INFO:tensorflow:global_step/sec: 4.2796
# INFO:tensorflow:loss = 3.03549, step = 101 (23.460 sec)
# INFO:tensorflow:global_step/sec: 1.62077
# INFO:tensorflow:loss = 3.32546, step = 201 (61.746 sec)
# INFO:tensorflow:global_step/sec: 1.6575
# INFO:tensorflow:loss = 2.58416, step = 301 (60.347 sec)
# INFO:tensorflow:global_step/sec: 1.58772
# INFO:tensorflow:loss = 2.70498, step = 401 (62.952 sec)
# INFO:tensorflow:global_step/sec: 1.48748
# INFO:tensorflow:loss = 4.06041, step = 501 (67.321 sec)
# INFO:tensorflow:global_step/sec: 1.55849
# INFO:tensorflow:loss = 6.62711, step = 601 (64.055 sec)
# INFO:tensorflow:global_step/sec: 1.65912
# INFO:tensorflow:loss = 2.27826, step = 701 (60.320 sec)
# INFO:tensorflow:global_step/sec: 1.61329
# INFO:tensorflow:loss = 0.295172, step = 801 (61.938 sec)
# INFO:tensorflow:global_step/sec: 1.65547
# INFO:tensorflow:loss = 4.31527, step = 901 (60.546 sec)
# INFO:tensorflow:Saving checkpoints for 912 into C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.785797
# INFO:tensorflow:loss = 8.81737, step = 1001 (127.222 sec)
# INFO:tensorflow:global_step/sec: 1.64199
# INFO:tensorflow:loss = 2.64826, step = 1101 (60.799 sec)
# INFO:tensorflow:global_step/sec: 1.63436
# INFO:tensorflow:loss = 4.18166, step = 1201 (61.430 sec)
# INFO:tensorflow:global_step/sec: 1.61212
# INFO:tensorflow:loss = 2.44422, step = 1301 (61.849 sec)
# INFO:tensorflow:global_step/sec: 1.63022
# INFO:tensorflow:loss = 3.87695, step = 1401 (61.484 sec)
# INFO:tensorflow:global_step/sec: 1.53771
# INFO:tensorflow:loss = 5.21022, step = 1501 (64.858 sec)
# INFO:tensorflow:global_step/sec: 1.63046
# INFO:tensorflow:loss = 1.09562, step = 1601 (61.365 sec)
# INFO:tensorflow:global_step/sec: 1.64065
# INFO:tensorflow:loss = 1.44998, step = 1701 (60.872 sec)
# INFO:tensorflow:Saving checkpoints for 1777 into C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.629379
# INFO:tensorflow:loss = 5.42182, step = 1801 (158.949 sec)
# INFO:tensorflow:global_step/sec: 3.22492
# INFO:tensorflow:loss = 3.82529, step = 1901 (30.993 sec)
# INFO:tensorflow:global_step/sec: 1.64326
# INFO:tensorflow:loss = 2.14913, step = 2001 (60.933 sec)
# INFO:tensorflow:global_step/sec: 1.62283
# INFO:tensorflow:loss = 1.27145, step = 2101 (61.589 sec)
# INFO:tensorflow:global_step/sec: 1.6573
# INFO:tensorflow:loss = 2.13409, step = 2201 (60.261 sec)
# INFO:tensorflow:global_step/sec: 1.65704
# INFO:tensorflow:loss = 1.28972, step = 2301 (60.739 sec)
# INFO:tensorflow:global_step/sec: 1.57643
# INFO:tensorflow:loss = 2.97539, step = 2401 (63.059 sec)
# INFO:tensorflow:global_step/sec: 1.62698
# INFO:tensorflow:loss = 1.94035, step = 2501 (61.557 sec)
# INFO:tensorflow:global_step/sec: 1.60676
# INFO:tensorflow:loss = 0.256698, step = 2601 (62.143 sec)
# INFO:tensorflow:Saving checkpoints for 2645 into C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.696412
# INFO:tensorflow:loss = 1.83266, step = 2701 (143.624 sec)
# INFO:tensorflow:global_step/sec: 2.30342
# INFO:tensorflow:loss = 1.51431, step = 2801 (43.414 sec)
# INFO:tensorflow:global_step/sec: 1.61923
# INFO:tensorflow:loss = 4.80856, step = 2901 (61.742 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.06187.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-21:02:48
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-21:03:46
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.878401, accuracy_baseline = 0.839286, auc = 0.873238, auc_precision_recall = 0.969785, average_loss = 0.299834, global_step = 3000, label/mean = 0.839286, loss = 29.3837, prediction/mean = 0.84101
# Evaluation using Tensorflow evaluate method...Result at folding session: 5 {'auc': 0.87323838, 'prediction/mean': 0.84101021, 'accuracy': 0.87840134, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.96978521, 'loss': 29.383698, 'accuracy_baseline': 0.83928573, 'average_loss': 0.29983366}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmptbobo04o\model.ckpt-3000
#
# -----Folding Session 5 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.873174013498 Accuracy: 0.878401360544 Error_rate: 0.121598639456
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmprxlysulo
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmprxlysulo', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:loss = 7.26281, step = 1
# INFO:tensorflow:global_step/sec: 3.50069
# INFO:tensorflow:loss = 2.58716, step = 101 (28.567 sec)
# INFO:tensorflow:global_step/sec: 1.18139
# INFO:tensorflow:loss = 4.65079, step = 201 (84.602 sec)
# INFO:tensorflow:global_step/sec: 1.32976
# INFO:tensorflow:loss = 1.80303, step = 301 (75.311 sec)
# INFO:tensorflow:global_step/sec: 1.36002
# INFO:tensorflow:loss = 3.2655, step = 401 (73.436 sec)
# INFO:tensorflow:global_step/sec: 1.3622
# INFO:tensorflow:loss = 0.520968, step = 501 (73.488 sec)
# INFO:tensorflow:global_step/sec: 1.40048
# INFO:tensorflow:loss = 4.24103, step = 601 (71.337 sec)
# INFO:tensorflow:global_step/sec: 1.30346
# INFO:tensorflow:loss = 6.96339, step = 701 (76.898 sec)
# INFO:tensorflow:Saving checkpoints for 751 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.550643
# INFO:tensorflow:loss = 3.67992, step = 801 (181.444 sec)
# INFO:tensorflow:global_step/sec: 1.83089
# INFO:tensorflow:loss = 5.79243, step = 901 (54.609 sec)
# INFO:tensorflow:global_step/sec: 1.31856
# INFO:tensorflow:loss = 2.82849, step = 1001 (75.883 sec)
# INFO:tensorflow:global_step/sec: 1.58989
# INFO:tensorflow:loss = 8.55579, step = 1101 (62.962 sec)
# INFO:tensorflow:global_step/sec: 1.59153
# INFO:tensorflow:loss = 0.816125, step = 1201 (62.770 sec)
# INFO:tensorflow:global_step/sec: 1.60233
# INFO:tensorflow:loss = 4.44242, step = 1301 (62.362 sec)
# INFO:tensorflow:global_step/sec: 1.19697
# INFO:tensorflow:loss = 2.18774, step = 1401 (83.693 sec)
# INFO:tensorflow:Saving checkpoints for 1475 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.543849
# INFO:tensorflow:loss = 5.30769, step = 1501 (183.773 sec)
# INFO:tensorflow:global_step/sec: 2.97685
# INFO:tensorflow:loss = 2.10243, step = 1601 (33.624 sec)
# INFO:tensorflow:global_step/sec: 1.24863
# INFO:tensorflow:loss = 2.92614, step = 1701 (79.995 sec)
# INFO:tensorflow:global_step/sec: 1.2136
# INFO:tensorflow:loss = 1.66033, step = 1801 (82.493 sec)
# INFO:tensorflow:global_step/sec: 1.2469
# INFO:tensorflow:loss = 0.700239, step = 1901 (80.109 sec)
# INFO:tensorflow:global_step/sec: 1.14803
# INFO:tensorflow:loss = 1.79114, step = 2001 (87.151 sec)
# INFO:tensorflow:global_step/sec: 1.31649
# INFO:tensorflow:loss = 1.40394, step = 2101 (75.899 sec)
# INFO:tensorflow:Saving checkpoints for 2144 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.679506
# INFO:tensorflow:loss = 1.17799, step = 2201 (147.285 sec)
# INFO:tensorflow:global_step/sec: 2.14797
# INFO:tensorflow:loss = 1.43899, step = 2301 (46.509 sec)
# INFO:tensorflow:global_step/sec: 1.58089
# INFO:tensorflow:loss = 4.14521, step = 2401 (63.334 sec)
# INFO:tensorflow:global_step/sec: 1.1902
# INFO:tensorflow:loss = 3.98416, step = 2501 (84.070 sec)
# INFO:tensorflow:global_step/sec: 1.30487
# INFO:tensorflow:loss = 1.48916, step = 2601 (76.479 sec)
# INFO:tensorflow:global_step/sec: 1.29858
# INFO:tensorflow:loss = 4.77367, step = 2701 (77.049 sec)
# INFO:tensorflow:global_step/sec: 1.32383
# INFO:tensorflow:loss = 1.36019, step = 2801 (75.467 sec)
# INFO:tensorflow:Saving checkpoints for 2886 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.568196
# INFO:tensorflow:loss = 1.21723, step = 2901 (176.006 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt.
# INFO:tensorflow:Loss for final step: 2.62532.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-22:03:50
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-22:04:54
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.888605, accuracy_baseline = 0.839286, auc = 0.902744, auc_precision_recall = 0.978076, average_loss = 0.280874, global_step = 3000, label/mean = 0.839286, loss = 27.5257, prediction/mean = 0.876926
# Evaluation using Tensorflow evaluate method...Result at folding session: 6 {'auc': 0.90274358, 'prediction/mean': 0.87692642, 'accuracy': 0.88860542, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97807574, 'loss': 27.525656, 'accuracy_baseline': 0.83928573, 'average_loss': 0.28087404}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmprxlysulo\model.ckpt-3000
#
# -----Folding Session 6 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.903783578049 Accuracy: 0.888605442177 Error_rate: 0.111394557823
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp7u5u4tl4', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt.
# INFO:tensorflow:loss = 7.30387, step = 1
# INFO:tensorflow:global_step/sec: 3.99933
# INFO:tensorflow:loss = 1.90994, step = 101 (25.241 sec)
# INFO:tensorflow:global_step/sec: 1.43394
# INFO:tensorflow:loss = 0.371654, step = 201 (69.657 sec)
# INFO:tensorflow:global_step/sec: 1.57829
# INFO:tensorflow:loss = 2.81456, step = 301 (63.438 sec)
# INFO:tensorflow:global_step/sec: 1.62119
# INFO:tensorflow:loss = 6.73034, step = 401 (61.748 sec)
# INFO:tensorflow:global_step/sec: 1.61122
# INFO:tensorflow:loss = 1.29698, step = 501 (62.304 sec)
# INFO:tensorflow:global_step/sec: 1.50768
# INFO:tensorflow:loss = 3.09511, step = 601 (65.913 sec)
# INFO:tensorflow:global_step/sec: 1.54159
# INFO:tensorflow:loss = 1.51869, step = 701 (64.915 sec)
# INFO:tensorflow:global_step/sec: 1.53734
# INFO:tensorflow:loss = 1.97063, step = 801 (65.032 sec)
# INFO:tensorflow:Saving checkpoints for 887 into C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.599386
# INFO:tensorflow:loss = 2.20223, step = 901 (166.759 sec)
# INFO:tensorflow:global_step/sec: 3.48861
# INFO:tensorflow:loss = 1.27783, step = 1001 (28.758 sec)
# INFO:tensorflow:global_step/sec: 1.54826
# INFO:tensorflow:loss = 1.57899, step = 1101 (64.604 sec)
# INFO:tensorflow:global_step/sec: 1.47409
# INFO:tensorflow:loss = 2.09618, step = 1201 (67.916 sec)
# INFO:tensorflow:global_step/sec: 1.56635
# INFO:tensorflow:loss = 1.37864, step = 1301 (63.702 sec)
# INFO:tensorflow:global_step/sec: 1.5694
# INFO:tensorflow:loss = 1.54434, step = 1401 (63.812 sec)
# INFO:tensorflow:global_step/sec: 1.54105
# INFO:tensorflow:loss = 0.530288, step = 1501 (64.859 sec)
# INFO:tensorflow:global_step/sec: 1.54828
# INFO:tensorflow:loss = 0.621915, step = 1601 (64.541 sec)
# INFO:tensorflow:global_step/sec: 1.52414
# INFO:tensorflow:loss = 4.93932, step = 1701 (65.611 sec)
# INFO:tensorflow:Saving checkpoints for 1708 into C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.71046
# INFO:tensorflow:loss = 3.23368, step = 1801 (140.629 sec)
# INFO:tensorflow:global_step/sec: 1.54667
# INFO:tensorflow:loss = 1.878, step = 1901 (64.686 sec)
# INFO:tensorflow:global_step/sec: 1.55894
# INFO:tensorflow:loss = 5.246, step = 2001 (64.474 sec)
# INFO:tensorflow:global_step/sec: 1.5972
# INFO:tensorflow:loss = 2.22739, step = 2101 (62.406 sec)
# INFO:tensorflow:global_step/sec: 1.4894
# INFO:tensorflow:loss = 3.43237, step = 2201 (67.063 sec)
# INFO:tensorflow:global_step/sec: 1.50226
# INFO:tensorflow:loss = 5.07304, step = 2301 (66.598 sec)
# INFO:tensorflow:global_step/sec: 1.55507
# INFO:tensorflow:loss = 0.88185, step = 2401 (64.337 sec)
# INFO:tensorflow:global_step/sec: 1.54106
# INFO:tensorflow:loss = 3.85761, step = 2501 (64.797 sec)
# INFO:tensorflow:Saving checkpoints for 2517 into C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.681902
# INFO:tensorflow:loss = 2.25697, step = 2601 (146.633 sec)
# INFO:tensorflow:global_step/sec: 1.40339
# INFO:tensorflow:loss = 4.05827, step = 2701 (71.365 sec)
# INFO:tensorflow:global_step/sec: 1.50527
# INFO:tensorflow:loss = 3.97849, step = 2801 (66.433 sec)
# INFO:tensorflow:global_step/sec: 1.52371
# INFO:tensorflow:loss = 3.32321, step = 2901 (65.645 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.25703.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-22:59:54
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-23:00:54
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.87585, accuracy_baseline = 0.839286, auc = 0.900321, auc_precision_recall = 0.977778, average_loss = 0.279523, global_step = 3000, label/mean = 0.839286, loss = 27.3932, prediction/mean = 0.869385
# Evaluation using Tensorflow evaluate method...Result at folding session: 7 {'auc': 0.90032059, 'prediction/mean': 0.86938518, 'accuracy': 0.87585032, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.9777782, 'loss': 27.393209, 'accuracy_baseline': 0.83928573, 'average_loss': 0.27952254}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp7u5u4tl4\model.ckpt-3000
#
# -----Folding Session 7 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.901775998027 Accuracy: 0.875850340136 Error_rate: 0.124149659864
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpgwrye28m', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt.
# INFO:tensorflow:loss = 7.18349, step = 1
# INFO:tensorflow:global_step/sec: 4.00879
# INFO:tensorflow:loss = 4.54603, step = 101 (25.255 sec)
# INFO:tensorflow:global_step/sec: 1.60525
# INFO:tensorflow:loss = 2.83374, step = 201 (62.092 sec)
# INFO:tensorflow:global_step/sec: 1.50488
# INFO:tensorflow:loss = 1.64783, step = 301 (66.575 sec)
# INFO:tensorflow:global_step/sec: 1.58567
# INFO:tensorflow:loss = 9.36514, step = 401 (62.971 sec)
# INFO:tensorflow:global_step/sec: 1.61962
# INFO:tensorflow:loss = 2.62938, step = 501 (61.696 sec)
# INFO:tensorflow:global_step/sec: 1.47349
# INFO:tensorflow:loss = 1.74326, step = 601 (67.929 sec)
# INFO:tensorflow:global_step/sec: 1.57534
# INFO:tensorflow:loss = 2.39913, step = 701 (63.431 sec)
# INFO:tensorflow:global_step/sec: 1.56701
# INFO:tensorflow:loss = 3.67139, step = 801 (63.847 sec)
# INFO:tensorflow:Saving checkpoints for 890 into C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.590143
# INFO:tensorflow:loss = 0.844736, step = 901 (169.491 sec)
# INFO:tensorflow:global_step/sec: 4.02565
# INFO:tensorflow:loss = 1.88178, step = 1001 (24.753 sec)
# INFO:tensorflow:global_step/sec: 1.45473
# INFO:tensorflow:loss = 1.65107, step = 1101 (68.741 sec)
# INFO:tensorflow:global_step/sec: 1.57797
# INFO:tensorflow:loss = 3.45533, step = 1201 (63.372 sec)
# INFO:tensorflow:global_step/sec: 1.56748
# INFO:tensorflow:loss = 4.43256, step = 1301 (63.875 sec)
# INFO:tensorflow:global_step/sec: 1.5464
# INFO:tensorflow:loss = 1.58247, step = 1401 (64.776 sec)
# INFO:tensorflow:global_step/sec: 1.58954
# INFO:tensorflow:loss = 0.341069, step = 1501 (62.724 sec)
# INFO:tensorflow:global_step/sec: 1.56987
# INFO:tensorflow:loss = 2.22117, step = 1601 (63.700 sec)
# INFO:tensorflow:global_step/sec: 1.5485
# INFO:tensorflow:loss = 2.87799, step = 1701 (64.563 sec)
# INFO:tensorflow:Saving checkpoints for 1722 into C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.681757
# INFO:tensorflow:loss = 4.23103, step = 1801 (146.727 sec)
# INFO:tensorflow:global_step/sec: 1.66212
# INFO:tensorflow:loss = 2.53216, step = 1901 (60.195 sec)
# INFO:tensorflow:global_step/sec: 1.48317
# INFO:tensorflow:loss = 2.59656, step = 2001 (67.376 sec)
# INFO:tensorflow:global_step/sec: 1.5565
# INFO:tensorflow:loss = 2.85691, step = 2101 (65.559 sec)
# INFO:tensorflow:global_step/sec: 1.50195
# INFO:tensorflow:loss = 3.7804, step = 2201 (65.267 sec)
# INFO:tensorflow:global_step/sec: 1.53946
# INFO:tensorflow:loss = 5.91353, step = 2301 (64.864 sec)
# INFO:tensorflow:global_step/sec: 1.50286
# INFO:tensorflow:loss = 4.72314, step = 2401 (66.634 sec)
# INFO:tensorflow:global_step/sec: 1.49877
# INFO:tensorflow:loss = 3.37341, step = 2501 (66.659 sec)
# INFO:tensorflow:Saving checkpoints for 2517 into C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.695829
# INFO:tensorflow:loss = 3.59032, step = 2601 (143.713 sec)
# INFO:tensorflow:global_step/sec: 1.55177
# INFO:tensorflow:loss = 2.71841, step = 2701 (64.506 sec)
# INFO:tensorflow:global_step/sec: 1.51616
# INFO:tensorflow:loss = 0.28414, step = 2801 (65.991 sec)
# INFO:tensorflow:global_step/sec: 1.28882
# INFO:tensorflow:loss = 0.635597, step = 2901 (77.576 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.85473.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-18-23:55:55
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-18-23:57:09
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.873299, accuracy_baseline = 0.839286, auc = 0.887163, auc_precision_recall = 0.975247, average_loss = 0.291777, global_step = 3000, label/mean = 0.839286, loss = 28.5941, prediction/mean = 0.806987
# Evaluation using Tensorflow evaluate method...Result at folding session: 8 {'auc': 0.8871628, 'prediction/mean': 0.80698705, 'accuracy': 0.8732993, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97524709, 'loss': 28.594149, 'accuracy_baseline': 0.83928573, 'average_loss': 0.29177704}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpgwrye28m\model.ckpt-3000
#
# -----Folding Session 8 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.887160064972 Accuracy: 0.873299319728 Error_rate: 0.126700680272
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp33va6_su
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_save_checkpoints_steps': None, '_keep_checkpoint_max': 5, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp33va6_su', '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt.
# INFO:tensorflow:loss = 7.17943, step = 1
# INFO:tensorflow:global_step/sec: 3.84258
# INFO:tensorflow:loss = 5.05211, step = 101 (26.212 sec)
# INFO:tensorflow:global_step/sec: 1.53592
# INFO:tensorflow:loss = 3.04675, step = 201 (65.061 sec)
# INFO:tensorflow:global_step/sec: 1.51689
# INFO:tensorflow:loss = 8.65438, step = 301 (65.862 sec)
# INFO:tensorflow:global_step/sec: 1.53972
# INFO:tensorflow:loss = 5.0385, step = 401 (64.994 sec)
# INFO:tensorflow:global_step/sec: 1.57413
# INFO:tensorflow:loss = 4.31101, step = 501 (63.590 sec)
# INFO:tensorflow:global_step/sec: 1.54639
# INFO:tensorflow:loss = 2.36359, step = 601 (64.573 sec)
# INFO:tensorflow:global_step/sec: 1.56387
# INFO:tensorflow:loss = 6.92313, step = 701 (64.038 sec)
# INFO:tensorflow:global_step/sec: 1.42504
# INFO:tensorflow:loss = 3.34383, step = 801 (70.142 sec)
# INFO:tensorflow:Saving checkpoints for 869 into C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.615467
# INFO:tensorflow:loss = 2.83115, step = 901 (162.445 sec)
# INFO:tensorflow:global_step/sec: 2.68146
# INFO:tensorflow:loss = 2.52622, step = 1001 (37.201 sec)
# INFO:tensorflow:global_step/sec: 1.54087
# INFO:tensorflow:loss = 5.97747, step = 1101 (64.992 sec)
# INFO:tensorflow:global_step/sec: 1.48471
# INFO:tensorflow:loss = 5.45243, step = 1201 (67.497 sec)
# INFO:tensorflow:global_step/sec: 1.48142
# INFO:tensorflow:loss = 0.566553, step = 1301 (67.406 sec)
# INFO:tensorflow:global_step/sec: 1.44614
# INFO:tensorflow:loss = 3.19746, step = 1401 (68.994 sec)
# INFO:tensorflow:global_step/sec: 1.5276
# INFO:tensorflow:loss = 2.13313, step = 1501 (65.587 sec)
# INFO:tensorflow:global_step/sec: 1.57233
# INFO:tensorflow:loss = 1.47022, step = 1601 (63.928 sec)
# INFO:tensorflow:Saving checkpoints for 1675 into C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.597662
# INFO:tensorflow:loss = 1.52964, step = 1701 (166.928 sec)
# INFO:tensorflow:global_step/sec: 2.9107
# INFO:tensorflow:loss = 2.02434, step = 1801 (34.434 sec)
# INFO:tensorflow:global_step/sec: 1.51524
# INFO:tensorflow:loss = 2.3633, step = 1901 (66.027 sec)
# INFO:tensorflow:global_step/sec: 1.52671
# INFO:tensorflow:loss = 5.82467, step = 2001 (65.516 sec)
# INFO:tensorflow:global_step/sec: 1.49357
# INFO:tensorflow:loss = 1.68335, step = 2101 (66.891 sec)
# INFO:tensorflow:global_step/sec: 1.56795
# INFO:tensorflow:loss = 1.40638, step = 2201 (63.840 sec)
# INFO:tensorflow:global_step/sec: 1.52741
# INFO:tensorflow:loss = 2.42656, step = 2301 (65.470 sec)
# INFO:tensorflow:global_step/sec: 1.55592
# INFO:tensorflow:loss = 6.14508, step = 2401 (64.224 sec)
# INFO:tensorflow:Saving checkpoints for 2484 into C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt.
# INFO:tensorflow:global_step/sec: 0.585716
# INFO:tensorflow:loss = 2.89713, step = 2501 (170.669 sec)
# INFO:tensorflow:global_step/sec: 3.23186
# INFO:tensorflow:loss = 0.904948, step = 2601 (30.973 sec)
# INFO:tensorflow:global_step/sec: 1.51998
# INFO:tensorflow:loss = 0.783504, step = 2701 (65.853 sec)
# INFO:tensorflow:global_step/sec: 1.46118
# INFO:tensorflow:loss = 4.94777, step = 2801 (68.438 sec)
# INFO:tensorflow:global_step/sec: 1.53424
# INFO:tensorflow:loss = 1.11453, step = 2901 (65.132 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.90098.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-00:50:54
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-00:52:00
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.873299, accuracy_baseline = 0.839286, auc = 0.875734, auc_precision_recall = 0.972046, average_loss = 0.2966, global_step = 3000, label/mean = 0.839286, loss = 29.0668, prediction/mean = 0.847576
# Evaluation using Tensorflow evaluate method...Result at folding session: 9 {'auc': 0.87573379, 'prediction/mean': 0.84757626, 'accuracy': 0.8732993, 'label/mean': 0.83928573, 'global_step': 3000, 'auc_precision_recall': 0.97204649, 'loss': 29.066809, 'accuracy_baseline': 0.83928573, 'average_loss': 0.29660007}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp33va6_su\model.ckpt-3000
#
# -----Folding Session 9 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.875409423028 Accuracy: 0.873299319728 Error_rate: 0.126700680272
#
# -----k-fold summary:-----
# Evaluation Errors: [0.11394557823129252, 0.11224489795918367, 0.13010204081632654, 0.11224489795918367, 0.12670068027210885, 0.12159863945578231, 0.11139455782312925, 0.12414965986394558, 0.12670068027210885, 0.12670068027210885]
# Evaluation error rate average: 0.120578231293
# Model's standard deviation: 0.00695825596785
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpg_q48srh\model.ckpt-3000
#
# Final Test>> AUC: 0.895315976705 Accuracy: 0.882653061224 Final Error_rate: 0.117346938776
# F-measure: 0.932761644904 Accuracy: 0.882653061224 Recall: 0.96961102107 Precision: 0.898610589561 False Positive Rate: 0.572033898305 False Negative Rate: 0.0303889789303
# Confusion matrix, without normalization
# [[ 202  270]
#  [  75 2393]]
# Normalized confusion matrix
# [[ 0.43  0.57]
#  [ 0.03  0.97]]
