# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.model_selection import StratifiedKFold
from sklearn import preprocessing
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import itertools
from sklearn import metrics

# %%
# %matplotlib inline

# %%
data_source_path = "F:\deep lerning project\data\FinalData\d3.wordpress_phpbb23.label.normalized_density.csv"

#test_output_file = open("F:\\deep lerning project\\data\\FinalData\\hidden_layer_test_output.txt", mode = 'w')# for testing layers...delete if not needed
# for slicing the necessary columns from the source file...directly related to source data columns
label_col_start = 0
feature_col_start = 8

# I have many labels but here is the col that contains 'changed_ever_class'
class_label_col = 2 # class is in col 2

# %%
# Some configurations
# set only one to true...
select_model_based_on_loss = False
select_model_based_on_error_rate = False
select_model_based_on_auc = True
#---------------------------------

# %%
def get_feature_and_label():
    # read the data file
    # return features and labels
    
    file_change_df = pd.read_csv(data_source_path)
    
    X = file_change_df.iloc[:,feature_col_start:]
    #print(X.shape)
    #print(X)
    
    y_all_labels = file_change_df.iloc[:,label_col_start:feature_col_start] # all available labels 
    #print(type(y_all_labels))
    #print(y_all_labels)
    y = y_all_labels.iloc[:,class_label_col] # take the changed_ever col only
    y = pd.Series.to_frame(y) # y is a series...convert it to dataframe again--- not necessary...series will do
    #print(y.head())
    #print(type(y))
    
    #print(y.shape)
    #print(y)
    
    return X, y

# %%
def get_train_test_split(X, y, nsplits = 1, testSize = 0.2):

    sss = StratifiedShuffleSplit(n_splits=nsplits, test_size=testSize)
    
    for train_index, test_index in sss.split(X, y):
        X_train, X_test = X.iloc[train_index], X.iloc[test_index] # X.iloc[index] because its pandas dataframe.so..iloc
        y_train, y_test = y.iloc[train_index], y.iloc[test_index]
        
    return X_train, y_train, X_test, y_test

# %%
def show_data_statistics(X_train, y_train, X_test, y_test):
    #print(X_train.shape)
    #print(y_train.shape)
    #print(X_test.shape)
    #print(y_test.shape)
    #print(type(y_test))
    print("y_train Statistics:\n", y_train.describe())
    print("y_test Statistics:\n",y_test.describe())
    
    plt.hist(y_train)
    plt.hist(y_test)

# %%
def get_feature_cols(X):
    feature_cols = []
    i=0

    for col in X.columns:
        #if is_numeric_dtype(X[col]): #is_numeric_dtype is pandas function
        feature_cols.extend([tf.feature_column.numeric_column(col)])
        i = i+1
        
    print("Total features column names converted to tf.feature_column.numeric_column('col_name') = ", i)
    return feature_cols

# %%
def train_model(model, X_train, y_train):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
        x=X_train,
        y=y_train,
        batch_size=10,
        num_epochs=3000,
        shuffle=True)    
    
    model = model.train(input_fn=input_func,steps=3000)
    
    return model

# %%
def evaluate_model(model, X_test, y_test):
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    results = model.evaluate(input_func)
    #print(results)
    
    return results

# %%
def prediction(model, X, y):
    
    prediction_list = []
    y_proba_positive_class_list = [] # positive class probability of each element for calculating AUC
    
    input_func = tf.estimator.inputs.pandas_input_fn(
      x=X,
      batch_size=100,
      num_epochs=1,
      shuffle=False)
    
    y_predicted = model.predict(input_func)
    
    for elem in y_predicted: # y_predicted is a generator object holds a memory address...read all values from there
        #print("type elem:", type(elem))
        #print("elem:", elem)
        elem_probabilities = np.array(elem['probabilities'])
        #print("Elem probabilities of each class:", elem_probabilities)
        
        y_proba_positive_class_list.append(elem_probabilities[1]) # class 1 is the positive class, its index is 1
        #print("prob_list_now:", elem_positive_class_proba_list)
        
        elem_class = np.argmax(elem_probabilities) # one probable class based on the index that contain max value
        #print("probable class:",elem_class)
        
        prediction_list.append(elem_class)
        
    
    # assign prediction list to y_predicted for consistent name
    y_predicted = np.array(prediction_list)
    
    #print("y_predicted_shape:", y_predicted.shape, "val:", y_predicted)
    #print("y_type:", type(y),"y shape:", y.shape, "val:", y)
    
    #error_rate = sum(y_predicted != np.array(y)/len(y_predicted))
    
    #print(list(y_predicted))
    
    y = np.array(y) # convert y data to np array
    r,c = y.shape
    #print("y- r,c:",r,c)
    y = y.reshape(r) # change the shape of y to numpy [row,]
    #print("y-shape:", y.shape)
    
    
    '''
    print("before converting to list y_predicted:", y_predicted)
    
    y_predicted = list(y_predicted)
    print("y_predicted:", y_predicted)
    
    y_predicted = np.array(y_predicted)
    print("after converting to nparray y_predicted:", y_predicted, "shape:", y_predicted.shape)
    
    y= np.array(y)
    r,c = y.shape
    print("y- r,c:",r,c)
    y = y.reshape(r)
    print("y-shape:", y.shape)
    '''
    
    error_rate = sum(y_predicted != y)/len(y_predicted) # sum needs the operands in np array of shape [row,]
    
    return y_predicted, error_rate, y_proba_positive_class_list

# %%
def get_normalized_train_data(X_train):
    #Unused function---Normalization is done separately
    #print(type(X_train))
    #print(X_train.head())
    saved_cols = X_train.columns # save the columns names..scaling change the pandas frame to numpy..need to restore
    saved_index = list(X_train.index) # # scaling changes pandas X indices..need to restore to match with y data indices
    #print("saved_index", saved_index)
    
    min_max_scaler = preprocessing.MinMaxScaler()
    
    scaled_X_train = min_max_scaler.fit_transform(X_train)
    scaled_X_train = pd.DataFrame(scaled_X_train, index=saved_index, columns=saved_cols)# restore the column names

    #print(scaled_X_train.head())
    return scaled_X_train

# %%
def get_random_sample(X, y, n_sample = 1):
    n = np.arange(X.shape[0]) # generate numbers equal to the max no of rows in the X df
    if n_sample>len(n):
        print("You have asked", n_sample, " samples, but the training data has", len(n), " rows. Returning 1 sample...")
        n_sample = 1
        
    np.random.shuffle(n) # shuffle all the numbers representing row index
    index = n[0:n_sample] # take the numbers from 0 to given sample
    
    X_sample = X.iloc[index]
    y_sample = y.iloc[index]
    
    #print(X_sample.head())
    #print(y_sample.head())
    
    return X_sample, y_sample

# %%
def show_evaluation_error_report(eval_error_rates):
    
    eval_error_rate_avg = sum(eval_error_rates)/len(eval_error_rates)
    model_std = np.std(eval_error_rates)
    
    print("Evaluation Errors:", eval_error_rates)
    print('Evaluation error rate average:', eval_error_rate_avg, '\nModel\'s standard deviation:', model_std)

# %%
def calculate_performance_metrics(cnf_matrix):
    
    TP = cnf_matrix[1,1]
    TN = cnf_matrix[0,0]
    FP = cnf_matrix[0,1]
    FN = cnf_matrix[1,0]
    
    
    # Sensitivity, hit rate, recall, or true positive rate
    TPR_recall = TP/(TP+FN) # Recall
    # Specificity or true negative rate
    TNR = TN/(TN+FP) # **
    # Precision or positive predictive value
    PPV_precision = TP/(TP+FP) # precision
    # Negative predictive value
    NPV = TN/(TN+FN) #**
    # Fall out or false positive rate
    FPR_false_positive = FP/(FP+TN)
    # False negative rate
    FNR_false_negative = FN/(TP+FN)
    # False discovery rate
    FDR = FP/(TP+FP) # **

    # Overall accuracy
    accuracy = (TP+TN)/(TP+FP+FN+TN)
    f_measure = 2/((1.0/TPR_recall) + (1.0/PPV_precision)) #https://en.wikipedia.org/wiki/F1_score
    
    # ** some extra values are calculated but not returned
    return TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
def get_roc_auc(y, y_proba_positive_class_list):
    
    y = y.as_matrix() # convert series data to numpy array
    
    auc = metrics.roc_auc_score(y, y_proba_positive_class_list)
    #print("Auc:", auc)
    
    '''
    #This one also works but not needed
    fpr, tpr, thresholds = metrics.roc_curve(y, elem_positive_class_proba_list)
    auc2 = metrics.auc(fpr, tpr)
    print("AUC2:", auc2, "fpr:", fpr, "tpr:", tpr)
    '''
    return auc

# %%
def get_cnf_matrix_prf_metrics(y, y_predicted):
    
    y = y.values.tolist() # convert pandas data to list
    #print(">>>>>type_y:", type(y), "val:", y)
    
    y = list(np.array(y).flat) # when converted to list panda gives [[values], [values]]...convert them to flat list[]
    #print("----------type_y_f:", type(y), "val:", y)
    
    
    y_predicted = list(y_predicted)
    #print(">>>>>>type_y_predicted:", type(y_predicted), "val:", y_predicted)
    
    cnf_matrix = confusion_matrix(y, y_predicted)
    
    #print("conf matrix:", cnf_matrix)
    # Calculate performane metrics
    TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = calculate_performance_metrics(cnf_matrix)
    
    return cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure

# %%
def show_confusion_matrix(cnf_matrix, class_names):
    # show cmap of confusion metrics
    np.set_printoptions(precision=2) # settings for printing floating point values
    
    # Plot non-normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names,
                          title='Confusion matrix, without normalization')

    # Plot normalized confusion matrix
    plt.figure()
    plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                          title='Normalized confusion matrix')

    plt.show()

# %%
def main():
    
    X, y = get_feature_and_label()
    X_train_0, y_train_0, X_test_final, y_test_final = get_train_test_split(X,y) #get_train_test_split(X, y, nsplits = 1, testSize = 0.2)

    #show_data_statistics("---Train-Test Statistics---",X_train, y_train, X_test, y_test)
    #print(type(X))
    feature_cols = get_feature_cols(X_train_0)
    #print(feature_cols)

    # start k-fold cross validation and find the best model with the minimum loss during evaluation
    
    min_loss = float('inf')
    min_error_rate = float("inf")
    max_auc = float("-inf")

    folding_session = 0
    eval_error_rates = []
    
    sss = StratifiedShuffleSplit(n_splits=10) #stratifiedkfold generates error for y_train_0 and doesn't work if y multi-labe
    
    for train_index, eval_index in sss.split(X_train_0, y_train_0):

        X_train, X_eval = X_train_0.iloc[train_index], X_train_0.iloc[eval_index]  # iloc[index] because X is a pandas dataframe
        y_train, y_eval = y_train_0.iloc[train_index], y_train_0.iloc[eval_index]
        

        #X_train = get_normalized_train_data(X_train) # min-max standardization
        #print(X_train.head())
        
        # Add layers in this list if more layer settings are needed
        hidden_layers_units = [
            [1022, 511, 255, 128]
        ]
        
        for my_hidden_units in hidden_layers_units:
            print("Hidden Settings:", my_hidden_units)
            #create a new estimator model

            file_change_prediction_model = tf.estimator.DNNClassifier(
                                                                    hidden_units = my_hidden_units,
                                                                    feature_columns = feature_cols, 
                                                                    n_classes=2, 
                                                                    activation_fn = tf.nn.relu)

            #print("new:", file_change_prediction_model)    

            #train the model
            file_change_prediction_model = train_model(file_change_prediction_model, X_train, y_train)
            #print("ret:", file_change_prediction_model)

            #evaluate the trained model
            evaluation_res = evaluate_model(file_change_prediction_model, X_eval, y_eval)
            print("Evaluation using Tensorflow evaluate method...Result at folding session:", folding_session, evaluation_res,"\n\n")
            
            # Do my own evaluation using the trained model in this folding session using evaluation data
            y_predicted, error_rate, y_proba_positive_class_list = prediction(file_change_prediction_model, X_eval, y_eval)
            eval_error_rates.append(error_rate) # error_rate of current folding session
            
            # calculate auc
            auc_evaluation = get_roc_auc(y_eval, y_proba_positive_class_list)

            #----
            #print("\nHidden Settings:", my_hidden_units, file=test_output_file)
            #print('\nFolding Session', folding_session,"AUC:",auc_validation,"Accuracy:", 1-error_rate, 'Error_rate:', error_rate, file=test_output_file)
            print('\n-----Folding Session', folding_session, "Hidden Settings:", my_hidden_units, "-----\nAUC:",auc_evaluation, "Accuracy:", 1-error_rate, 'Error_rate:', error_rate)
    
            #----
            #select the best model using the tensorflow evaluation result
            if select_model_based_on_loss:
                if evaluation_res['loss'] < min_loss:
                    best_model = file_change_prediction_model
                    min_loss = evaluation_res['loss']
                    print("Selecting model based on min_loss.")
    
            # select the best model based on calculated error rate
            if select_model_based_on_error_rate:
                if error_rate < min_error_rate:
                    best_model = file_change_prediction_model # save the best model
                    min_error_rate = error_rate # update the min_error_rate
                    print("Selecting model based on min_error_rate.")
                
            if select_model_based_on_auc:
                if auc_evaluation > max_auc:
                    best_model = file_change_prediction_model # save the best model
                    max_auc = auc_evaluation # update the max_auc
                    print("Selecting model based on max_auc.")

            #Take the next fold in the loop
        folding_session = folding_session + 1
        #break # remove it later for k-fold...now just one fold    
    
    #============================================
    
    print("\n-----k-fold summary:-----")
    k_fold_eval_error_rates = eval_error_rates # for naming consistency with other models
    show_evaluation_error_report(k_fold_eval_error_rates) 
    
    # see the evaluation result using the best model and some random sample from the used training data
    #X_eval, y_eval = get_random_sample(X_train_0,y_train_0, n_sample = 1000)
    #test_res = evaluate_model(best_model, X_eval, y_eval)
    #print("A random evaluation of the model:\n", test_res)
    
    # Do final test using tensorflow function
    #test_res = evaluate_model(best_model, X_test_final, y_test_final)
    #print("Final performance with the best model and test data:", test_res)
    
    #Everything finished I have got the best model and now want to get the final evaluation in my format
    #----------------------------------------------------------------------------------------------------
    #predict using the best model
    y_predicted, error_rate, y_proba_positive_class_list = prediction(best_model, X_test_final, y_test_final)
    #print("shape of x test final:", X_test_final)
    
    # calculate auc
    auc_final = get_roc_auc(y_test_final, y_proba_positive_class_list)
    print("\nFinal Test>> AUC:", auc_final, "Accuracy:", 1-error_rate, "Final Error_rate:", error_rate)
    
    cnf_matrix, TPR_recall, PPV_precision, FPR_false_positive, FNR_false_negative, accuracy, f_measure = get_cnf_matrix_prf_metrics(y_test_final, y_predicted)
    print("F-measure:", f_measure, "Accuracy:",accuracy, "Recall:", TPR_recall, "Precision:", PPV_precision, "False Positive Rate:", FPR_false_positive, "False Negative Rate:", FNR_false_negative)
    
    class_names = ['0','1'] # class names in order.. 1st index for class whose label is 0, 2nd index for class whose label is 1......
    show_confusion_matrix(cnf_matrix, class_names)

# %%
main()
# Out:
# Total features column names converted to tf.feature_column.numeric_column('col_name') =  1021
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp236q1fvd', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd\model.ckpt.
# INFO:tensorflow:loss = 6.92256, step = 1
# INFO:tensorflow:global_step/sec: 8.93859
# INFO:tensorflow:loss = 6.55428, step = 101 (11.360 sec)
# INFO:tensorflow:global_step/sec: 3.46869
# INFO:tensorflow:loss = 8.37504, step = 201 (28.782 sec)
# INFO:tensorflow:global_step/sec: 3.36619
# INFO:tensorflow:loss = 1.26177, step = 301 (29.801 sec)
# INFO:tensorflow:global_step/sec: 3.15607
# INFO:tensorflow:loss = 3.51385, step = 401 (31.607 sec)
# INFO:tensorflow:global_step/sec: 3.37571
# INFO:tensorflow:loss = 1.86629, step = 501 (29.654 sec)
# INFO:tensorflow:global_step/sec: 3.34912
# INFO:tensorflow:loss = 1.64585, step = 601 (29.859 sec)
# INFO:tensorflow:global_step/sec: 3.40461
# INFO:tensorflow:loss = 5.78324, step = 701 (29.403 sec)
# INFO:tensorflow:global_step/sec: 3.21595
# INFO:tensorflow:loss = 8.31236, step = 801 (31.001 sec)
# INFO:tensorflow:global_step/sec: 3.41075
# INFO:tensorflow:loss = 3.40186, step = 901 (29.350 sec)
# INFO:tensorflow:global_step/sec: 3.40919
# INFO:tensorflow:loss = 5.26502, step = 1001 (29.332 sec)
# INFO:tensorflow:global_step/sec: 3.23883
# INFO:tensorflow:loss = 3.40778, step = 1101 (30.891 sec)
# INFO:tensorflow:global_step/sec: 3.25501
# INFO:tensorflow:loss = 3.4025, step = 1201 (30.628 sec)
# INFO:tensorflow:global_step/sec: 3.24312
# INFO:tensorflow:loss = 5.60686, step = 1301 (30.897 sec)
# INFO:tensorflow:global_step/sec: 2.93024
# INFO:tensorflow:loss = 5.60511, step = 1401 (34.018 sec)
# INFO:tensorflow:global_step/sec: 3.24943
# INFO:tensorflow:loss = 1.89937, step = 1501 (30.947 sec)
# INFO:tensorflow:global_step/sec: 3.30604
# INFO:tensorflow:loss = 3.10633, step = 1601 (30.232 sec)
# INFO:tensorflow:global_step/sec: 3.49448
# INFO:tensorflow:loss = 3.42257, step = 1701 (28.617 sec)
# INFO:tensorflow:global_step/sec: 3.37084
# INFO:tensorflow:loss = 2.68105, step = 1801 (29.619 sec)
# INFO:tensorflow:global_step/sec: 3.35192
# INFO:tensorflow:loss = 7.84095, step = 1901 (29.865 sec)
# INFO:tensorflow:Saving checkpoints for 1930 into C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.45292
# INFO:tensorflow:loss = 3.54557, step = 2001 (68.827 sec)
# INFO:tensorflow:global_step/sec: 4.02371
# INFO:tensorflow:loss = 2.30909, step = 2101 (24.775 sec)
# INFO:tensorflow:global_step/sec: 3.17241
# INFO:tensorflow:loss = 5.268, step = 2201 (31.631 sec)
# INFO:tensorflow:global_step/sec: 3.49135
# INFO:tensorflow:loss = 1.83469, step = 2301 (28.595 sec)
# INFO:tensorflow:global_step/sec: 3.25856
# INFO:tensorflow:loss = 3.04266, step = 2401 (30.798 sec)
# INFO:tensorflow:global_step/sec: 2.96528
# INFO:tensorflow:loss = 5.5327, step = 2501 (33.505 sec)
# INFO:tensorflow:global_step/sec: 3.36762
# INFO:tensorflow:loss = 1.24485, step = 2601 (29.835 sec)
# INFO:tensorflow:global_step/sec: 3.03008
# INFO:tensorflow:loss = 4.77842, step = 2701 (32.971 sec)
# INFO:tensorflow:global_step/sec: 3.01394
# INFO:tensorflow:loss = 1.22743, step = 2801 (33.289 sec)
# INFO:tensorflow:global_step/sec: 3.26521
# INFO:tensorflow:loss = 4.61909, step = 2901 (30.485 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.80235.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-15:54:00
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-15:54:29
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.859694, accuracy_baseline = 0.839286, auc = 0.830444, auc_precision_recall = 0.955753, average_loss = 0.336765, global_step = 3000, label/mean = 0.839286, loss = 33.0029, prediction/mean = 0.816836
# Evaluation using Tensorflow evaluate method...Result at folding session: 0 {'auc': 0.83044386, 'loss': 33.002926, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.33676457, 'accuracy': 0.85969388, 'global_step': 3000, 'prediction/mean': 0.8168363, 'auc_precision_recall': 0.95575339}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp236q1fvd\model.ckpt-3000
#
# -----Folding Session 0 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.830942463668 Accuracy: 0.859693877551 Error_rate: 0.140306122449
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp0eh6uys1', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1\model.ckpt.
# INFO:tensorflow:loss = 6.92166, step = 1
# INFO:tensorflow:global_step/sec: 8.54792
# INFO:tensorflow:loss = 5.77711, step = 101 (11.886 sec)
# INFO:tensorflow:global_step/sec: 3.37316
# INFO:tensorflow:loss = 6.45342, step = 201 (29.583 sec)
# INFO:tensorflow:global_step/sec: 3.51163
# INFO:tensorflow:loss = 5.06475, step = 301 (28.586 sec)
# INFO:tensorflow:global_step/sec: 3.39483
# INFO:tensorflow:loss = 3.45331, step = 401 (29.285 sec)
# INFO:tensorflow:global_step/sec: 3.40774
# INFO:tensorflow:loss = 3.37065, step = 501 (29.407 sec)
# INFO:tensorflow:global_step/sec: 3.48671
# INFO:tensorflow:loss = 3.47302, step = 601 (28.715 sec)
# INFO:tensorflow:global_step/sec: 3.39895
# INFO:tensorflow:loss = 5.23085, step = 701 (29.386 sec)
# INFO:tensorflow:global_step/sec: 3.4306
# INFO:tensorflow:loss = 3.22408, step = 801 (29.431 sec)
# INFO:tensorflow:global_step/sec: 3.19353
# INFO:tensorflow:loss = 2.87608, step = 901 (31.079 sec)
# INFO:tensorflow:global_step/sec: 3.24334
# INFO:tensorflow:loss = 4.44022, step = 1001 (30.817 sec)
# INFO:tensorflow:global_step/sec: 3.24302
# INFO:tensorflow:loss = 3.24816, step = 1101 (30.804 sec)
# INFO:tensorflow:global_step/sec: 3.50932
# INFO:tensorflow:loss = 1.40936, step = 1201 (28.496 sec)
# INFO:tensorflow:global_step/sec: 3.39571
# INFO:tensorflow:loss = 1.3462, step = 1301 (29.496 sec)
# INFO:tensorflow:global_step/sec: 3.46299
# INFO:tensorflow:loss = 2.35666, step = 1401 (28.877 sec)
# INFO:tensorflow:global_step/sec: 3.30278
# INFO:tensorflow:loss = 7.25624, step = 1501 (30.293 sec)
# INFO:tensorflow:global_step/sec: 3.50144
# INFO:tensorflow:loss = 4.54458, step = 1601 (28.497 sec)
# INFO:tensorflow:global_step/sec: 2.89694
# INFO:tensorflow:loss = 1.44002, step = 1701 (34.629 sec)
# INFO:tensorflow:global_step/sec: 3.51296
# INFO:tensorflow:loss = 2.77908, step = 1801 (28.403 sec)
# INFO:tensorflow:global_step/sec: 3.21878
# INFO:tensorflow:loss = 6.70518, step = 1901 (31.021 sec)
# INFO:tensorflow:Saving checkpoints for 1958 into C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.36079
# INFO:tensorflow:loss = 6.05662, step = 2001 (73.377 sec)
# INFO:tensorflow:global_step/sec: 5.36366
# INFO:tensorflow:loss = 4.07734, step = 2101 (18.831 sec)
# INFO:tensorflow:global_step/sec: 3.47849
# INFO:tensorflow:loss = 3.54497, step = 2201 (28.608 sec)
# INFO:tensorflow:global_step/sec: 3.4135
# INFO:tensorflow:loss = 1.76503, step = 2301 (29.389 sec)
# INFO:tensorflow:global_step/sec: 3.34623
# INFO:tensorflow:loss = 5.14716, step = 2401 (29.900 sec)
# INFO:tensorflow:global_step/sec: 3.48155
# INFO:tensorflow:loss = 2.2851, step = 2501 (28.551 sec)
# INFO:tensorflow:global_step/sec: 3.49133
# INFO:tensorflow:loss = 5.87697, step = 2601 (28.783 sec)
# INFO:tensorflow:global_step/sec: 3.41602
# INFO:tensorflow:loss = 2.67834, step = 2701 (29.305 sec)
# INFO:tensorflow:global_step/sec: 3.48
# INFO:tensorflow:loss = 1.19025, step = 2801 (28.736 sec)
# INFO:tensorflow:global_step/sec: 3.39702
# INFO:tensorflow:loss = 2.05141, step = 2901 (29.438 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.31428.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-16:18:08
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-16:18:37
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.875, accuracy_baseline = 0.839286, auc = 0.852819, auc_precision_recall = 0.962218, average_loss = 0.314918, global_step = 3000, label/mean = 0.839286, loss = 30.8619, prediction/mean = 0.830992
# Evaluation using Tensorflow evaluate method...Result at folding session: 1 {'auc': 0.85281938, 'loss': 30.861925, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.31491762, 'accuracy': 0.875, 'global_step': 3000, 'prediction/mean': 0.8309921, 'auc_precision_recall': 0.96221769}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp0eh6uys1\model.ckpt-3000
#
# -----Folding Session 1 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.852696161207 Accuracy: 0.875 Error_rate: 0.125
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpt0kn7v7k', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k\model.ckpt.
# INFO:tensorflow:loss = 6.92531, step = 1
# INFO:tensorflow:global_step/sec: 9.08428
# INFO:tensorflow:loss = 3.39081, step = 101 (11.164 sec)
# INFO:tensorflow:global_step/sec: 3.44094
# INFO:tensorflow:loss = 5.42658, step = 201 (29.077 sec)
# INFO:tensorflow:global_step/sec: 3.38205
# INFO:tensorflow:loss = 5.08001, step = 301 (29.615 sec)
# INFO:tensorflow:global_step/sec: 3.48176
# INFO:tensorflow:loss = 1.44548, step = 401 (28.674 sec)
# INFO:tensorflow:global_step/sec: 3.40476
# INFO:tensorflow:loss = 5.37102, step = 501 (29.355 sec)
# INFO:tensorflow:global_step/sec: 3.61303
# INFO:tensorflow:loss = 1.72763, step = 601 (27.662 sec)
# INFO:tensorflow:global_step/sec: 3.16693
# INFO:tensorflow:loss = 4.66836, step = 701 (31.545 sec)
# INFO:tensorflow:global_step/sec: 2.62645
# INFO:tensorflow:loss = 3.35317, step = 801 (38.152 sec)
# INFO:tensorflow:global_step/sec: 3.3948
# INFO:tensorflow:loss = 5.5248, step = 901 (29.426 sec)
# INFO:tensorflow:global_step/sec: 3.34065
# INFO:tensorflow:loss = 2.49945, step = 1001 (30.669 sec)
# INFO:tensorflow:global_step/sec: 3.41145
# INFO:tensorflow:loss = 0.97425, step = 1101 (28.579 sec)
# INFO:tensorflow:global_step/sec: 3.28284
# INFO:tensorflow:loss = 1.06711, step = 1201 (30.461 sec)
# INFO:tensorflow:global_step/sec: 3.49212
# INFO:tensorflow:loss = 1.16241, step = 1301 (28.589 sec)
# INFO:tensorflow:global_step/sec: 3.37312
# INFO:tensorflow:loss = 3.66913, step = 1401 (29.709 sec)
# INFO:tensorflow:global_step/sec: 3.50951
# INFO:tensorflow:loss = 0.73578, step = 1501 (28.478 sec)
# INFO:tensorflow:global_step/sec: 3.37958
# INFO:tensorflow:loss = 9.15588, step = 1601 (29.590 sec)
# INFO:tensorflow:global_step/sec: 2.41728
# INFO:tensorflow:loss = 2.87993, step = 1701 (41.494 sec)
# INFO:tensorflow:global_step/sec: 2.91888
# INFO:tensorflow:loss = 0.836471, step = 1801 (34.166 sec)
# INFO:tensorflow:Saving checkpoints for 1881 into C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.08501
# INFO:tensorflow:loss = 3.68169, step = 1901 (92.196 sec)
# INFO:tensorflow:global_step/sec: 5.64519
# INFO:tensorflow:loss = 4.71644, step = 2001 (17.652 sec)
# INFO:tensorflow:global_step/sec: 3.35488
# INFO:tensorflow:loss = 1.90681, step = 2101 (29.807 sec)
# INFO:tensorflow:global_step/sec: 3.39737
# INFO:tensorflow:loss = 2.33464, step = 2201 (29.419 sec)
# INFO:tensorflow:global_step/sec: 2.97517
# INFO:tensorflow:loss = 3.46671, step = 2301 (33.674 sec)
# INFO:tensorflow:global_step/sec: 3.07474
# INFO:tensorflow:loss = 5.34315, step = 2401 (32.554 sec)
# INFO:tensorflow:global_step/sec: 3.1786
# INFO:tensorflow:loss = 1.69109, step = 2501 (31.367 sec)
# INFO:tensorflow:global_step/sec: 3.08273
# INFO:tensorflow:loss = 4.19746, step = 2601 (32.472 sec)
# INFO:tensorflow:global_step/sec: 3.40464
# INFO:tensorflow:loss = 0.621631, step = 2701 (29.323 sec)
# INFO:tensorflow:global_step/sec: 3.25255
# INFO:tensorflow:loss = 3.50269, step = 2801 (30.840 sec)
# INFO:tensorflow:global_step/sec: 3.34435
# INFO:tensorflow:loss = 2.23888, step = 2901 (29.744 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.13069.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-16:43:24
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-16:43:54
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.861395, accuracy_baseline = 0.839286, auc = 0.843637, auc_precision_recall = 0.959175, average_loss = 0.327203, global_step = 3000, label/mean = 0.839286, loss = 32.0659, prediction/mean = 0.838985
# Evaluation using Tensorflow evaluate method...Result at folding session: 2 {'auc': 0.84363657, 'loss': 32.065857, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.32720262, 'accuracy': 0.86139458, 'global_step': 3000, 'prediction/mean': 0.83898532, 'auc_precision_recall': 0.95917487}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpt0kn7v7k\model.ckpt-3000
#
# -----Folding Session 2 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.844328117378 Accuracy: 0.861394557823 Error_rate: 0.138605442177
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpz89x0c7q', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q\model.ckpt.
# INFO:tensorflow:loss = 6.92074, step = 1
# INFO:tensorflow:global_step/sec: 8.73452
# INFO:tensorflow:loss = 4.99094, step = 101 (11.621 sec)
# INFO:tensorflow:global_step/sec: 3.54157
# INFO:tensorflow:loss = 1.83628, step = 201 (28.189 sec)
# INFO:tensorflow:global_step/sec: 3.47758
# INFO:tensorflow:loss = 3.46389, step = 301 (28.959 sec)
# INFO:tensorflow:global_step/sec: 3.36372
# INFO:tensorflow:loss = 8.90357, step = 401 (29.557 sec)
# INFO:tensorflow:global_step/sec: 3.49718
# INFO:tensorflow:loss = 5.10648, step = 501 (28.579 sec)
# INFO:tensorflow:global_step/sec: 3.39224
# INFO:tensorflow:loss = 8.20026, step = 601 (29.463 sec)
# INFO:tensorflow:global_step/sec: 3.48887
# INFO:tensorflow:loss = 1.82982, step = 701 (28.678 sec)
# INFO:tensorflow:global_step/sec: 3.45105
# INFO:tensorflow:loss = 4.95711, step = 801 (29.008 sec)
# INFO:tensorflow:global_step/sec: 3.4307
# INFO:tensorflow:loss = 2.31534, step = 901 (29.117 sec)
# INFO:tensorflow:global_step/sec: 3.31816
# INFO:tensorflow:loss = 3.17611, step = 1001 (30.075 sec)
# INFO:tensorflow:global_step/sec: 3.00954
# INFO:tensorflow:loss = 5.5635, step = 1101 (33.259 sec)
# INFO:tensorflow:global_step/sec: 3.3802
# INFO:tensorflow:loss = 3.78439, step = 1201 (29.678 sec)
# INFO:tensorflow:global_step/sec: 3.53779
# INFO:tensorflow:loss = 3.07016, step = 1301 (28.188 sec)
# INFO:tensorflow:global_step/sec: 3.01905
# INFO:tensorflow:loss = 7.26635, step = 1401 (33.154 sec)
# INFO:tensorflow:global_step/sec: 2.98263
# INFO:tensorflow:loss = 4.84684, step = 1501 (33.449 sec)
# INFO:tensorflow:global_step/sec: 3.38332
# INFO:tensorflow:loss = 3.82893, step = 1601 (29.557 sec)
# INFO:tensorflow:global_step/sec: 3.07286
# INFO:tensorflow:loss = 1.37852, step = 1701 (32.574 sec)
# INFO:tensorflow:global_step/sec: 3.40106
# INFO:tensorflow:loss = 2.03929, step = 1801 (29.418 sec)
# INFO:tensorflow:global_step/sec: 3.01678
# INFO:tensorflow:loss = 1.43917, step = 1901 (33.164 sec)
# INFO:tensorflow:Saving checkpoints for 1934 into C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.27818
# INFO:tensorflow:loss = 4.10584, step = 2001 (78.183 sec)
# INFO:tensorflow:global_step/sec: 4.12078
# INFO:tensorflow:loss = 3.75417, step = 2101 (24.352 sec)
# INFO:tensorflow:global_step/sec: 3.32159
# INFO:tensorflow:loss = 2.83852, step = 2201 (30.075 sec)
# INFO:tensorflow:global_step/sec: 3.31598
# INFO:tensorflow:loss = 2.1764, step = 2301 (30.085 sec)
# INFO:tensorflow:global_step/sec: 3.29336
# INFO:tensorflow:loss = 1.51553, step = 2401 (30.468 sec)
# INFO:tensorflow:global_step/sec: 2.93358
# INFO:tensorflow:loss = 5.66071, step = 2501 (34.088 sec)
# INFO:tensorflow:global_step/sec: 3.31187
# INFO:tensorflow:loss = 0.976227, step = 2601 (30.210 sec)
# INFO:tensorflow:global_step/sec: 3.34791
# INFO:tensorflow:loss = 1.13689, step = 2701 (29.838 sec)
# INFO:tensorflow:global_step/sec: 3.34018
# INFO:tensorflow:loss = 2.63484, step = 2801 (30.017 sec)
# INFO:tensorflow:global_step/sec: 3.40492
# INFO:tensorflow:loss = 2.22924, step = 2901 (29.229 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q\model.ckpt.
# INFO:tensorflow:Loss for final step: 4.69483.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-17:08:12
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-17:08:41
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.869898, accuracy_baseline = 0.839286, auc = 0.841318, auc_precision_recall = 0.961216, average_loss = 0.327202, global_step = 3000, label/mean = 0.839286, loss = 32.0658, prediction/mean = 0.842993
# Evaluation using Tensorflow evaluate method...Result at folding session: 3 {'auc': 0.84131801, 'loss': 32.065792, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.32720196, 'accuracy': 0.86989796, 'global_step': 3000, 'prediction/mean': 0.84299272, 'auc_precision_recall': 0.96121567}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpz89x0c7q\model.ckpt-3000
#
# -----Folding Session 3 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.840433572956 Accuracy: 0.869897959184 Error_rate: 0.130102040816
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpviu4j0e6', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt.
# INFO:tensorflow:loss = 6.91809, step = 1
# INFO:tensorflow:global_step/sec: 6.73043
# INFO:tensorflow:loss = 3.25241, step = 101 (14.967 sec)
# INFO:tensorflow:global_step/sec: 3.42319
# INFO:tensorflow:loss = 5.16785, step = 201 (29.275 sec)
# INFO:tensorflow:global_step/sec: 3.49549
# INFO:tensorflow:loss = 3.4398, step = 301 (28.937 sec)
# INFO:tensorflow:global_step/sec: 3.53393
# INFO:tensorflow:loss = 6.29143, step = 401 (27.922 sec)
# INFO:tensorflow:global_step/sec: 2.93325
# INFO:tensorflow:loss = 5.0237, step = 501 (34.139 sec)
# INFO:tensorflow:global_step/sec: 3.22673
# INFO:tensorflow:loss = 3.42812, step = 601 (30.835 sec)
# INFO:tensorflow:global_step/sec: 3.24991
# INFO:tensorflow:loss = 10.2106, step = 701 (30.973 sec)
# INFO:tensorflow:global_step/sec: 3.11475
# INFO:tensorflow:loss = 3.25979, step = 801 (32.043 sec)
# INFO:tensorflow:global_step/sec: 3.29958
# INFO:tensorflow:loss = 1.03941, step = 901 (30.322 sec)
# INFO:tensorflow:global_step/sec: 3.43715
# INFO:tensorflow:loss = 6.65681, step = 1001 (29.063 sec)
# INFO:tensorflow:global_step/sec: 3.40774
# INFO:tensorflow:loss = 2.96765, step = 1101 (29.782 sec)
# INFO:tensorflow:global_step/sec: 3.57174
# INFO:tensorflow:loss = 1.21257, step = 1201 (27.560 sec)
# INFO:tensorflow:global_step/sec: 3.41273
# INFO:tensorflow:loss = 1.24838, step = 1301 (29.318 sec)
# INFO:tensorflow:global_step/sec: 3.44217
# INFO:tensorflow:loss = 7.21458, step = 1401 (29.052 sec)
# INFO:tensorflow:global_step/sec: 3.52835
# INFO:tensorflow:loss = 5.15862, step = 1501 (28.341 sec)
# INFO:tensorflow:global_step/sec: 3.53551
# INFO:tensorflow:loss = 4.10747, step = 1601 (28.331 sec)
# INFO:tensorflow:global_step/sec: 3.37931
# INFO:tensorflow:loss = 0.976556, step = 1701 (29.561 sec)
# INFO:tensorflow:global_step/sec: 3.41499
# INFO:tensorflow:loss = 0.704683, step = 1801 (29.235 sec)
# INFO:tensorflow:global_step/sec: 3.49425
# INFO:tensorflow:loss = 3.44344, step = 1901 (28.556 sec)
# INFO:tensorflow:Saving checkpoints for 1957 into C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.38659
# INFO:tensorflow:loss = 5.56187, step = 2001 (72.166 sec)
# INFO:tensorflow:global_step/sec: 5.08789
# INFO:tensorflow:loss = 1.27155, step = 2101 (19.717 sec)
# INFO:tensorflow:global_step/sec: 3.32308
# INFO:tensorflow:loss = 6.89952, step = 2201 (30.061 sec)
# INFO:tensorflow:global_step/sec: 3.38598
# INFO:tensorflow:loss = 1.42672, step = 2301 (29.534 sec)
# INFO:tensorflow:global_step/sec: 3.4741
# INFO:tensorflow:loss = 3.11681, step = 2401 (28.784 sec)
# INFO:tensorflow:global_step/sec: 3.38758
# INFO:tensorflow:loss = 1.96914, step = 2501 (29.598 sec)
# INFO:tensorflow:global_step/sec: 3.45325
# INFO:tensorflow:loss = 1.31024, step = 2601 (28.865 sec)
# INFO:tensorflow:global_step/sec: 3.27156
# INFO:tensorflow:loss = 1.92511, step = 2701 (30.597 sec)
# INFO:tensorflow:global_step/sec: 3.42855
# INFO:tensorflow:loss = 1.85435, step = 2801 (29.089 sec)
# INFO:tensorflow:global_step/sec: 3.36364
# INFO:tensorflow:loss = 1.34048, step = 2901 (29.714 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt.
# INFO:tensorflow:Loss for final step: 7.83053.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-17:32:38
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-17:33:08
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.877551, accuracy_baseline = 0.839286, auc = 0.860335, auc_precision_recall = 0.964228, average_loss = 0.308434, global_step = 3000, label/mean = 0.839286, loss = 30.2265, prediction/mean = 0.851243
# Evaluation using Tensorflow evaluate method...Result at folding session: 4 {'auc': 0.86033517, 'loss': 30.226507, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.30843374, 'accuracy': 0.87755102, 'global_step': 3000, 'prediction/mean': 0.8512435, 'auc_precision_recall': 0.96422756}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt-3000
# -----Folding Session 4 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.86123038656 Accuracy: 0.877551020408 Error_rate: 0.122448979592
# Selecting model based on max_auc.
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp8uxz3hxy', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy\model.ckpt.
# INFO:tensorflow:loss = 6.92469, step = 1
# INFO:tensorflow:global_step/sec: 9.0045
# INFO:tensorflow:loss = 3.62283, step = 101 (11.293 sec)
# INFO:tensorflow:global_step/sec: 3.5015
# INFO:tensorflow:loss = 2.98063, step = 201 (28.481 sec)
# INFO:tensorflow:global_step/sec: 3.32727
# INFO:tensorflow:loss = 2.45109, step = 301 (30.148 sec)
# INFO:tensorflow:global_step/sec: 3.47023
# INFO:tensorflow:loss = 6.66185, step = 401 (28.754 sec)
# INFO:tensorflow:global_step/sec: 3.38807
# INFO:tensorflow:loss = 1.41074, step = 501 (29.547 sec)
# INFO:tensorflow:global_step/sec: 3.40822
# INFO:tensorflow:loss = 3.28901, step = 601 (29.294 sec)
# INFO:tensorflow:global_step/sec: 3.59029
# INFO:tensorflow:loss = 5.34045, step = 701 (27.900 sec)
# INFO:tensorflow:global_step/sec: 3.42766
# INFO:tensorflow:loss = 4.292, step = 801 (29.206 sec)
# INFO:tensorflow:global_step/sec: 3.39202
# INFO:tensorflow:loss = 6.03217, step = 901 (29.450 sec)
# INFO:tensorflow:global_step/sec: 3.44419
# INFO:tensorflow:loss = 3.35916, step = 1001 (28.972 sec)
# INFO:tensorflow:global_step/sec: 2.96315
# INFO:tensorflow:loss = 3.35263, step = 1101 (33.748 sec)
# INFO:tensorflow:global_step/sec: 3.31626
# INFO:tensorflow:loss = 1.46239, step = 1201 (30.233 sec)
# INFO:tensorflow:global_step/sec: 3.44212
# INFO:tensorflow:loss = 2.10823, step = 1301 (28.958 sec)
# INFO:tensorflow:global_step/sec: 3.18556
# INFO:tensorflow:loss = 4.61385, step = 1401 (31.470 sec)
# INFO:tensorflow:global_step/sec: 3.12923
# INFO:tensorflow:loss = 3.66742, step = 1501 (31.926 sec)
# INFO:tensorflow:global_step/sec: 3.08638
# INFO:tensorflow:loss = 2.19658, step = 1601 (32.416 sec)
# INFO:tensorflow:global_step/sec: 3.39479
# INFO:tensorflow:loss = 2.55121, step = 1701 (29.457 sec)
# INFO:tensorflow:global_step/sec: 3.40127
# INFO:tensorflow:loss = 2.27069, step = 1801 (29.385 sec)
# INFO:tensorflow:global_step/sec: 3.37552
# INFO:tensorflow:loss = 6.19041, step = 1901 (29.656 sec)
# INFO:tensorflow:Saving checkpoints for 1952 into C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.37518
# INFO:tensorflow:loss = 1.16523, step = 2001 (72.671 sec)
# INFO:tensorflow:global_step/sec: 4.81758
# INFO:tensorflow:loss = 0.422533, step = 2101 (20.726 sec)
# INFO:tensorflow:global_step/sec: 3.35053
# INFO:tensorflow:loss = 1.80921, step = 2201 (29.924 sec)
# INFO:tensorflow:global_step/sec: 3.46021
# INFO:tensorflow:loss = 2.78934, step = 2301 (28.900 sec)
# INFO:tensorflow:global_step/sec: 3.44234
# INFO:tensorflow:loss = 2.91207, step = 2401 (29.050 sec)
# INFO:tensorflow:global_step/sec: 3.42509
# INFO:tensorflow:loss = 1.52079, step = 2501 (29.259 sec)
# INFO:tensorflow:global_step/sec: 3.25019
# INFO:tensorflow:loss = 3.94373, step = 2601 (30.705 sec)
# INFO:tensorflow:global_step/sec: 3.48281
# INFO:tensorflow:loss = 6.47745, step = 2701 (28.728 sec)
# INFO:tensorflow:global_step/sec: 3.1509
# INFO:tensorflow:loss = 5.2815, step = 2801 (31.721 sec)
# INFO:tensorflow:global_step/sec: 3.31099
# INFO:tensorflow:loss = 4.56457, step = 2901 (30.156 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.51719.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-17:57:03
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-17:57:33
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.875, accuracy_baseline = 0.839286, auc = 0.835234, auc_precision_recall = 0.954039, average_loss = 0.326687, global_step = 3000, label/mean = 0.839286, loss = 32.0153, prediction/mean = 0.821678
# Evaluation using Tensorflow evaluate method...Result at folding session: 5 {'auc': 0.83523375, 'loss': 32.015308, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.3266868, 'accuracy': 0.875, 'global_step': 3000, 'prediction/mean': 0.82167834, 'auc_precision_recall': 0.95403898}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp8uxz3hxy\model.ckpt-3000
#
# -----Folding Session 5 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.834831647395 Accuracy: 0.875 Error_rate: 0.125
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpbf5rekzo', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo\model.ckpt.
# INFO:tensorflow:loss = 6.92163, step = 1
# INFO:tensorflow:global_step/sec: 8.0066
# INFO:tensorflow:loss = 5.01644, step = 101 (12.630 sec)
# INFO:tensorflow:global_step/sec: 3.1781
# INFO:tensorflow:loss = 3.49942, step = 201 (31.465 sec)
# INFO:tensorflow:global_step/sec: 2.98752
# INFO:tensorflow:loss = 7.0616, step = 301 (33.519 sec)
# INFO:tensorflow:global_step/sec: 3.35629
# INFO:tensorflow:loss = 5.04505, step = 401 (29.732 sec)
# INFO:tensorflow:global_step/sec: 3.31801
# INFO:tensorflow:loss = 3.58102, step = 501 (30.170 sec)
# INFO:tensorflow:global_step/sec: 3.19023
# INFO:tensorflow:loss = 4.98975, step = 601 (31.330 sec)
# INFO:tensorflow:global_step/sec: 3.35516
# INFO:tensorflow:loss = 4.0533, step = 701 (29.852 sec)
# INFO:tensorflow:global_step/sec: 3.34972
# INFO:tensorflow:loss = 4.73076, step = 801 (29.823 sec)
# INFO:tensorflow:global_step/sec: 3.35822
# INFO:tensorflow:loss = 5.85714, step = 901 (29.792 sec)
# INFO:tensorflow:global_step/sec: 3.45517
# INFO:tensorflow:loss = 1.10309, step = 1001 (28.895 sec)
# INFO:tensorflow:global_step/sec: 3.36782
# INFO:tensorflow:loss = 2.92574, step = 1101 (29.708 sec)
# INFO:tensorflow:global_step/sec: 3.41467
# INFO:tensorflow:loss = 1.30926, step = 1201 (29.285 sec)
# INFO:tensorflow:global_step/sec: 3.50499
# INFO:tensorflow:loss = 2.08263, step = 1301 (28.562 sec)
# INFO:tensorflow:global_step/sec: 3.28857
# INFO:tensorflow:loss = 6.09706, step = 1401 (30.377 sec)
# INFO:tensorflow:global_step/sec: 3.50651
# INFO:tensorflow:loss = 5.65892, step = 1501 (28.565 sec)
# INFO:tensorflow:global_step/sec: 3.42038
# INFO:tensorflow:loss = 2.63971, step = 1601 (29.205 sec)
# INFO:tensorflow:global_step/sec: 3.49746
# INFO:tensorflow:loss = 4.65606, step = 1701 (28.936 sec)
# INFO:tensorflow:global_step/sec: 3.50617
# INFO:tensorflow:loss = 2.47928, step = 1801 (28.130 sec)
# INFO:tensorflow:global_step/sec: 3.35809
# INFO:tensorflow:loss = 2.57545, step = 1901 (29.810 sec)
# INFO:tensorflow:Saving checkpoints for 1944 into C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.41746
# INFO:tensorflow:loss = 1.80579, step = 2001 (70.564 sec)
# INFO:tensorflow:global_step/sec: 4.29541
# INFO:tensorflow:loss = 3.68132, step = 2101 (23.249 sec)
# INFO:tensorflow:global_step/sec: 3.44786
# INFO:tensorflow:loss = 2.29366, step = 2201 (29.019 sec)
# INFO:tensorflow:global_step/sec: 3.34851
# INFO:tensorflow:loss = 11.6341, step = 2301 (29.864 sec)
# INFO:tensorflow:global_step/sec: 3.06334
# INFO:tensorflow:loss = 0.757971, step = 2401 (32.645 sec)
# INFO:tensorflow:global_step/sec: 3.42796
# INFO:tensorflow:loss = 3.06237, step = 2501 (29.265 sec)
# INFO:tensorflow:global_step/sec: 3.43626
# INFO:tensorflow:loss = 3.42396, step = 2601 (29.039 sec)
# INFO:tensorflow:global_step/sec: 3.36293
# INFO:tensorflow:loss = 2.03816, step = 2701 (29.705 sec)
# INFO:tensorflow:global_step/sec: 3.25186
# INFO:tensorflow:loss = 3.42018, step = 2801 (30.736 sec)
# INFO:tensorflow:global_step/sec: 3.47905
# INFO:tensorflow:loss = 3.03244, step = 2901 (28.743 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo\model.ckpt.
# INFO:tensorflow:Loss for final step: 10.3489.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-18:21:44
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-18:22:14
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.867347, accuracy_baseline = 0.839286, auc = 0.838922, auc_precision_recall = 0.958517, average_loss = 0.344646, global_step = 3000, label/mean = 0.839286, loss = 33.7753, prediction/mean = 0.788456
# Evaluation using Tensorflow evaluate method...Result at folding session: 6 {'auc': 0.8389219, 'loss': 33.775311, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.34464601, 'accuracy': 0.86734694, 'global_step': 3000, 'prediction/mean': 0.78845596, 'auc_precision_recall': 0.95851743}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbf5rekzo\model.ckpt-3000
#
# -----Folding Session 6 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.838758355982 Accuracy: 0.867346938776 Error_rate: 0.132653061224
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp93wnx5nj', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj\model.ckpt.
# INFO:tensorflow:loss = 6.92187, step = 1
# INFO:tensorflow:global_step/sec: 8.46729
# INFO:tensorflow:loss = 4.08942, step = 101 (11.982 sec)
# INFO:tensorflow:global_step/sec: 3.39123
# INFO:tensorflow:loss = 4.98252, step = 201 (29.441 sec)
# INFO:tensorflow:global_step/sec: 3.34159
# INFO:tensorflow:loss = 4.99484, step = 301 (30.004 sec)
# INFO:tensorflow:global_step/sec: 3.47781
# INFO:tensorflow:loss = 5.02426, step = 401 (28.644 sec)
# INFO:tensorflow:global_step/sec: 3.27595
# INFO:tensorflow:loss = 8.79114, step = 501 (30.557 sec)
# INFO:tensorflow:global_step/sec: 3.39646
# INFO:tensorflow:loss = 5.00397, step = 601 (29.458 sec)
# INFO:tensorflow:global_step/sec: 3.4327
# INFO:tensorflow:loss = 5.14247, step = 701 (29.100 sec)
# INFO:tensorflow:global_step/sec: 3.49694
# INFO:tensorflow:loss = 3.04327, step = 801 (28.612 sec)
# INFO:tensorflow:global_step/sec: 3.24605
# INFO:tensorflow:loss = 3.60738, step = 901 (30.885 sec)
# INFO:tensorflow:global_step/sec: 3.47596
# INFO:tensorflow:loss = 6.23119, step = 1001 (28.644 sec)
# INFO:tensorflow:global_step/sec: 3.37935
# INFO:tensorflow:loss = 2.09425, step = 1101 (29.670 sec)
# INFO:tensorflow:global_step/sec: 3.45235
# INFO:tensorflow:loss = 3.44867, step = 1201 (28.965 sec)
# INFO:tensorflow:global_step/sec: 3.26544
# INFO:tensorflow:loss = 1.96076, step = 1301 (30.670 sec)
# INFO:tensorflow:global_step/sec: 3.33628
# INFO:tensorflow:loss = 3.97689, step = 1401 (29.927 sec)
# INFO:tensorflow:global_step/sec: 3.57385
# INFO:tensorflow:loss = 4.93679, step = 1501 (27.997 sec)
# INFO:tensorflow:global_step/sec: 3.34291
# INFO:tensorflow:loss = 2.09316, step = 1601 (29.867 sec)
# INFO:tensorflow:global_step/sec: 3.01758
# INFO:tensorflow:loss = 3.76672, step = 1701 (33.202 sec)
# INFO:tensorflow:global_step/sec: 3.38889
# INFO:tensorflow:loss = 5.52021, step = 1801 (29.461 sec)
# INFO:tensorflow:global_step/sec: 3.39822
# INFO:tensorflow:loss = 4.36046, step = 1901 (29.458 sec)
# INFO:tensorflow:Saving checkpoints for 1961 into C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.18668
# INFO:tensorflow:loss = 5.80595, step = 2001 (84.255 sec)
# INFO:tensorflow:global_step/sec: 5.31808
# INFO:tensorflow:loss = 4.24564, step = 2101 (18.786 sec)
# INFO:tensorflow:global_step/sec: 2.62123
# INFO:tensorflow:loss = 1.33697, step = 2201 (38.181 sec)
# INFO:tensorflow:global_step/sec: 3.30216
# INFO:tensorflow:loss = 4.75907, step = 2301 (30.268 sec)
# INFO:tensorflow:global_step/sec: 2.90288
# INFO:tensorflow:loss = 1.41685, step = 2401 (34.464 sec)
# INFO:tensorflow:global_step/sec: 3.34935
# INFO:tensorflow:loss = 3.6906, step = 2501 (29.794 sec)
# INFO:tensorflow:global_step/sec: 3.1495
# INFO:tensorflow:loss = 2.52687, step = 2601 (31.814 sec)
# INFO:tensorflow:global_step/sec: 3.28399
# INFO:tensorflow:loss = 4.99503, step = 2701 (30.420 sec)
# INFO:tensorflow:global_step/sec: 3.46702
# INFO:tensorflow:loss = 2.99301, step = 2801 (28.937 sec)
# INFO:tensorflow:global_step/sec: 3.48128
# INFO:tensorflow:loss = 8.17009, step = 2901 (28.631 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.59527.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-18:46:29
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-18:47:07
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.857993, accuracy_baseline = 0.839286, auc = 0.81876, auc_precision_recall = 0.947242, average_loss = 0.342127, global_step = 3000, label/mean = 0.839286, loss = 33.5284, prediction/mean = 0.851594
# Evaluation using Tensorflow evaluate method...Result at folding session: 7 {'auc': 0.81876028, 'loss': 33.528416, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.34212667, 'accuracy': 0.85799319, 'global_step': 3000, 'prediction/mean': 0.85159421, 'auc_precision_recall': 0.9472419}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp93wnx5nj\model.ckpt-3000
#
# -----Folding Session 7 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.818907704926 Accuracy: 0.857993197279 Error_rate: 0.142006802721
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmpbdfrj9kq', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq\model.ckpt.
# INFO:tensorflow:loss = 6.92162, step = 1
# INFO:tensorflow:global_step/sec: 5.63893
# INFO:tensorflow:loss = 9.34445, step = 101 (17.804 sec)
# INFO:tensorflow:global_step/sec: 2.36329
# INFO:tensorflow:loss = 3.5365, step = 201 (42.426 sec)
# INFO:tensorflow:global_step/sec: 2.69847
# INFO:tensorflow:loss = 3.56595, step = 301 (36.941 sec)
# INFO:tensorflow:global_step/sec: 2.44602
# INFO:tensorflow:loss = 3.40691, step = 401 (40.866 sec)
# INFO:tensorflow:global_step/sec: 2.61264
# INFO:tensorflow:loss = 5.37476, step = 501 (38.288 sec)
# INFO:tensorflow:global_step/sec: 3.05208
# INFO:tensorflow:loss = 2.34485, step = 601 (32.831 sec)
# INFO:tensorflow:global_step/sec: 2.57644
# INFO:tensorflow:loss = 3.90745, step = 701 (38.768 sec)
# INFO:tensorflow:global_step/sec: 2.65502
# INFO:tensorflow:loss = 3.74309, step = 801 (37.656 sec)
# INFO:tensorflow:global_step/sec: 2.68073
# INFO:tensorflow:loss = 6.08365, step = 901 (37.358 sec)
# INFO:tensorflow:global_step/sec: 2.59336
# INFO:tensorflow:loss = 7.89543, step = 1001 (38.638 sec)
# INFO:tensorflow:global_step/sec: 3.03676
# INFO:tensorflow:loss = 0.936005, step = 1101 (32.899 sec)
# INFO:tensorflow:global_step/sec: 3.13749
# INFO:tensorflow:loss = 2.67639, step = 1201 (31.874 sec)
# INFO:tensorflow:global_step/sec: 3.13899
# INFO:tensorflow:loss = 7.91987, step = 1301 (31.825 sec)
# INFO:tensorflow:global_step/sec: 3.12754
# INFO:tensorflow:loss = 4.36327, step = 1401 (32.005 sec)
# INFO:tensorflow:global_step/sec: 3.3355
# INFO:tensorflow:loss = 6.4122, step = 1501 (29.996 sec)
# INFO:tensorflow:Saving checkpoints for 1587 into C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.14874
# INFO:tensorflow:loss = 4.55178, step = 1601 (87.068 sec)
# INFO:tensorflow:global_step/sec: 7.37838
# INFO:tensorflow:loss = 3.6259, step = 1701 (13.787 sec)
# INFO:tensorflow:global_step/sec: 3.13681
# INFO:tensorflow:loss = 2.66868, step = 1801 (31.567 sec)
# INFO:tensorflow:global_step/sec: 3.1939
# INFO:tensorflow:loss = 4.14232, step = 1901 (31.341 sec)
# INFO:tensorflow:global_step/sec: 3.19573
# INFO:tensorflow:loss = 3.5605, step = 2001 (31.307 sec)
# INFO:tensorflow:global_step/sec: 3.31503
# INFO:tensorflow:loss = 4.32838, step = 2101 (30.197 sec)
# INFO:tensorflow:global_step/sec: 3.06646
# INFO:tensorflow:loss = 5.09111, step = 2201 (32.564 sec)
# INFO:tensorflow:global_step/sec: 3.14373
# INFO:tensorflow:loss = 3.19859, step = 2301 (31.794 sec)
# INFO:tensorflow:global_step/sec: 3.07603
# INFO:tensorflow:loss = 2.64051, step = 2401 (32.431 sec)
# INFO:tensorflow:global_step/sec: 2.89786
# INFO:tensorflow:loss = 5.39091, step = 2501 (34.586 sec)
# INFO:tensorflow:global_step/sec: 3.14979
# INFO:tensorflow:loss = 2.68498, step = 2601 (31.811 sec)
# INFO:tensorflow:global_step/sec: 3.16112
# INFO:tensorflow:loss = 3.86724, step = 2701 (31.619 sec)
# INFO:tensorflow:global_step/sec: 3.00968
# INFO:tensorflow:loss = 3.55739, step = 2801 (33.195 sec)
# INFO:tensorflow:global_step/sec: 3.02346
# INFO:tensorflow:loss = 3.2555, step = 2901 (33.121 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.88383.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-19:15:17
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-19:15:49
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.855442, accuracy_baseline = 0.839286, auc = 0.823639, auc_precision_recall = 0.95335, average_loss = 0.344611, global_step = 3000, label/mean = 0.839286, loss = 33.7719, prediction/mean = 0.815813
# Evaluation using Tensorflow evaluate method...Result at folding session: 8 {'auc': 0.82363856, 'loss': 33.771889, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.34461111, 'accuracy': 0.85544217, 'global_step': 3000, 'prediction/mean': 0.81581253, 'auc_precision_recall': 0.95334965}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpbdfrj9kq\model.ckpt-3000
#
# -----Folding Session 8 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.824565917778 Accuracy: 0.855442176871 Error_rate: 0.144557823129
# Hidden Settings: [1022, 511, 255, 128]
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k
# INFO:tensorflow:Using config: {'_tf_random_seed': 1, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': 600, '_session_config': None, '_save_checkpoints_steps': None, '_model_dir': 'C:\\Users\\ASR\\AppData\\Local\\Temp\\tmp_d2qly6k', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k\model.ckpt.
# INFO:tensorflow:loss = 6.92132, step = 1
# INFO:tensorflow:global_step/sec: 7.94074
# INFO:tensorflow:loss = 3.43791, step = 101 (12.718 sec)
# INFO:tensorflow:global_step/sec: 3.28955
# INFO:tensorflow:loss = 3.35749, step = 201 (30.399 sec)
# INFO:tensorflow:global_step/sec: 3.3734
# INFO:tensorflow:loss = 7.19712, step = 301 (29.739 sec)
# INFO:tensorflow:global_step/sec: 3.24475
# INFO:tensorflow:loss = 7.24688, step = 401 (30.771 sec)
# INFO:tensorflow:global_step/sec: 3.48749
# INFO:tensorflow:loss = 7.47548, step = 501 (28.690 sec)
# INFO:tensorflow:global_step/sec: 3.41612
# INFO:tensorflow:loss = 1.20443, step = 601 (29.132 sec)
# INFO:tensorflow:global_step/sec: 3.36774
# INFO:tensorflow:loss = 3.3425, step = 701 (29.756 sec)
# INFO:tensorflow:global_step/sec: 3.28673
# INFO:tensorflow:loss = 2.99329, step = 801 (30.410 sec)
# INFO:tensorflow:global_step/sec: 3.45461
# INFO:tensorflow:loss = 6.25181, step = 901 (29.009 sec)
# INFO:tensorflow:global_step/sec: 3.36085
# INFO:tensorflow:loss = 1.088, step = 1001 (29.754 sec)
# INFO:tensorflow:global_step/sec: 3.34664
# INFO:tensorflow:loss = 1.63862, step = 1101 (30.599 sec)
# INFO:tensorflow:global_step/sec: 3.38122
# INFO:tensorflow:loss = 3.15857, step = 1201 (28.872 sec)
# INFO:tensorflow:global_step/sec: 3.39537
# INFO:tensorflow:loss = 1.14712, step = 1301 (29.514 sec)
# INFO:tensorflow:global_step/sec: 3.36932
# INFO:tensorflow:loss = 3.32689, step = 1401 (29.570 sec)
# INFO:tensorflow:global_step/sec: 3.34268
# INFO:tensorflow:loss = 2.83105, step = 1501 (29.932 sec)
# INFO:tensorflow:global_step/sec: 3.3936
# INFO:tensorflow:loss = 1.01805, step = 1601 (29.467 sec)
# INFO:tensorflow:global_step/sec: 3.36897
# INFO:tensorflow:loss = 2.90494, step = 1701 (29.730 sec)
# INFO:tensorflow:global_step/sec: 3.42524
# INFO:tensorflow:loss = 4.1554, step = 1801 (29.195 sec)
# INFO:tensorflow:global_step/sec: 3.1866
# INFO:tensorflow:loss = 1.99147, step = 1901 (31.381 sec)
# INFO:tensorflow:Saving checkpoints for 1964 into C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k\model.ckpt.
# INFO:tensorflow:global_step/sec: 1.23884
# INFO:tensorflow:loss = 7.15399, step = 2001 (80.674 sec)
# INFO:tensorflow:global_step/sec: 5.32568
# INFO:tensorflow:loss = 2.59239, step = 2101 (18.839 sec)
# INFO:tensorflow:global_step/sec: 2.96323
# INFO:tensorflow:loss = 4.09007, step = 2201 (33.716 sec)
# INFO:tensorflow:global_step/sec: 3.32272
# INFO:tensorflow:loss = 6.28306, step = 2301 (30.068 sec)
# INFO:tensorflow:global_step/sec: 3.29575
# INFO:tensorflow:loss = 5.38725, step = 2401 (30.323 sec)
# INFO:tensorflow:global_step/sec: 3.31128
# INFO:tensorflow:loss = 2.76297, step = 2501 (30.294 sec)
# INFO:tensorflow:global_step/sec: 3.28447
# INFO:tensorflow:loss = 6.52138, step = 2601 (30.384 sec)
# INFO:tensorflow:global_step/sec: 3.45357
# INFO:tensorflow:loss = 4.55213, step = 2701 (28.861 sec)
# INFO:tensorflow:global_step/sec: 3.27135
# INFO:tensorflow:loss = 2.40202, step = 2801 (30.678 sec)
# INFO:tensorflow:global_step/sec: 3.16804
# INFO:tensorflow:loss = 2.40438, step = 2901 (31.565 sec)
# INFO:tensorflow:Saving checkpoints for 3000 into C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k\model.ckpt.
# INFO:tensorflow:Loss for final step: 1.16399.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'float32'> labels to bool.
# INFO:tensorflow:Starting evaluation at 2018-04-19-19:40:28
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k\model.ckpt-3000
# INFO:tensorflow:Finished evaluation at 2018-04-19-19:40:58
# INFO:tensorflow:Saving dict for global step 3000: accuracy = 0.873299, accuracy_baseline = 0.839286, auc = 0.847496, auc_precision_recall = 0.962789, average_loss = 0.325462, global_step = 3000, label/mean = 0.839286, loss = 31.8953, prediction/mean = 0.866347
# Evaluation using Tensorflow evaluate method...Result at folding session: 9 {'auc': 0.84749627, 'loss': 31.895254, 'label/mean': 0.83928573, 'accuracy_baseline': 0.83928573, 'average_loss': 0.32546178, 'accuracy': 0.8732993, 'global_step': 3000, 'prediction/mean': 0.86634684, 'auc_precision_recall': 0.96278864}
#
#
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmp_d2qly6k\model.ckpt-3000
# -----Folding Session 9 Hidden Settings: [1022, 511, 255, 128] -----
# AUC: 0.848311113255 Accuracy: 0.873299319728 Error_rate: 0.126700680272
#
# -----k-fold summary:-----
# Evaluation Errors: [0.14030612244897958, 0.125, 0.13860544217687074, 0.13010204081632654, 0.12244897959183673, 0.125, 0.1326530612244898, 0.14200680272108843, 0.14455782312925169, 0.12670068027210885]
# Evaluation error rate average: 0.132738095238
# Model's standard deviation: 0.0076573117448
# INFO:tensorflow:Restoring parameters from C:\Users\ASR\AppData\Local\Temp\tmpviu4j0e6\model.ckpt-3000
#
# Final Test>> AUC: 0.829361161855 Accuracy: 0.870068027211 Final Error_rate: 0.129931972789
# F-measure: 0.926566705113 Accuracy: 0.870068027211 Recall: 0.976499189627 Precision: 0.881492318947 False Positive Rate: 0.686440677966 False Negative Rate: 0.0235008103728
# Confusion matrix, without normalization
# [[ 148  324]
#  [  58 2410]]
# Normalized confusion matrix
# [[ 0.31  0.69]
#  [ 0.02  0.98]]
